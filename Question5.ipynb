# %% [markdown]
# # Question 5

# %%
#Using smth means: pre-compile and load smth as a package.
using Pkg;
#Set the Gurobi path
ENV["GUROBI_HOME"] = "C:\\gurobi1103\\win64"
#For first timers (comment after): compile Gurobi with the given path
Pkg.build("Gurobi")
#Add the packages that may not be installed.
Pkg.add(["Latexify", "Polyhedra", "Plots", "Makie", "CDDLib", "JuMP", "Gurobi", "AbstractPlotting"])
#Load the packages
using JuMP, Latexify, Gurobi, LinearAlgebra, Polyhedra, CDDLib, Plots, SparseArrays, Makie, AbstractPlotting

display("Initialization done! All set :-)")
# Out:
#     Building Gurobi → `C:\Users\user\.julia\scratchspaces\44cfe95a-1eb2-52ea-b672-e2afdf69b78f\53cc56f49295c6b41da670fcf0e0cd812c9580c7\build.log`
#    Resolving package versions...
#   No Changes to `C:\Users\user\.julia\environments\v1.11\Project.toml`
#   No Changes to `C:\Users\user\.julia\environments\v1.11\Manifest.toml`
# ┌ Warning: Everything from AbstractPlotting.jl got moved to Makie.jl.
# │ Have a look at the README for information on how to upgrade:
# │ https://github.com/JuliaPlots/AbstractPlotting.jl
# └ @ AbstractPlotting C:\Users\user\.julia\packages\AbstractPlotting\2A5iv\src\AbstractPlotting.jl:261
# "Initialization done! All set :-)"

# %%
Pkg.status("Gurobi")
# Out:
# Status `C:\Users\user\.julia\environments\v1.11\Project.toml`
# ⌃ [2e9cd046] Gurobi v1.3.1
# Info Packages marked with ⌃ have new versions available and may be upgradable.

# %%
using Pkg
Pkg.add("CSV")
Pkg.add("DataFrames")
Pkg.add("Plots")
# Out:
#    Resolving package versions...
#   No Changes to `C:\Users\user\.julia\environments\v1.11\Project.toml`
#   No Changes to `C:\Users\user\.julia\environments\v1.11\Manifest.toml`
#    Resolving package versions...
#   No Changes to `C:\Users\user\.julia\environments\v1.11\Project.toml`
#   No Changes to `C:\Users\user\.julia\environments\v1.11\Manifest.toml`
#    Resolving package versions...
#   No Changes to `C:\Users\user\.julia\environments\v1.11\Project.toml`
#   No Changes to `C:\Users\user\.julia\environments\v1.11\Manifest.toml`

# %%
# Datasets
thetas = [0.5431, 0.4569]

using CSV, DataFrames
# Read CSV file into DataFrame
data1 = CSV.read("data1.csv", DataFrame)
data2 = CSV.read("data2.csv", DataFrame)
data3 = CSV.read("data3.csv", DataFrame)
data4 = CSV.read("data4.csv", DataFrame)
df_norm_params = CSV.read("normalization_params_q1.csv", DataFrame)

data1_original = deepcopy(data1)
data2_original = deepcopy(data2)
data3_original = deepcopy(data3)
data4_original = deepcopy(data4);

# %%
# Loop through each column of data1,2,3,4 and normalize using df_norm_params
for col in names(data1)
    μ = df_norm_params[1, col]  # mean
    σ = df_norm_params[2, col]  # std
    data1[!, col] .= (data1[!, col] .- μ) ./ σ
end

for col in names(data2)
    μ = df_norm_params[1, col]  # mean
    σ = df_norm_params[2, col]  # std
    data2[!, col] .= (data2[!, col] .- μ) ./ σ
end

for col in names(data3)
    μ = df_norm_params[1, col]  # mean
    σ = df_norm_params[2, col]  # std
    data3[!, col] .= (data3[!, col] .- μ) ./ σ
end

for col in names(data4)
    μ = df_norm_params[1, col]  # mean
    σ = df_norm_params[2, col]  # std
    data4[!, col] .= (data4[!, col] .- μ) ./ σ
end

# %% [markdown]
# ## data1

# %%
# Cleaning up data1, to repeat for data2, 3, 4
using DataFrames, LinearAlgebra

# Step 1: Updated model parameters (new betas)
# intercepts = [-1.9298, -1.5113]  # β₀ for Segment 1 and Segment 2

# # β₁ to β₈ for each segment (rows = segments, columns = features)
# betas = [
#     0.382051   0.123374   0.094369  -0.021846   0.059121  -0.096772  -1.311852  0.140862;   # Segment 1
#     0.455844   0.096673   0.109066   0.085289   0.024871  -0.031250  -1.062061  0.182273    # Segment 2
# ]

# Step 1: Model parameters
intercepts = [-1.9180, -1.5397]  # β₀ for Segment 1 and Segment 2

# β₁ to β₈ for each segment (rows = segments, columns = features)
betas = [
    0.379038   0.124630   0.092098  -0.021459   0.057844  -0.094884  -1.071555  0.134802;   # Segment 1
    0.462759   0.095586   0.112906   0.087280   0.025559  -0.031981  -1.696923  0.194143    # Segment 2
]

# Step 2: Extract features from your DataFrame
features = Matrix(data1)  # 27×8, assume column order is correct

# Step 3: Compute v[i, k] = exp(β₀ₖ + sum_j βⱼₖ xⱼᵢ)
n = size(features, 1)
K = size(betas, 1)
v = Array{Float64}(undef, n, K)

for k in 1:K
    for i in 1:n
        utility = intercepts[k] + dot(betas[k, :], features[i, :])
        v[i, k] = exp(utility)
    end
end

# Price matrix
p = data1_original[:, :price_usd];

# %% [markdown]
# ## Model
# #### do not know customer segment type
#
# $$
# \begin{align*}
# \max \quad & \sum_{k=1}^{2} \theta_k z_k \\
# \text{s.t.} \quad
# & -M y_i \leq x_{ik} \leq M y_i, && \forall i \forall k \\
# & -M(1 - y_i) + p_i - z_k \leq x_{ik} \leq p_i - z_k + M(1 - y_i) && \forall i, \forall k \\
# & z_k \leq \sum_{i=1}^{n} x_{ik} v_{ik} && \forall k \\
# & y_i \in \{0, 1\} && \forall i \\
# & z_k \geq 0 && \forall k
# \end{align*}
# $$

# %%
#Building the JuMP model
using JuMP, Gurobi, LinearAlgebra

#Initialize the model with a given optimizer, say Gurobi
model = Model(Gurobi.Optimizer)
set_optimizer_attribute(model, "OutputFlag", 0)

# Define the variables
num_segment_k = 2
num_hotels_i = nrow(data1)

#create variables
@variable(model, z[1:num_segment_k] >= 0)
@variable(model, y[1:num_hotels_i], Bin)
@variable(model, x[1:num_hotels_i, 1:num_segment_k])

#Set the objective. The arguments are the model object, the objective sense and its expression.
@objective(model, Max, sum(thetas[k] * z[k] for k in 1:num_segment_k))

# Set up constraints

# Constraint 1: -M y_i <= x_ik <= M y_i for all i, k
M = 1000
for i in 1:num_hotels_i, k in 1:num_segment_k
    @constraint(model, -M * y[i] <= x[i, k])
    @constraint(model, x[i, k] <= M * y[i])
end

# Constraint 2: -M (1-y_i) + p_i - z_k <= x_ik <= p_i - z_k + M (1 - y_i) for all i, k
for i in 1:num_hotels_i, k in 1:num_segment_k
    @constraint(model, -M * (1 - y[i]) + p[i] - z[k] <= x[i, k])
    @constraint(model, x[i, k] <= p[i] - z[k] + M * (1 - y[i]))
end

# Constraint 3: z_k <= Sum over i of x_ik v_ik for all k
 for k in 1:num_segment_k
    @constraint(model, z[k] <= sum(x[i, k] * v[i, k] for i in 1:num_hotels_i))
end
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-10-20

# %%
#optimize the model
optimize!(model)

#get the status of the optimization
#either
println("Status = ", raw_status(model))

#print the solution: value and variables
println("data1 without knowing customer segment type")
println("Optimal Objective Function value: ", objective_value(model))
println("Optimal Solutions:")
for i in 1:num_hotels_i
    if value(y[i]) == 1
        println("y[$(i)] = ", value(y[i]))
    end
end

println("All other y_i = 0")
# Out:
# Status = Model was solved to optimality (subject to tolerances), and an optimal solution is available.
# data1 without knowing customer segment type
# Optimal Objective Function value: 107.30479932507615
# Optimal Solutions:
# y[1] = 1.0
# y[2] = 1.0
# y[3] = 1.0
# y[4] = 1.0
# y[5] = 1.0
# y[6] = 1.0
# y[7] = 1.0
# y[13] = 1.0
# y[16] = 1.0
# y[18] = 1.0
# y[19] = 1.0
# y[20] = 1.0
# y[21] = 1.0
# y[22] = 1.0
# y[23] = 1.0
# y[24] = 1.0
# y[25] = 1.0
# y[27] = 1.0
# All other y_i = 0

# %% [markdown]
# ## Model
# #### know customer segment type
#
# $$
# \begin{align*}
# \max z \\
# \text{s.t.} \quad
# & -M y_i \leq x_{i} \leq M y_i, && \forall i \\
# & -M(1 - y_i) + p_i - z \leq x_{i} \leq p_i - z + M(1 - y_i) && \forall i \\
# & z \leq \sum_{i=1}^{n} x_{i} v_{i} \\
# & y_i \in \{0, 1\} && \forall i \\
# \end{align*}
# $$

# %%
# Extract the two columns of v representing the two segments
v_1 = v[:, 1]
v_2 = v[:, 2];

# %%
#Building the JuMP model
using JuMP, Gurobi, LinearAlgebra

#Initialize the model with a given optimizer, say Gurobi
model = Model(Gurobi.Optimizer)
set_optimizer_attribute(model, "OutputFlag", 0)

# Define the variables
num_hotels_i = nrow(data1)

#create variables
@variable(model, z)
@variable(model, y[1:num_hotels_i], Bin)
@variable(model, x[1:num_hotels_i])

#Set the objective. The arguments are the model object, the objective sense and its expression.
@objective(model, Max, z)

# Set up constraints

# Constraint 1: -M y_i <= x_i <= M y_i for all i
M = 1000
for i in 1:num_hotels_i
    @constraint(model, -M * y[i] <= x[i])
    @constraint(model, x[i] <= M * y[i])
end

# Constraint 2: -M (1-y_i) + p_i - z <= x_i <= p_i - z + M (1 - y_i) for all i
for i in 1:num_hotels_i
    @constraint(model, -M * (1 - y[i]) + p[i] - z <= x[i])
    @constraint(model, x[i] <= p[i] - z + M * (1 - y[i]))
end

# Constraint 3: z <= Sum over i of x_i v_i
@constraint(model, z <= sum(x[i] * v_1[i] for i in 1:num_hotels_i));
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-10-20

# %%
#optimize the model
optimize!(model)

#get the status of the optimization
#either
println("Status = ", raw_status(model))

#print the solution: value and variables
println("S1 of data1")
println("Optimal Objective Function value: ", objective_value(model))
println("Optimal Solutions:")
for i in 1:num_hotels_i
    if value(y[i]) == 1
        println("y[$(i)] = ", value(y[i]))
    end
end

println("All other y_i = 0")
# Out:
# Status = Model was solved to optimality (subject to tolerances), and an optimal solution is available.
# S1 of data1
# Optimal Objective Function value: 103.47160468652824
# Optimal Solutions:
# y[1] = 1.0
# y[2] = 1.0
# y[3] = 1.0
# y[4] = 1.0
# y[5] = 1.0
# y[6] = 1.0
# y[7] = 1.0
# y[10] = 1.0
# y[13] = 1.0
# y[15] = 1.0
# y[16] = 1.0
# y[17] = 1.0
# y[18] = 1.0
# y[19] = 1.0
# y[20] = 1.0
# y[21] = 1.0
# y[22] = 1.0
# y[23] = 1.0
# y[24] = 1.0
# y[25] = 1.0
# y[27] = 1.0
# All other y_i = 0

# %%
#Building the JuMP model
using JuMP, Gurobi, LinearAlgebra

#Initialize the model with a given optimizer, say Gurobi
model = Model(Gurobi.Optimizer)
set_optimizer_attribute(model, "OutputFlag", 0)

# Define the variables
num_hotels_i = nrow(data1)

#create variables
@variable(model, z)
@variable(model, y[1:num_hotels_i], Bin)
@variable(model, x[1:num_hotels_i])

#Set the objective. The arguments are the model object, the objective sense and its expression.
@objective(model, Max, z)

# Set up constraints

# Constraint 1: -M y_i <= x_i <= M y_i for all i
M = 1000
for i in 1:num_hotels_i
    @constraint(model, -M * y[i] <= x[i])
    @constraint(model, x[i] <= M * y[i])
end

# Constraint 2: -M (1-y_i) + p_i - z <= x_i <= p_i - z + M (1 - y_i) for all i
for i in 1:num_hotels_i
    @constraint(model, -M * (1 - y[i]) + p[i] - z <= x[i])
    @constraint(model, x[i] <= p[i] - z + M * (1 - y[i]))
end

# Constraint 3: z <= Sum over i of x_i v_i
@constraint(model, z <= sum(x[i] * v_2[i] for i in 1:num_hotels_i))

#optimize the model
optimize!(model)

#get the status of the optimization
#either
println("Status = ", raw_status(model))

#print the solution: value and variables
println("S2 of data1")
println("Optimal Objective Function value: ", objective_value(model))
println("Optimal Solutions:")
for i in 1:num_hotels_i
    if value(y[i]) == 1
        println("y[$(i)] = ", value(y[i]))
    end
end

println("All other y_i = 0")
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-10-20
# Status = Model was solved to optimality (subject to tolerances), and an optimal solution is available.
# S2 of data1
# Optimal Objective Function value: 112.22213523649923
# Optimal Solutions:
# y[1] = 1.0
# y[2] = 1.0
# y[3] = 1.0
# y[4] = 1.0
# y[5] = 1.0
# y[6] = 1.0
# y[7] = 1.0
# y[16] = 1.0
# y[18] = 1.0
# y[19] = 1.0
# y[20] = 1.0
# y[21] = 1.0
# y[22] = 1.0
# y[23] = 1.0
# y[24] = 1.0
# y[25] = 1.0
# All other y_i = 0

# %% [markdown]
# ## data2

# %%
# Cleaning up data2
using DataFrames, LinearAlgebra

# Step 1: Model parameters
intercepts = [-1.9180, -1.5397]  # β₀ for Segment 1 and Segment 2

# β₁ to β₈ for each segment (rows = segments, columns = features)
betas = [
    0.379038   0.124630   0.092098  -0.021459   0.057844  -0.094884  -1.071555  0.134802;   # Segment 1
    0.462759   0.095586   0.112906   0.087280   0.025559  -0.031981  -1.696923  0.194143    # Segment 2
]

# Step 2: Extract features from your DataFrame
features = Matrix(data2)

# Step 3: Compute v[i, k] = exp(β₀ₖ + sum_j βⱼₖ xⱼᵢ)
n = size(features, 1)
K = size(betas, 1)
v = Array{Float64}(undef, n, K)

for k in 1:K
    for i in 1:n
        utility = intercepts[k] + dot(betas[k, :], features[i, :])
        v[i, k] = exp(utility)
    end
end

# Price matrix
p = data2_original[:, :price_usd];

# %% [markdown]
# ### data2 - do not know customer segment type

# %%
#Building the JuMP model
using JuMP, Gurobi, LinearAlgebra

#Initialize the model with a given optimizer, say Gurobi
model = Model(Gurobi.Optimizer)
set_optimizer_attribute(model, "OutputFlag", 0)

# Define the variables
num_segment_k = 2
num_hotels_i = nrow(data2)

#create variables
@variable(model, z[1:num_segment_k] >= 0)
@variable(model, y[1:num_hotels_i], Bin)
@variable(model, x[1:num_hotels_i, 1:num_segment_k])

#Set the objective. The arguments are the model object, the objective sense and its expression.
@objective(model, Max, sum(thetas[k] * z[k] for k in 1:num_segment_k))

# Set up constraints

# Constraint 1: -M y_i <= x_ik <= M y_i for all i, k
M = maximum(p) + 10
for i in 1:num_hotels_i, k in 1:num_segment_k
    @constraint(model, -M * y[i] <= x[i, k])
    @constraint(model, x[i, k] <= M * y[i])
end

# Constraint 2: -M (1-y_i) + p_i - z_k <= x_ik <= p_i - z_k + M (1 - y_i) for all i, k
for i in 1:num_hotels_i, k in 1:num_segment_k
    @constraint(model, -M * (1 - y[i]) + p[i] - z[k] <= x[i, k])
    @constraint(model, x[i, k] <= p[i] - z[k] + M * (1 - y[i]))
end

# Constraint 3: z_k <= Sum over i of x_ik v_ik for all k
 for k in 1:num_segment_k
    @constraint(model, z[k] <= sum(x[i, k] * v[i, k] for i in 1:num_hotels_i))
end
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-10-20

# %%
# Sort by price
sorted_indices = sortperm(data2[:, :price_usd], rev=true)  # highest price first

# Mark top 5 indices
top5_indices = sorted_indices[1:5]

# Set warm start values (without modifying data2)
for i in 1:num_hotels_i
    if i in top5_indices
        set_start_value(y[i], 1)
    else
        set_start_value(y[i], 0)
    end
end

set_optimizer_attribute(model, "TimeLimit", 180)       # Stop after 180 seconds
set_optimizer_attribute(model, "Presolve", 2)          # Use aggressive presolve
set_optimizer_attribute(model, "Cuts", 2)              # Use aggressive cuts
set_optimizer_attribute(model, "OutputFlag", 1)        # Show Gurobi output

# Optimize the model
optimize!(model)

# Get status of optimization
status = termination_status(model)
raw = raw_status(model)
println("Status = ", raw)

# Print results based on status
println("data2 without knowing customer segment type")
if status == MOI.OPTIMAL || status == MOI.TIME_LIMIT
    println("Objective value (may be optimal or best found): ", objective_value(model))
    println("Selected hotels (y[i] = 1):")
    for i in 1:num_hotels_i
        if value(y[i]) > 0.5
            println("y[$i] = ", value(y[i]))
        end
    end
    println("All other y[i] = 0")
else
    println("No feasible or meaningful solution found. Status: ", status)
end
# Out:
# Set parameter OutputFlag to value 1
# Set parameter Cuts to value 2
# Set parameter TimeLimit to value 180
# Set parameter Presolve to value 2
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) Ultra 7 155H, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 22 logical processors, using up to 22 threads
#
# Optimize a model with 234 rows, 89 columns and 640 nonzeros
# Model fingerprint: 0xcad58b8a
# Variable types: 60 continuous, 29 integer (29 binary)
# Coefficient statistics:
#   Matrix range     [2e-01, 2e+02]
#   Objective range  [5e-01, 5e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 5e+02]
#
# User MIP start produced solution with objective 126.731 (0.00s)
# Loaded user MIP start with objective 126.731
#
# Presolve time: 0.01s
# Presolved: 234 rows, 89 columns, 640 nonzeros
# Variable types: 60 continuous, 29 integer (29 binary)
# Root relaxation presolved: 234 rows, 89 columns, 640 nonzeros
#
#
# Root relaxation: objective 2.510600e+02, 149 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  251.05999    0   29  126.73137  251.05999  98.1%     -    0s
# H    0     0                     130.0184986  251.05999  93.1%     -    0s
# H    0     0                     130.0499389  251.05999  93.0%     -    0s
#      0     0  229.84594    0   29  130.04994  229.84594  76.7%     -    0s
#      0     0  226.95175    0   29  130.04994  226.95175  74.5%     -    0s
#      0     0  220.83678    0   29  130.04994  220.83678  69.8%     -    0s
#      0     0  209.75536    0   28  130.04994  209.75536  61.3%     -    0s
#      0     2  205.82639    0   28  130.04994  205.82639  58.3%     -    0s
# H   42    48                     130.7848810  200.21297  53.1%  20.5    0s
# H 1049   837                     131.0970560  190.11993  45.0%   4.2    1s
# H 1259  1055                     131.2791280  190.11993  44.8%   4.1    1s
#  58013 23057  145.68984   25   15  131.27913  151.20444  15.2%   4.7    5s
#  190973 49164  136.70723   25   15  131.27913  144.66390  10.2%   4.4   10s
#  314897 58938  137.44513   28   12  131.27913  142.07378  8.22%   4.3   15s
#  436633 61330  132.03671   30   10  131.27913  140.12962  6.74%   4.2   20s
#  546735 57998  132.02223   27   13  131.27913  138.79405  5.72%   4.2   25s
#  642959 50635  134.63785   30   10  131.27913  137.79575  4.96%   4.1   30s
#  725377 40887     cutoff   31       131.27913  136.96288  4.33%   4.1   35s
#  795267 30090     cutoff   31       131.27913  136.14102  3.70%   4.1   40s
#  853747 17748  134.76812   27   13  131.27913  135.00512  2.84%   4.1   45s
#  877989  9789  131.97705   29   11  131.27913  133.92412  2.01%   4.1   50s
#
# Cutting planes:
#   Gomory: 73
#   Implied bound: 34
#   Projected implied bound: 3
#   MIR: 28
#   Flow cover: 69
#   RLT: 8
#
# Explored 895128 nodes (3695396 simplex iterations) in 53.30 seconds (14.40 work units)
# Thread count was 22 (of 22 available processors)
#
# Solution count 5: 131.279 131.097 130.05 ... 126.731
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.312791280218e+02, best bound 1.312791280218e+02, gap 0.0000%
#
# User-callback calls 1792532, time in user-callback 0.34 sec
# Status = Model was solved to optimality (subject to tolerances), and an optimal solution is available.
# data2 without knowing customer segment type
# Objective value (may be optimal or best found): 131.2791280217877
# Selected hotels (y[i] = 1):
# y[1] = 1.0
# y[2] = 1.0
# y[7] = 1.0
# y[8] = 1.0
# y[9] = 1.0
# y[10] = 1.0
# y[11] = 1.0
# y[22] = 1.0
# y[24] = 1.0
# y[26] = 1.0
# All other y[i] = 0

# %% [markdown]
# ### data2 - know customer segment type
#
# #### S1

# %%
# Extract the two columns of v representing the two segments
v_1 = v[:, 1]
v_2 = v[:, 2]

#Building the JuMP model
using JuMP, Gurobi, LinearAlgebra

#Initialize the model with a given optimizer, say Gurobi
model = Model(Gurobi.Optimizer)
set_optimizer_attribute(model, "OutputFlag", 0)

# Define the variables
num_hotels_i = nrow(data2)

#create variables
@variable(model, z)
@variable(model, y[1:num_hotels_i], Bin)
@variable(model, x[1:num_hotels_i])

#Set the objective. The arguments are the model object, the objective sense and its expression.
@objective(model, Max, z)

# Set up constraints

# Constraint 1: -M y_i <= x_i <= M y_i for all i
M = 1000
for i in 1:num_hotels_i
    @constraint(model, -M * y[i] <= x[i])
    @constraint(model, x[i] <= M * y[i])
end

# Constraint 2: -M (1-y_i) + p_i - z <= x_i <= p_i - z + M (1 - y_i) for all i
for i in 1:num_hotels_i
    @constraint(model, -M * (1 - y[i]) + p[i] - z <= x[i])
    @constraint(model, x[i] <= p[i] - z + M * (1 - y[i]))
end

# Constraint 3: z <= Sum over i of x_i v_i
@constraint(model, z <= sum(x[i] * v_1[i] for i in 1:num_hotels_i))

#optimize the model
optimize!(model)

#get the status of the optimization
#either
println("Status = ", raw_status(model))

#print the solution: value and variables
println("S1 of data2")
println("Optimal Objective Function value: ", objective_value(model))
println("Optimal Solutions:")
for i in 1:num_hotels_i
    if value(y[i]) == 1
        println("y[$(i)] = ", value(y[i]))
    end
end

println("All other y_i = 0")
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-10-20
# Status = Model was solved to optimality (subject to tolerances), and an optimal solution is available.
# S1 of data2
# Optimal Objective Function value: 126.92370023226118
# Optimal Solutions:
# y[1] = 1.0
# y[2] = 1.0
# y[7] = 1.0
# y[8] = 1.0
# y[9] = 1.0
# y[10] = 1.0
# y[11] = 1.0
# y[22] = 1.0
# y[24] = 1.0
# y[26] = 1.0
# All other y_i = 0

# %% [markdown]
# #### S2

# %%
#Building the JuMP model
using JuMP, Gurobi, LinearAlgebra

#Initialize the model with a given optimizer, say Gurobi
model = Model(Gurobi.Optimizer)
set_optimizer_attribute(model, "OutputFlag", 0)

# Define the variables
num_hotels_i = nrow(data2)

#create variables
@variable(model, z)
@variable(model, y[1:num_hotels_i], Bin)
@variable(model, x[1:num_hotels_i])

#Set the objective. The arguments are the model object, the objective sense and its expression.
@objective(model, Max, z)

# Set up constraints

# Constraint 1: -M y_i <= x_i <= M y_i for all i
M = 1000
for i in 1:num_hotels_i
    @constraint(model, -M * y[i] <= x[i])
    @constraint(model, x[i] <= M * y[i])
end

# Constraint 2: -M (1-y_i) + p_i - z <= x_i <= p_i - z + M (1 - y_i) for all i
for i in 1:num_hotels_i
    @constraint(model, -M * (1 - y[i]) + p[i] - z <= x[i])
    @constraint(model, x[i] <= p[i] - z + M * (1 - y[i]))
end

# Constraint 3: z <= Sum over i of x_i v_i
@constraint(model, z <= sum(x[i] * v_2[i] for i in 1:num_hotels_i))

#optimize the model
optimize!(model)

#get the status of the optimization
#either
println("Status = ", raw_status(model))

#print the solution: value and variables
println("S2 of data2")
println("Optimal Objective Function value: ", objective_value(model))
println("Optimal Solutions:")
for i in 1:num_hotels_i
    if value(y[i]) == 1
        println("y[$(i)] = ", value(y[i]))
    end
end

println("All other y_i = 0")
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-10-20
# Status = Model was solved to optimality (subject to tolerances), and an optimal solution is available.
# S2 of data2
# Optimal Objective Function value: 137.37465667244123
# Optimal Solutions:
# y[1] = 1.0
# y[2] = 1.0
# y[7] = 1.0
# y[8] = 1.0
# y[9] = 1.0
# y[11] = 1.0
# y[22] = 1.0
# All other y_i = 0

# %% [markdown]
# ## data3

# %%
# Cleaning up data3
using DataFrames, LinearAlgebra

# Step 1: Model parameters
intercepts = [-1.9180, -1.5397]  # β₀ for Segment 1 and Segment 2

# β₁ to β₈ for each segment (rows = segments, columns = features)
betas = [
    0.379038   0.124630   0.092098  -0.021459   0.057844  -0.094884  -1.071555  0.134802;   # Segment 1
    0.462759   0.095586   0.112906   0.087280   0.025559  -0.031981  -1.696923  0.194143    # Segment 2
]

# Step 2: Extract features from your DataFrame
features = Matrix(data3)

# Step 3: Compute v[i, k] = exp(β₀ₖ + sum_j βⱼₖ xⱼᵢ)
n = size(features, 1)
K = size(betas, 1)
v = Array{Float64}(undef, n, K)

for k in 1:K
    for i in 1:n
        utility = intercepts[k] + dot(betas[k, :], features[i, :])
        v[i, k] = exp(utility)
    end
end

# Price matrix
p = data3_original[:, :price_usd];

# %% [markdown]
# ### data3 - do not know customer segment type

# %%
#Building the JuMP model
using JuMP, Gurobi, LinearAlgebra

#Initialize the model with a given optimizer, say Gurobi
model = Model(Gurobi.Optimizer)
set_optimizer_attribute(model, "OutputFlag", 0)

# Define the variables
num_segment_k = 2
num_hotels_i = nrow(data3)

#create variables
@variable(model, z[1:num_segment_k] >= 0)
@variable(model, y[1:num_hotels_i], Bin)
@variable(model, x[1:num_hotels_i, 1:num_segment_k])

#Set the objective. The arguments are the model object, the objective sense and its expression.
@objective(model, Max, sum(thetas[k] * z[k] for k in 1:num_segment_k))

# Set up constraints

# Constraint 1: -M y_i <= x_ik <= M y_i for all i, k
M = maximum(p) + 10
for i in 1:num_hotels_i, k in 1:num_segment_k
    @constraint(model, -M * y[i] <= x[i, k])
    @constraint(model, x[i, k] <= M * y[i])
end

# Constraint 2: -M (1-y_i) + p_i - z_k <= x_ik <= p_i - z_k + M (1 - y_i) for all i, k
for i in 1:num_hotels_i, k in 1:num_segment_k
    @constraint(model, -M * (1 - y[i]) + p[i] - z[k] <= x[i, k])
    @constraint(model, x[i, k] <= p[i] - z[k] + M * (1 - y[i]))
end

# Constraint 3: z_k <= Sum over i of x_ik v_ik for all k
 for k in 1:num_segment_k
    @constraint(model, z[k] <= sum(x[i, k] * v[i, k] for i in 1:num_hotels_i))
end
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-10-20

# %%
# Sort by price
sorted_indices = sortperm(data3[:, :price_usd], rev=true)  # highest price first

# Mark top 5 indices
top5_indices = sorted_indices[1:5]

# Set warm start values (without modifying data2)
for i in 1:num_hotels_i
    if i in top5_indices
        set_start_value(y[i], 1)
    else
        set_start_value(y[i], 0)
    end
end

set_optimizer_attribute(model, "TimeLimit", 180)       # Stop after 180 seconds
set_optimizer_attribute(model, "Presolve", 2)          # Use aggressive presolve
set_optimizer_attribute(model, "Cuts", 2)              # Use aggressive cuts
set_optimizer_attribute(model, "OutputFlag", 1)        # Show Gurobi output

# Optimize the model
optimize!(model)

# Get status of optimization
status = termination_status(model)
raw = raw_status(model)
println("Status = ", raw)

# Print results based on status
println("data3 without knowing customer segment type")
if status == MOI.OPTIMAL || status == MOI.TIME_LIMIT
    println("Objective value (may be optimal or best found): ", objective_value(model))
    println("Selected hotels (y[i] = 1):")
    for i in 1:num_hotels_i
        if value(y[i]) > 0.5
            println("y[$i] = ", value(y[i]))
        end
    end
    println("All other y[i] = 0")
else
    println("No feasible or meaningful solution found. Status: ", status)
end
# Out:
# Set parameter OutputFlag to value 1
# Set parameter Cuts to value 2
# Set parameter TimeLimit to value 180
# Set parameter Presolve to value 2
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) Ultra 7 155H, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 22 logical processors, using up to 22 threads
#
# Optimize a model with 210 rows, 80 columns and 574 nonzeros
# Model fingerprint: 0x972b7235
# Variable types: 54 continuous, 26 integer (26 binary)
# Coefficient statistics:
#   Matrix range     [2e-03, 6e+02]
#   Objective range  [5e-01, 5e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 1e+03]
#
# User MIP start produced solution with objective 77.1069 (0.00s)
# Loaded user MIP start with objective 77.1069
#
# Presolve removed 1 rows and 0 columns
# Presolve time: 0.02s
# Presolved: 209 rows, 80 columns, 572 nonzeros
# Variable types: 54 continuous, 26 integer (26 binary)
# Root relaxation presolved: 209 rows, 80 columns, 572 nonzeros
#
#
# Root relaxation: objective 3.002863e+02, 90 iterations, 0.02 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  300.28632    0   25   77.10687  300.28632   289%     -    0s
# H    0     0                      79.4630567  300.28632   278%     -    0s
# H    0     0                      80.1698359  300.28632   275%     -    0s
# H    0     0                      81.9918975  300.28632   266%     -    0s
# H    0     0                     115.3466733  300.28632   160%     -    0s
# H    0     0                     118.0722160  243.56470   106%     -    0s
#      0     0  229.72509    0   25  118.07222  229.72509  94.6%     -    0s
#      0     0  229.15381    0   25  118.07222  229.15381  94.1%     -    0s
# H    0     0                     118.2743037  229.15381  93.7%     -    0s
#      0     0  221.46408    0   24  118.27430  221.46408  87.2%     -    0s
# H    0     0                     118.2805694  216.13069  82.7%     -    0s
# H    0     0                     118.5700553  216.13069  82.3%     -    0s
#      0     0  208.75836    0   25  118.57006  208.75836  76.1%     -    0s
#      0     0  208.75836    0   25  118.57006  208.75836  76.1%     -    0s
#      0     0  208.75836    0   25  118.57006  208.75836  76.1%     -    0s
#      0     0  208.75836    0   25  118.57006  208.75836  76.1%     -    0s
# H    0     0                     119.0564333  208.75836  75.3%     -    0s
#      0     0  203.05872    0   25  119.05643  203.05872  70.6%     -    0s
# H    0     0                     119.5830279  203.05872  69.8%     -    0s
# H    0     2                     119.6278959  203.05872  69.7%     -    0s
#      0     2  203.05872    0   25  119.62790  203.05872  69.7%     -    0s
# * 2375  1489              25     119.8695843  162.53784  35.6%   3.7    1s
# H 3409  1654                     120.5171108  159.32562  32.2%   3.4    1s
# H 3518  1666                     120.9574140  149.21092  23.4%   3.8    2s
# H 4667  1837                     120.9982453  144.29696  19.3%   3.8    2s
#   6112  1985  127.11567   25   13  120.99825  138.08026  14.1%   3.7    5s
#  52760  7756  124.77714   25   13  120.99825  127.30242  5.21%   3.1   10s
#
# Cutting planes:
#   Gomory: 66
#   Implied bound: 5
#   Projected implied bound: 3
#   MIR: 16
#   Flow cover: 39
#   RLT: 16
#   Relax-and-lift: 1
#
# Explored 105579 nodes (334476 simplex iterations) in 13.49 seconds (3.07 work units)
# Thread count was 22 (of 22 available processors)
#
# Solution count 10: 120.998 120.957 119.87 ... 81.9919
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.209982452711e+02, best bound 1.209982452711e+02, gap 0.0000%
#
# User-callback calls 213437, time in user-callback 0.06 sec
# Status = Model was solved to optimality (subject to tolerances), and an optimal solution is available.
# data3 without knowing customer segment type
# Objective value (may be optimal or best found): 120.99824527110692
# Selected hotels (y[i] = 1):
# y[1] = 1.0
# y[2] = 1.0
# y[3] = 1.0
# y[4] = 1.0
# y[5] = 1.0
# y[6] = 1.0
# y[8] = 1.0
# y[9] = 1.0
# y[11] = 1.0
# y[12] = 1.0
# y[14] = 1.0
# y[15] = 1.0
# y[16] = 1.0
# y[17] = 1.0
# y[19] = 1.0
# y[20] = 1.0
# y[24] = 1.0
# y[25] = 1.0
# All other y[i] = 0

# %% [markdown]
# ### data3 - know customer segment type
#
# #### S1

# %%
# Extract the two columns of v representing the two segments
v_1 = v[:, 1]
v_2 = v[:, 2]

#Building the JuMP model
using JuMP, Gurobi, LinearAlgebra

#Initialize the model with a given optimizer, say Gurobi
model = Model(Gurobi.Optimizer)
set_optimizer_attribute(model, "OutputFlag", 0)

# Define the variables
num_hotels_i = nrow(data3)

#create variables
@variable(model, z)
@variable(model, y[1:num_hotels_i], Bin)
@variable(model, x[1:num_hotels_i])

#Set the objective. The arguments are the model object, the objective sense and its expression.
@objective(model, Max, z)

# Set up constraints

# Constraint 1: -M y_i <= x_i <= M y_i for all i
M = 1000
for i in 1:num_hotels_i
    @constraint(model, -M * y[i] <= x[i])
    @constraint(model, x[i] <= M * y[i])
end

# Constraint 2: -M (1-y_i) + p_i - z <= x_i <= p_i - z + M (1 - y_i) for all i
for i in 1:num_hotels_i
    @constraint(model, -M * (1 - y[i]) + p[i] - z <= x[i])
    @constraint(model, x[i] <= p[i] - z + M * (1 - y[i]))
end

# Constraint 3: z <= Sum over i of x_i v_i
@constraint(model, z <= sum(x[i] * v_1[i] for i in 1:num_hotels_i))

#optimize the model
optimize!(model)

#get the status of the optimization
#either
println("Status = ", raw_status(model))

#print the solution: value and variables
println("S1 of data3")
println("Optimal Objective Function value: ", objective_value(model))
println("Optimal Solutions:")
for i in 1:num_hotels_i
    if value(y[i]) == 1
        println("y[$(i)] = ", value(y[i]))
    end
end

println("All other y_i = 0")
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-10-20
# Status = Model was solved to optimality (subject to tolerances), and an optimal solution is available.
# S1 of data3
# Optimal Objective Function value: 117.52114848843323
# Optimal Solutions:
# y[1] = 1.0
# y[2] = 1.0
# y[3] = 1.0
# y[4] = 1.0
# y[5] = 1.0
# y[6] = 1.0
# y[8] = 1.0
# y[9] = 1.0
# y[11] = 1.0
# y[12] = 1.0
# y[14] = 1.0
# y[15] = 1.0
# y[16] = 1.0
# y[17] = 1.0
# y[19] = 1.0
# y[20] = 1.0
# y[24] = 1.0
# y[25] = 1.0
# y[26] = 1.0
# All other y_i = 0

# %% [markdown]
# #### S2

# %%
#Building the JuMP model
using JuMP, Gurobi, LinearAlgebra

#Initialize the model with a given optimizer, say Gurobi
model = Model(Gurobi.Optimizer)
set_optimizer_attribute(model, "OutputFlag", 0)

# Define the variables
num_hotels_i = nrow(data3)

#create variables
@variable(model, z)
@variable(model, y[1:num_hotels_i], Bin)
@variable(model, x[1:num_hotels_i])

#Set the objective. The arguments are the model object, the objective sense and its expression.
@objective(model, Max, z)

# Set up constraints

# Constraint 1: -M y_i <= x_i <= M y_i for all i
M = 1000
for i in 1:num_hotels_i
    @constraint(model, -M * y[i] <= x[i])
    @constraint(model, x[i] <= M * y[i])
end

# Constraint 2: -M (1-y_i) + p_i - z <= x_i <= p_i - z + M (1 - y_i) for all i
for i in 1:num_hotels_i
    @constraint(model, -M * (1 - y[i]) + p[i] - z <= x[i])
    @constraint(model, x[i] <= p[i] - z + M * (1 - y[i]))
end

# Constraint 3: z <= Sum over i of x_i v_i
@constraint(model, z <= sum(x[i] * v_2[i] for i in 1:num_hotels_i))

#optimize the model
optimize!(model)

#get the status of the optimization
#either
println("Status = ", raw_status(model))

#print the solution: value and variables
println("S2 of data3")
println("Optimal Objective Function value: ", objective_value(model))
println("Optimal Solutions:")
for i in 1:num_hotels_i
    if value(y[i]) == 1
        println("y[$(i)] = ", value(y[i]))
    end
end

println("All other y_i = 0")
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-10-20
# Status = Model was solved to optimality (subject to tolerances), and an optimal solution is available.
# S2 of data3
# Optimal Objective Function value: 125.34894655852843
# Optimal Solutions:
# y[1] = 1.0
# y[2] = 1.0
# y[3] = 1.0
# y[4] = 1.0
# y[5] = 1.0
# y[6] = 1.0
# y[8] = 1.0
# y[9] = 1.0
# y[11] = 1.0
# y[12] = 1.0
# y[14] = 1.0
# y[15] = 1.0
# y[16] = 1.0
# y[17] = 1.0
# y[20] = 1.0
# y[24] = 1.0
# y[25] = 1.0
# All other y_i = 0

# %% [markdown]
# ## data4

# %%
# Cleaning up data4
using DataFrames, LinearAlgebra

# Step 1: Model parameters
intercepts = [-1.9180, -1.5397]  # β₀ for Segment 1 and Segment 2

# β₁ to β₈ for each segment (rows = segments, columns = features)
betas = [
    0.379038   0.124630   0.092098  -0.021459   0.057844  -0.094884  -1.071555  0.134802;   # Segment 1
    0.462759   0.095586   0.112906   0.087280   0.025559  -0.031981  -1.696923  0.194143    # Segment 2
]

# Step 2: Extract features from your DataFrame
features = Matrix(data4)

# Step 3: Compute v[i, k] = exp(β₀ₖ + sum_j βⱼₖ xⱼᵢ)
n = size(features, 1)
K = size(betas, 1)
v = Array{Float64}(undef, n, K)

for k in 1:K
    for i in 1:n
        utility = intercepts[k] + dot(betas[k, :], features[i, :])
        v[i, k] = exp(utility)
    end
end

# Price matrix
p = data4_original[:, :price_usd];

# %% [markdown]
# ### data4 - do not know customer segment type

# %%
#Building the JuMP model
using JuMP, Gurobi, LinearAlgebra

#Initialize the model with a given optimizer, say Gurobi
model = Model(Gurobi.Optimizer)
set_optimizer_attribute(model, "OutputFlag", 0)

# Define the variables
num_segment_k = 2
num_hotels_i = nrow(data4)

#create variables
@variable(model, z[1:num_segment_k] >= 0)
@variable(model, y[1:num_hotels_i], Bin)
@variable(model, x[1:num_hotels_i, 1:num_segment_k])

#Set the objective. The arguments are the model object, the objective sense and its expression.
@objective(model, Max, sum(thetas[k] * z[k] for k in 1:num_segment_k))

# Set up constraints

# Constraint 1: -M y_i <= x_ik <= M y_i for all i, k
M = maximum(p) + 10
for i in 1:num_hotels_i, k in 1:num_segment_k
    @constraint(model, -M * y[i] <= x[i, k])
    @constraint(model, x[i, k] <= M * y[i])
end

# Constraint 2: -M (1-y_i) + p_i - z_k <= x_ik <= p_i - z_k + M (1 - y_i) for all i, k
for i in 1:num_hotels_i, k in 1:num_segment_k
    @constraint(model, -M * (1 - y[i]) + p[i] - z[k] <= x[i, k])
    @constraint(model, x[i, k] <= p[i] - z[k] + M * (1 - y[i]))
end

# Constraint 3: z_k <= Sum over i of x_ik v_ik for all k
 for k in 1:num_segment_k
    @constraint(model, z[k] <= sum(x[i, k] * v[i, k] for i in 1:num_hotels_i))
end
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-10-20

# %%
# Sort by price
sorted_indices = sortperm(data4[:, :price_usd], rev=true)  # highest price first

# Mark top 5 indices
top5_indices = sorted_indices[1:5]

# Set warm start values (without modifying data2)
for i in 1:num_hotels_i
    if i in top5_indices
        set_start_value(y[i], 1)
    else
        set_start_value(y[i], 0)
    end
end

set_optimizer_attribute(model, "TimeLimit", 180)       # Stop after 180 seconds
set_optimizer_attribute(model, "Presolve", 2)          # Use aggressive presolve
set_optimizer_attribute(model, "Cuts", 2)              # Use aggressive cuts
set_optimizer_attribute(model, "OutputFlag", 1)        # Show Gurobi output

# Optimize the model
optimize!(model)

# Get status of optimization
status = termination_status(model)
raw = raw_status(model)
println("Status = ", raw)

# Print results based on status
println("data3 without knowing customer segment type")
if status == MOI.OPTIMAL || status == MOI.TIME_LIMIT
    println("Objective value (may be optimal or best found): ", objective_value(model))
    println("Selected hotels (y[i] = 1):")
    for i in 1:num_hotels_i
        if value(y[i]) > 0.5
            println("y[$i] = ", value(y[i]))
        end
    end
    println("All other y[i] = 0")
else
    println("No feasible or meaningful solution found. Status: ", status)
end
# Out:
# Set parameter OutputFlag to value 1
# Set parameter Cuts to value 2
# Set parameter TimeLimit to value 180
# Set parameter Presolve to value 2
# Gurobi Optimizer version 11.0.2 build v11.0.2rc0 (win64 - Windows 11+.0 (26100.2))
#
# CPU model: Intel(R) Core(TM) Ultra 7 155H, instruction set [SSE2|AVX|AVX2]
# Thread count: 16 physical cores, 22 logical processors, using up to 22 threads
#
# Optimize a model with 218 rows, 83 columns and 596 nonzeros
# Model fingerprint: 0x0a5541f9
# Variable types: 56 continuous, 27 integer (27 binary)
# Coefficient statistics:
#   Matrix range     [2e-01, 2e+02]
#   Objective range  [5e-01, 5e-01]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+01, 4e+02]
#
# User MIP start produced solution with objective 92.7774 (0.00s)
# Loaded user MIP start with objective 92.7774
#
# Presolve time: 0.00s
# Presolved: 218 rows, 83 columns, 596 nonzeros
# Variable types: 56 continuous, 27 integer (27 binary)
# Root relaxation presolved: 218 rows, 83 columns, 596 nonzeros
#
#
# Root relaxation: objective 1.882393e+02, 131 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0  188.23928    0   27   92.77735  188.23928   103%     -    0s
# H    0     0                      93.0311097  178.63412  92.0%     -    0s
#      0     0  168.71472    0   27   93.03111  168.71472  81.4%     -    0s
# H    0     0                      93.8185951  166.65701  77.6%     -    0s
# H    0     0                      94.0665128  162.55950  72.8%     -    0s
#      0     2  150.86614    0   27   94.06651  150.86614  60.4%     -    0s
# H   80    96                      94.3775511  150.86614  59.9%   5.1    0s
# H   81    96                      94.7035737  150.86614  59.3%   5.0    0s
# H   85    96                      94.9467550  150.86614  58.9%   5.0    0s
# H   94    96                      95.1649283  150.86614  58.5%   4.9    0s
# H  961   777                      95.9312661  144.83300  51.0%   2.9    0s
# * 1005   777              27      96.4428171  144.83300  50.2%   2.9    0s
# H 1360  1021                      96.9412201  140.21694  44.6%   3.0    0s
# H 1397  1018                      97.2079115  138.73040  42.7%   2.9    0s
# H 2831  1963                      97.3828063  133.77812  37.4%   2.7    1s
#  87524 23105  104.72529   30   11   97.38281  109.76202  12.7%   3.3    5s
#  191009 21958   98.10152   33    8   97.38281  105.35911  8.19%   3.5   10s
#  276371  5829   98.88545   28   13   97.38281  101.39784  4.12%   3.7   15s
#
# Cutting planes:
#   Gomory: 64
#   Implied bound: 6
#   Flow cover: 5
#   RLT: 20
#
# Explored 290762 nodes (1096578 simplex iterations) in 16.88 seconds (4.07 work units)
# Thread count was 22 (of 22 available processors)
#
# Solution count 9: 97.3828 96.9412 96.4428 ... 92.7774
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 9.738280634350e+01, best bound 9.738280634350e+01, gap 0.0000%
#
# User-callback calls 582848, time in user-callback 0.11 sec
# Status = Model was solved to optimality (subject to tolerances), and an optimal solution is available.
# data3 without knowing customer segment type
# Objective value (may be optimal or best found): 97.38280634349921
# Selected hotels (y[i] = 1):
# y[4] = 1.0
# y[5] = 1.0
# y[7] = 1.0
# y[9] = 1.0
# y[11] = 1.0
# y[16] = 1.0
# y[19] = 1.0
# y[20] = 1.0
# y[21] = 1.0
# y[22] = 1.0
# y[27] = 1.0
# All other y[i] = 0

# %% [markdown]
# ### data4 - know customer segment type
#
# #### S1

# %%
# Extract the two columns of v representing the two segments
v_1 = v[:, 1]
v_2 = v[:, 2]

#Building the JuMP model
using JuMP, Gurobi, LinearAlgebra

#Initialize the model with a given optimizer, say Gurobi
model = Model(Gurobi.Optimizer)
set_optimizer_attribute(model, "OutputFlag", 0)

# Define the variables
num_hotels_i = nrow(data4)

#create variables
@variable(model, z)
@variable(model, y[1:num_hotels_i], Bin)
@variable(model, x[1:num_hotels_i])

#Set the objective. The arguments are the model object, the objective sense and its expression.
@objective(model, Max, z)

# Set up constraints

# Constraint 1: -M y_i <= x_i <= M y_i for all i
M = 1000
for i in 1:num_hotels_i
    @constraint(model, -M * y[i] <= x[i])
    @constraint(model, x[i] <= M * y[i])
end

# Constraint 2: -M (1-y_i) + p_i - z <= x_i <= p_i - z + M (1 - y_i) for all i
for i in 1:num_hotels_i
    @constraint(model, -M * (1 - y[i]) + p[i] - z <= x[i])
    @constraint(model, x[i] <= p[i] - z + M * (1 - y[i]))
end

# Constraint 3: z <= Sum over i of x_i v_i
@constraint(model, z <= sum(x[i] * v_1[i] for i in 1:num_hotels_i))

#optimize the model
optimize!(model)

#get the status of the optimization
#either
println("Status = ", raw_status(model))

#print the solution: value and variables
println("S1 of data4")
println("Optimal Objective Function value: ", objective_value(model))
println("Optimal Solutions:")
for i in 1:num_hotels_i
    if value(y[i]) == 1
        println("y[$(i)] = ", value(y[i]))
    end
end

println("All other y_i = 0")
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-10-20
# Status = Model was solved to optimality (subject to tolerances), and an optimal solution is available.
# S1 of data4
# Optimal Objective Function value: 94.69566705306295
# Optimal Solutions:
# y[4] = 1.0
# y[5] = 1.0
# y[7] = 1.0
# y[9] = 1.0
# y[11] = 1.0
# y[16] = 1.0
# y[19] = 1.0
# y[20] = 1.0
# y[21] = 1.0
# y[22] = 1.0
# y[27] = 1.0
# All other y_i = 0

# %% [markdown]
# #### S2

# %%
#Building the JuMP model
using JuMP, Gurobi, LinearAlgebra

#Initialize the model with a given optimizer, say Gurobi
model = Model(Gurobi.Optimizer)
set_optimizer_attribute(model, "OutputFlag", 0)

# Define the variables
num_hotels_i = nrow(data4)

#create variables
@variable(model, z)
@variable(model, y[1:num_hotels_i], Bin)
@variable(model, x[1:num_hotels_i])

#Set the objective. The arguments are the model object, the objective sense and its expression.
@objective(model, Max, z)

# Set up constraints

# Constraint 1: -M y_i <= x_i <= M y_i for all i
M = 1000
for i in 1:num_hotels_i
    @constraint(model, -M * y[i] <= x[i])
    @constraint(model, x[i] <= M * y[i])
end

# Constraint 2: -M (1-y_i) + p_i - z <= x_i <= p_i - z + M (1 - y_i) for all i
for i in 1:num_hotels_i
    @constraint(model, -M * (1 - y[i]) + p[i] - z <= x[i])
    @constraint(model, x[i] <= p[i] - z + M * (1 - y[i]))
end

# Constraint 3: z <= Sum over i of x_i v_i
@constraint(model, z <= sum(x[i] * v_2[i] for i in 1:num_hotels_i))

#optimize the model
optimize!(model)

#get the status of the optimization
#either
println("Status = ", raw_status(model))

#print the solution: value and variables
println("S2 of data4")
println("Optimal Objective Function value: ", objective_value(model))
println("Optimal Solutions:")
for i in 1:num_hotels_i
    if value(y[i]) == 1
        println("y[$(i)] = ", value(y[i]))
    end
end

println("All other y_i = 0")
# Out:
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-10-20
# Status = Model was solved to optimality (subject to tolerances), and an optimal solution is available.
# S2 of data4
# Optimal Objective Function value: 100.63909615263897
# Optimal Solutions:
# y[4] = 1.0
# y[5] = 1.0
# y[7] = 1.0
# y[11] = 1.0
# y[16] = 1.0
# y[19] = 1.0
# y[20] = 1.0
# y[21] = 1.0
# y[22] = 1.0
# y[27] = 1.0
# All other y_i = 0
