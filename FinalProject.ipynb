# %% [markdown]
# ## Problem 1

# %%
import pandas as pd
import numpy as np
from scipy import optimize
import matplotlib.pyplot as plt

# Read the data
# data = pd.read_csv('/Users/helmadevina/Desktop/Pricing-Analytics-and-Revenue-Management/data.csv')
data = pd.read_csv("data.csv")
print(f"Data loaded, shape: {data.shape}")

# Group by search_id
search_groups = data.groupby('srch_id')

# Features to use in the MNL model
features = [
    'prop_starrating',
    'prop_review_score',
    'prop_brand_bool',
    'prop_location_score',
    'prop_accesibility_score',
    'prop_log_historical_price',
    'price_usd',
    'promotion_flag'
]

# Function to calculate MNL log-likelihood
def mnl_log_likelihood(beta, data, search_groups, features):
    # Initialize log-likelihood
    log_likelihood = 0
    
    # Extract beta values
    beta0 = beta[0]  # intercept
    beta_features = beta[1:].copy()  # coefficients for features
    
    # Get price index to use for scaling
    price_index = features.index('price_usd')
    
    # Loop through each search session
    for search_id, group in search_groups:
        # Get the hotels in this search
        hotels = group.copy()
        
        # Scale price for numerical stability (but don't modify the beta)
        X = hotels[features].copy()
        X['price_usd'] = X['price_usd'] / 100.0  # Scale price to prevent overflow
        
        # Calculate utilities
        utilities = beta0 + X.dot(beta_features)
        hotels['utility'] = utilities
        
        # Calculate exp(utility) with numerical stability
        max_utility = utilities.max()
        hotels['exp_utility'] = np.exp(utilities - max_utility)
        
        # Calculate denominator (sum of exp(utility) + no-purchase option)
        denominator = hotels['exp_utility'].sum() + np.exp(-max_utility)  # no-purchase has utility 0
        
        # If there was a booking
        if (hotels['booking_bool'] == 1).any():
            # Get the booked hotel
            booked_hotel = hotels[hotels['booking_bool'] == 1].iloc[0]
            
            # Add to log-likelihood: log(P(j|S))
            log_likelihood += (booked_hotel['utility'] - max_utility) - np.log(denominator)
        else:
            # No booking - customer chose outside option
            log_likelihood += (-max_utility) - np.log(denominator)
    
    return -log_likelihood  # Negative because we're minimizing

# Function to fit MNL model
def fit_mnl_model(data, search_groups, features):
    # Initial beta values (all zeros)
    initial_beta = np.zeros(len(features) + 1)  # +1 for intercept
    
    # Define the objective function for optimization
    def objective(beta):
        return mnl_log_likelihood(beta, data, search_groups, features)
    
    # Optimize using L-BFGS-B algorithm
    print("Starting optimization...")
    result = optimize.minimize(
        objective,
        initial_beta,
        method='L-BFGS-B',
        options={'disp': True, 'maxiter': 100}
    )
    
    print(f"Optimization completed: {result.success}")
    print(f"Final negative log-likelihood: {result.fun}")
    
    # Extract optimal beta values
    beta_opt = result.x
    
    return beta_opt

# Fit the MNL model
beta_opt = fit_mnl_model(data, search_groups, features)

# Print results
print("\nMNL Model Parameters:")
print(f"Intercept (β₀): {beta_opt[0]:.4f}")

feature_descriptions = {
    'prop_starrating': 'Star Rating (higher = better hotel quality)',
    'prop_review_score': 'Review Score (higher = better guest reviews)',
    'prop_brand_bool': 'Brand Flag (1 = branded hotel, 0 = independent)',
    'prop_location_score': 'Location Score (higher = better location)',
    'prop_accesibility_score': 'Accessibility Score (higher = better accessibility)',
    'prop_log_historical_price': 'Log Historical Price',
    'price_usd': 'Price in USD (per $1)',
    'promotion_flag': 'Promotion Flag (1 = has promotion, 0 = no promotion)'
}

for i, feature in enumerate(features):
    if feature == 'price_usd':
        # For price_usd, we need to adjust the interpretation because we scaled during calculation
        # The current coefficient is "per $100" because we divided price by 100 in calculations
        # To get "per $1", we divide by 100
        per_dollar_coef = beta_opt[i+1] / 100.0
        print(f"{feature_descriptions.get(feature, feature)} (β{i+1}): {per_dollar_coef:.6f}")
    else:
        print(f"{feature_descriptions.get(feature, feature)} (β{i+1}): {beta_opt[i+1]:.6f}")
# Out:
# Data loaded, shape: (153009, 15)
# Starting optimization...
# Optimization completed: True
# Final negative log-likelihood: 20611.325976062617
#
# MNL Model Parameters:
# Intercept (β₀): -2.8155
# Star Rating (higher = better hotel quality) (β1): 0.476158
# Review Score (higher = better guest reviews) (β2): 0.119901
# Brand Flag (1 = branded hotel, 0 = independent) (β3): 0.229825
# Location Score (higher = better location) (β4): 0.016356
# Accessibility Score (higher = better accessibility) (β5): 0.562822
# Log Historical Price (β6): -0.037346
# Price in USD (per $1) (β7): -0.007323
# Promotion Flag (1 = has promotion, 0 = no promotion) (β8): 0.454005

# %% [markdown]
# ## Problem 1 After implementing the normalization

# %%
import pandas as pd
import numpy as np
from scipy import optimize
import matplotlib.pyplot as plt

# Read the data
data = pd.read_csv("data.csv")
print(f"Data loaded, shape: {data.shape}")

# Group by search_id
search_groups = data.groupby('srch_id')

# Features to use in the MNL model
features = [
    'prop_starrating',
    'prop_review_score',
    'prop_brand_bool',
    'prop_location_score',
    'prop_accesibility_score',
    'prop_log_historical_price',
    'price_usd',
    'promotion_flag'
]

# Normalize features (as recommended by the professor)
# Save original data for later reference
data_original = data.copy()

# Store normalization parameters for later interpretation
normalization_params = {}
for feature in features:
    if feature not in ['prop_brand_bool', 'promotion_flag']:  # Skip binary features
        mean = data[feature].mean()
        std = data[feature].std()
        data[feature] = (data[feature] - mean) / std
        normalization_params[feature] = {'mean': mean, 'std': std}
        print(f"Normalized {feature}: mean={mean:.4f}, std={std:.4f}")

# Function to calculate MNL log-likelihood
def mnl_log_likelihood(beta, data, search_groups, features):
    # Initialize log-likelihood
    log_likelihood = 0
    
    # Extract beta values
    beta0 = beta[0]  # intercept
    beta_features = beta[1:]  # coefficients for features
    
    # Loop through each search session
    for search_id, group in search_groups:
        # Get the hotels in this search
        hotels = group.copy()
        
        # Calculate utilities
        X = hotels[features]
        utilities = beta0 + X.dot(beta_features)
        hotels['utility'] = utilities
        
        # Calculate exp(utility) with numerical stability
        max_utility = utilities.max()
        hotels['exp_utility'] = np.exp(utilities - max_utility)
        
        # Calculate denominator (sum of exp(utility) + no-purchase option)
        denominator = hotels['exp_utility'].sum() + np.exp(-max_utility)  # no-purchase has utility 0
        
        # If there was a booking
        if (hotels['booking_bool'] == 1).any():
            # Get the booked hotel
            booked_hotel = hotels[hotels['booking_bool'] == 1].iloc[0]
            
            # Add to log-likelihood: log(P(j|S))
            log_likelihood += (booked_hotel['utility'] - max_utility) - np.log(denominator)
        else:
            # No booking - customer chose outside option
            log_likelihood += (-max_utility) - np.log(denominator)
    
    return -log_likelihood  # Negative because we're minimizing

# Function to fit MNL model
def fit_mnl_model(data, search_groups, features):
    # Initial beta values (all zeros)
    initial_beta = np.zeros(len(features) + 1)  # +1 for intercept
    
    # Define the objective function for optimization
    def objective(beta):
        return mnl_log_likelihood(beta, data, search_groups, features)
    
    # Optimize using L-BFGS-B algorithm
    print("Starting optimization...")
    result = optimize.minimize(
        objective,
        initial_beta,
        method='L-BFGS-B',
        options={'disp': True, 'maxiter': 100}
    )
    
    print(f"Optimization completed: {result.success}")
    print(f"Final negative log-likelihood: {result.fun}")
    
    # Extract optimal beta values
    beta_opt = result.x
    
    return beta_opt

# Fit the MNL model with normalized features
beta_opt = fit_mnl_model(data, search_groups, features)

# Print results with proper interpretation accounting for normalization
print("\nMNL Model Parameters (with normalized features):")
print(f"Intercept (β₀): {beta_opt[0]:.4f}")

feature_descriptions = {
    'prop_starrating': 'Star Rating (higher = better hotel quality)',
    'prop_review_score': 'Review Score (higher = better guest reviews)',
    'prop_brand_bool': 'Brand Flag (1 = branded hotel, 0 = independent)',
    'prop_location_score': 'Location Score (higher = better location)',
    'prop_accesibility_score': 'Accessibility Score (higher = better accessibility)',
    'prop_log_historical_price': 'Log Historical Price',
    'price_usd': 'Price in USD',
    'promotion_flag': 'Promotion Flag (1 = has promotion, 0 = no promotion)'
}

for i, feature in enumerate(features):
    coef = beta_opt[i+1]
    print(f"{feature_descriptions.get(feature, feature)} (β{i+1}): {coef:.6f}")
# Out:
# Data loaded, shape: (153009, 15)
# Normalized prop_starrating: mean=3.1574, std=0.8572
# Normalized prop_review_score: mean=3.9877, std=0.9071
# Normalized prop_location_score: mean=2.6172, std=1.3482
# Normalized prop_accesibility_score: mean=0.0060, std=0.0772
# Normalized prop_log_historical_price: mean=4.2763, std=1.7895
# Normalized price_usd: mean=141.1936, std=181.7699
# Starting optimization...
# Optimization completed: True
# Final negative log-likelihood: 20611.325970146525
#
# MNL Model Parameters (with normalized features):
# Intercept (β₀): -1.9816
# Star Rating (higher = better hotel quality) (β1): 0.408115
# Review Score (higher = better guest reviews) (β2): 0.108778
# Brand Flag (1 = branded hotel, 0 = independent) (β3): 0.229940
# Location Score (higher = better location) (β4): 0.022032
# Accessibility Score (higher = better accessibility) (β5): 0.043432
# Log Historical Price (β6): -0.066898
# Price in USD (β7): -1.331067
# Promotion Flag (1 = has promotion, 0 = no promotion) (β8): 0.454039

# %% [markdown]
# # Problem 1
# ### normalise all variables including the boolean ones

# %%
import pandas as pd
import numpy as np
from scipy import optimize
import matplotlib.pyplot as plt

# Read the data
data = pd.read_csv("data.csv")
print(f"Data loaded, shape: {data.shape}")

# Group by search_id
search_groups = data.groupby('srch_id')

# Features to use in the MNL model
features = [
    'prop_starrating',
    'prop_review_score',
    'prop_brand_bool',
    'prop_location_score',
    'prop_accesibility_score',
    'prop_log_historical_price',
    'price_usd',
    'promotion_flag'
]

# Normalize features (as recommended by the professor)
# Save original data for later reference
data_original = data.copy()

# Store normalization parameters for later interpretation
normalization_params = {}

# Updated normalization code to include all features
for feature in features:
    # if feature not in ['prop_brand_bool', 'promotion_flag']:  # Skip binary features
    mean = data[feature].mean()
    std = data[feature].std()
    data[feature] = (data[feature] - mean) / std
    normalization_params[feature] = {'mean': mean, 'std': std}
    print(f"Normalized {feature}: Original mean={mean:.4f}, Original std={std:.4f}")

# Function to calculate MNL log-likelihood
def mnl_log_likelihood(beta, data, search_groups, features):
    # Initialize log-likelihood
    log_likelihood = 0
    
    # Extract beta values
    beta0 = beta[0]  # intercept
    beta_features = beta[1:]  # coefficients for features
    
    # Loop through each search session
    for search_id, group in search_groups:
        # Get the hotels in this search
        hotels = group.copy()
        
        # Calculate utilities
        X = hotels[features]
        utilities = beta0 + X.dot(beta_features)
        hotels['utility'] = utilities
        
        # Calculate exp(utility) with numerical stability
        max_utility = utilities.max()
        hotels['exp_utility'] = np.exp(utilities - max_utility)
        
        # Calculate denominator (sum of exp(utility) + no-purchase option)
        denominator = hotels['exp_utility'].sum() + np.exp(-max_utility)  # no-purchase has utility 0
        
        # If there was a booking
        if (hotels['booking_bool'] == 1).any():
            # Get the booked hotel
            booked_hotel = hotels[hotels['booking_bool'] == 1].iloc[0]
            
            # Add to log-likelihood: log(P(j|S))
            log_likelihood += (booked_hotel['utility'] - max_utility) - np.log(denominator)
        else:
            # No booking - customer chose outside option
            log_likelihood += (-max_utility) - np.log(denominator)
    
    return -log_likelihood  # Negative because we're minimizing

# Function to fit MNL model
def fit_mnl_model(data, search_groups, features):
    # Initial beta values (all zeros)
    initial_beta = np.zeros(len(features) + 1)  # +1 for intercept
    
    # Define the objective function for optimization
    def objective(beta):
        return mnl_log_likelihood(beta, data, search_groups, features)
    
    # Optimize using L-BFGS-B algorithm
    print("Starting optimization...")
    result = optimize.minimize(
        objective,
        initial_beta,
        method='L-BFGS-B',
        options={'disp': True, 'maxiter': 100}
    )
    
    print(f"Optimization completed: {result.success}")
    print(f"Final negative log-likelihood: {result.fun}")
    
    # Extract optimal beta values
    beta_opt = result.x
    
    return beta_opt

# Fit the MNL model with normalized features
beta_opt = fit_mnl_model(data, search_groups, features)

# Print results with proper interpretation accounting for normalization
print("\nMNL Model Parameters (with normalized features):")
print(f"Intercept (β₀): {beta_opt[0]:.4f}")

feature_descriptions = {
    'prop_starrating': 'Star Rating (higher = better hotel quality)',
    'prop_review_score': 'Review Score (higher = better guest reviews)',
    'prop_brand_bool': 'Brand Flag (1 = branded hotel, 0 = independent)',
    'prop_location_score': 'Location Score (higher = better location)',
    'prop_accesibility_score': 'Accessibility Score (higher = better accessibility)',
    'prop_log_historical_price': 'Log Historical Price',
    'price_usd': 'Price in USD',
    'promotion_flag': 'Promotion Flag (1 = has promotion, 0 = no promotion)'
}

for i, feature in enumerate(features):
    coef = beta_opt[i+1]
    print(f"{feature_descriptions.get(feature, feature)} (β{i+1}): {coef:.6f}")
# Out:
# Data loaded, shape: (153009, 15)
# Normalized prop_starrating: Original mean=3.1574, Original std=0.8572
# Normalized prop_review_score: Original mean=3.9877, Original std=0.9071
# Normalized prop_brand_bool: Original mean=0.7357, Original std=0.4409
# Normalized prop_location_score: Original mean=2.6172, Original std=1.3482
# Normalized prop_accesibility_score: Original mean=0.0060, Original std=0.0772
# Normalized prop_log_historical_price: Original mean=4.2763, Original std=1.7895
# Normalized price_usd: Original mean=141.1936, Original std=181.7699
# Normalized promotion_flag: Original mean=0.1448, Original std=0.3519
# Starting optimization...
# Optimization completed: True
# Final negative log-likelihood: 20611.325970651484
#
# MNL Model Parameters (with normalized features):
# Intercept (β₀): -1.7467
# Star Rating (higher = better hotel quality) (β1): 0.408127
# Review Score (higher = better guest reviews) (β2): 0.108755
# Brand Flag (1 = branded hotel, 0 = independent) (β3): 0.101379
# Location Score (higher = better location) (β4): 0.021997
# Accessibility Score (higher = better accessibility) (β5): 0.043445
# Log Historical Price (β6): -0.066872
# Price in USD (β7): -1.331102
# Promotion Flag (1 = has promotion, 0 = no promotion) (β8): 0.159767

# %%
normalization_params_q1 = normalization_params.copy()

# %%
normalization_params_q1
# Out:
# {'prop_starrating': {'mean': 3.157402505734957, 'std': 0.857185087363258},
#  'prop_review_score': {'mean': 3.9876804632407246, 'std': 0.907122127197961},
#  'prop_brand_bool': {'mean': 0.7357279637145527, 'std': 0.44094625279740235},
#  'prop_location_score': {'mean': 2.6171728460417363, 'std': 1.348155303324557},
#  'prop_accesibility_score': {'mean': 0.005993111516316034,
#   'std': 0.07718311385622265},
#  'prop_log_historical_price': {'mean': 4.27631054382422,
#   'std': 1.7895092329050903},
#  'price_usd': {'mean': 141.19362259736354, 'std': 181.76994386241384},
#  'promotion_flag': {'mean': 0.14480847531844532, 'std': 0.3519087810174338}}

# %% [markdown]
# ## Problem 2
#
# ### Assumption:
# - We use the $\beta$ from problem 1
#
# ```
# betas = [-1.7467,  0.408127, 0.108755, 0.101379, 0.021997, 0.043445,  -0.066872, -1.331102, 0.159767]
# ```
#
# - The only identifier for all the hotels in `data1.csv` is price

# %%
import pandas as pd
import numpy as np

betas =  [-1.7467,  0.408127, 0.108755, 0.101379, 0.021997, 0.043445,  -0.066872, -1.331102, 0.159767]

# %%
def normalize_data(filepath):
    """
    Read and normalize all the features in the .csv file
    Inputs:
        filepath (str)
    Outputs:
        data (DataFrame)
    """
    data = pd.read_csv(filepath)
    # Select only numeric columns to normalize
    numeric_cols = data.select_dtypes(include='number').columns
    print(numeric_cols)
    # z-score normalization / standardization, avoid columns that are entirely 0
    for col in numeric_cols:
        col_min = data[col].min()
        col_max = data[col].max()
        if col_max != col_min:
            data[col] = (data[col] - data[col].mean()) / data[col].std()
    return data

def compute_preference_weight(betas, assortment):
    """
    Inputs:
        betas (List[int]): a list of 9 betas, include beta0
        assortment (DataFrame)
    Outputs:
        pref_weight (List[float]): a list of v_j for all the hotel in the assortment S 
    """
    pref_weights=[]
    for j, row in assortment.iterrows():
        hotel_features = row.tolist() # a list of x_ji values
        hotel_features.insert(0,1) # augmented by 1
        u_j = np.dot(hotel_features, betas)
        v_j = np.exp(u_j)
        pref_weights.append(v_j)
    return pref_weights

def expected_rev(assortment,betas):
    """
    Inputs:
        assortment (DataFrame)
    Outputs:
        expected_rev (float)
    """
    expected_rev = 0
    pref_weights = compute_preference_weight(betas, assortment)
    print(f"pref_weights = {pref_weights}")
    # print(f"pref_weights: {len(pref_weights)}, shape of the assortment: {assortment.shape}")
    j = 0
    for _,row in assortment.iterrows():
        pj = row["price_usd"]
        expected_rev += pj * pref_weights[j]/(1+np.sum(pref_weights))
        j+=1
    print("expected_rev =", expected_rev)
    return expected_rev

def optim_assortment(df, betas):
    """
    Inputs:
        df (DataFrame): all hotels and features 
        pref_weights (List[float]): a list of v_j for all the hotels in the assortment
    Outputs:
        sorted_assortment_rev (Dict[Str:Float]): a dict of assortment with revenue sorted by revenue
        
    """
    # sort by price
    df_sorted = df.sort_values(by="price_usd", ascending=False)
    # print("sorted df:", df_sorted)
    assortment_rev = dict() # {"j": rev}
    idx=1
    for _, row in df_sorted.iterrows():
        # each hotel j
        new_assortment = df_sorted.nlargest(idx, "price_usd")
        print("new_assortment:",new_assortment)
        assortment_rev[str(idx)] = expected_rev(new_assortment, betas)
        print(f"the expected_rev for idx={idx} is {assortment_rev[str(idx)]}")    
        idx+=1
        # if idx==3:
        #     break
    
    sorted_assortment_rev = dict(sorted(assortment_rev.items(), key=lambda x: x[1], reverse=True))
    opt_assortment, opt_rev =  next(iter(sorted_assortment_rev.items()))
    print(f"include the first {opt_assortment} hotels, the optimal revenue is {opt_rev}")
    return sorted_assortment_rev
    
# compute the optimal assortment for each doc

print("For data1.csv")
df1= normalize_data("data1.csv")
# df1 = pd.read_csv("data1.csv")
optim_assortment(df1, betas)

# print("For data2.csv")
# optim_assortment(df2, betas)
# print("For data3.csv")
# optim_assortment(df3, betas)
# print("For data4.csv")
# optim_assortment(df4, betas)
# Out:
# For data1.csv
# Index(['prop_starrating', 'prop_review_score', 'prop_brand_bool',
#        'prop_location_score', 'prop_accesibility_score',
#        'prop_log_historical_price', 'price_usd', 'promotion_flag'],
#       dtype='object')
# new_assortment:     prop_starrating  prop_review_score  prop_brand_bool  prop_location_score  \
# 23         1.471523           0.862323        -2.058406             1.284832
#
#     prop_accesibility_score  prop_log_historical_price  price_usd  \
# 23                        0                   0.109713   1.509469
#
#     promotion_flag
# 23       -0.277555
# pref_weights = [0.03711609901428053]
# expected_rev = 0.05402055923960557
# the expected_rev for idx=1 is 0.05402055923960557
# new_assortment:     prop_starrating  prop_review_score  prop_brand_bool  prop_location_score  \
# 23         1.471523           0.862323        -2.058406             1.284832
# 21         1.471523           0.862323         0.467820             1.284832
#
#     prop_accesibility_score  prop_log_historical_price  price_usd  \
# 23                        0                   0.109713   1.509469
# 21                        0                   3.071976   1.426884
#
#     promotion_flag
# 23       -0.277555
# 21       -0.277555
# pref_weights = [0.03711609901428053, 0.043903480709077555]
# expected_rev = 0.10977669678125837
# the expected_rev for idx=2 is 0.10977669678125837
# new_assortment:     prop_starrating  prop_review_score  prop_brand_bool  prop_location_score  \
# 23         1.471523           0.862323        -2.058406             1.284832
# 21         1.471523           0.862323         0.467820             1.284832
# 4          0.101484           0.862323         0.467820            -1.606040
#
#     prop_accesibility_score  prop_log_historical_price  price_usd  \
# 23                        0                   0.109713   1.509469
# 21                        0                   3.071976   1.426884
# 4                         0                   0.109713   1.344299
#
#     promotion_flag
# 23       -0.277555
# 21       -0.277555
# 4        -0.277555
# pref_weights = [0.03711609901428053, 0.043903480709077555, 0.0320492819597176]
# expected_rev = 0.14532306066883105
# the expected_rev for idx=3 is 0.14532306066883105
# new_assortment:     prop_starrating  prop_review_score  prop_brand_bool  prop_location_score  \
# 23         1.471523           0.862323        -2.058406             1.284832
# 21         1.471523           0.862323         0.467820             1.284832
# 4          0.101484           0.862323         0.467820            -1.606040
# 0          0.101484          -0.301813         0.467820            -1.606040
#
#     prop_accesibility_score  prop_log_historical_price  price_usd  \
# 23                        0                   0.109713   1.509469
# 21                        0                   3.071976   1.426884
# 4                         0                   0.109713   1.344299
# 0                         0                   0.109713   1.179129
#
#     promotion_flag
# 23       -0.277555
# 21       -0.277555
# 4        -0.277555
# 0        -0.277555
# pref_weights = [0.03711609901428053, 0.043903480709077555, 0.0320492819597176, 0.03518173572477866]
# expected_rev = 0.1769982807452966
# the expected_rev for idx=4 is 0.1769982807452966
# new_assortment:     prop_starrating  prop_review_score  prop_brand_bool  prop_location_score  \
# 23         1.471523           0.862323        -2.058406             1.284832
# 21         1.471523           0.862323         0.467820             1.284832
# 4          0.101484           0.862323         0.467820            -1.606040
# 0          0.101484          -0.301813         0.467820            -1.606040
# 22         1.471523          -0.301813         0.467820             1.284832
#
#     prop_accesibility_score  prop_log_historical_price  price_usd  \
# 23                        0                   0.109713   1.509469
# 21                        0                   3.071976   1.426884
# 4                         0                   0.109713   1.344299
# 0                         0                   0.109713   1.179129
# 22                        0                   0.109713   1.055252
#
#     promotion_flag
# 23       -0.277555
# 21       -0.277555
# 4        -0.277555
# 0        -0.277555
# 22        3.469443
# pref_weights = [0.03711609901428053, 0.043903480709077555, 0.0320492819597176, 0.03518173572477866, 0.1407249752077973]
# expected_rev = 0.2728823260759068
# the expected_rev for idx=5 is 0.2728823260759068
# new_assortment:     prop_starrating  prop_review_score  prop_brand_bool  prop_location_score  \
# 23         1.471523           0.862323        -2.058406             1.284832
# 21         1.471523           0.862323         0.467820             1.284832
# 4          0.101484           0.862323         0.467820            -1.606040
# 0          0.101484          -0.301813         0.467820            -1.606040
# 22         1.471523          -0.301813         0.467820             1.284832
# 19         1.471523          -0.301813         0.467820             1.284832
#
#     prop_accesibility_score  prop_log_historical_price  price_usd  \
# 23                        0                   0.109713   1.509469
# 21                        0                   3.071976   1.426884
# 4                         0                   0.109713   1.344299
# 0                         0                   0.109713   1.179129
# 22                        0                   0.109713   1.055252
# 19                        0                   0.109713   1.055252
#
#     promotion_flag
# 23       -0.277555
# 21       -0.277555
# 4        -0.277555
# 0        -0.277555
# 22        3.469443
# 19        3.469443
# pref_weights = [0.03711609901428053, 0.043903480709077555, 0.0320492819597176, 0.03518173572477866, 0.1407249752077973, 0.1407249752077973]
# expected_rev = 0.34989069856367533
# the expected_rev for idx=6 is 0.34989069856367533
# new_assortment:     prop_starrating  prop_review_score  prop_brand_bool  prop_location_score  \
# 23         1.471523           0.862323        -2.058406             1.284832
# 21         1.471523           0.862323         0.467820             1.284832
# 4          0.101484           0.862323         0.467820            -1.606040
# 0          0.101484          -0.301813         0.467820            -1.606040
# 22         1.471523          -0.301813         0.467820             1.284832
# 19         1.471523          -0.301813         0.467820             1.284832
# 2          0.101484           0.862323         0.467820            -0.642416
#
#     prop_accesibility_score  prop_log_historical_price  price_usd  \
# 23                        0                   0.109713   1.509469
# 21                        0                   3.071976   1.426884
# 4                         0                   0.109713   1.344299
# 0                         0                   0.109713   1.179129
# 22                        0                   0.109713   1.055252
# 19                        0                   0.109713   1.055252
# 2                         0                   0.109713   0.972667
#
#     promotion_flag
# 23       -0.277555
# 21       -0.277555
# 4        -0.277555
# 0        -0.277555
# 22        3.469443
# 19        3.469443
# 2        -0.277555
# pref_weights = [0.03711609901428053, 0.043903480709077555, 0.0320492819597176, 0.03518173572477866, 0.1407249752077973, 0.1407249752077973, 0.05368597976621425]
# expected_rev = 0.37242989807467236
# the expected_rev for idx=7 is 0.37242989807467236
# new_assortment:     prop_starrating  prop_review_score  prop_brand_bool  prop_location_score  \
# 23         1.471523           0.862323        -2.058406             1.284832
# 21         1.471523           0.862323         0.467820             1.284832
# 4          0.101484           0.862323         0.467820            -1.606040
# 0          0.101484          -0.301813         0.467820            -1.606040
# 22         1.471523          -0.301813         0.467820             1.284832
# 19         1.471523          -0.301813         0.467820             1.284832
# 2          0.101484           0.862323         0.467820            -0.642416
# 5          0.101484           0.862323         0.467820            -0.642416
#
#     prop_accesibility_score  prop_log_historical_price  price_usd  \
# 23                        0                   0.109713   1.509469
# 21                        0                   3.071976   1.426884
# 4                         0                   0.109713   1.344299
# 0                         0                   0.109713   1.179129
# 22                        0                   0.109713   1.055252
# 19                        0                   0.109713   1.055252
# 2                         0                   0.109713   0.972667
# 5                         0                   0.109713   0.931374
#
#     promotion_flag
# 23       -0.277555
# 21       -0.277555
# 4        -0.277555
# 0        -0.277555
# 22        3.469443
# 19        3.469443
# 2        -0.277555
# 5        -0.277555
# pref_weights = [0.03711609901428053, 0.043903480709077555, 0.0320492819597176, 0.03518173572477866, 0.1407249752077973, 0.1407249752077973, 0.05368597976621425, 0.05671940300006714]
# expected_rev = 0.3930148424122737
# the expected_rev for idx=8 is 0.3930148424122737
# new_assortment:     prop_starrating  prop_review_score  prop_brand_bool  prop_location_score  \
# 23         1.471523           0.862323        -2.058406             1.284832
# 21         1.471523           0.862323         0.467820             1.284832
# 4          0.101484           0.862323         0.467820            -1.606040
# 0          0.101484          -0.301813         0.467820            -1.606040
# 22         1.471523          -0.301813         0.467820             1.284832
# 19         1.471523          -0.301813         0.467820             1.284832
# 2          0.101484           0.862323         0.467820            -0.642416
# 5          0.101484           0.862323         0.467820            -0.642416
# 1          0.101484           0.862323         0.467820            -0.642416
#
#     prop_accesibility_score  prop_log_historical_price  price_usd  \
# 23                        0                   0.109713   1.509469
# 21                        0                   3.071976   1.426884
# 4                         0                   0.109713   1.344299
# 0                         0                   0.109713   1.179129
# 22                        0                   0.109713   1.055252
# 19                        0                   0.109713   1.055252
# 2                         0                   0.109713   0.972667
# 5                         0                   0.109713   0.931374
# 1                         0                   0.109713   0.766205
#
#     promotion_flag
# 23       -0.277555
# 21       -0.277555
# 4        -0.277555
# 0        -0.277555
# 22        3.469443
# 19        3.469443
# 2        -0.277555
# 5        -0.277555
# 1        -0.277555
# pref_weights = [0.03711609901428053, 0.043903480709077555, 0.0320492819597176, 0.03518173572477866, 0.1407249752077973, 0.1407249752077973, 0.05368597976621425, 0.05671940300006714, 0.07066668545777242]
# expected_rev = 0.40938715724160935
# the expected_rev for idx=9 is 0.40938715724160935
# new_assortment:     prop_starrating  prop_review_score  prop_brand_bool  prop_location_score  \
# 23         1.471523           0.862323        -2.058406             1.284832
# 21         1.471523           0.862323         0.467820             1.284832
# 4          0.101484           0.862323         0.467820            -1.606040
# 0          0.101484          -0.301813         0.467820            -1.606040
# 22         1.471523          -0.301813         0.467820             1.284832
# 19         1.471523          -0.301813         0.467820             1.284832
# 2          0.101484           0.862323         0.467820            -0.642416
# 5          0.101484           0.862323         0.467820            -0.642416
# 1          0.101484           0.862323         0.467820            -0.642416
# 6          0.101484          -0.301813         0.467820             0.321208
#
#     prop_accesibility_score  prop_log_historical_price  price_usd  \
# 23                        0                   0.109713   1.509469
# 21                        0                   3.071976   1.426884
# 4                         0                   0.109713   1.344299
# 0                         0                   0.109713   1.179129
# 22                        0                   0.109713   1.055252
# 19                        0                   0.109713   1.055252
# 2                         0                   0.109713   0.972667
# 5                         0                   0.109713   0.931374
# 1                         0                   0.109713   0.766205
# 6                         0                   0.109713   0.394572
#
#     promotion_flag
# 23       -0.277555
# 21       -0.277555
# 4        -0.277555
# 0        -0.277555
# 22        3.469443
# 19        3.469443
# 2        -0.277555
# 5        -0.277555
# 1        -0.277555
# 6        -0.277555
# pref_weights = [0.03711609901428053, 0.043903480709077555, 0.0320492819597176, 0.03518173572477866, 0.1407249752077973, 0.1407249752077973, 0.05368597976621425, 0.05671940300006714, 0.07066668545777242, 0.10429732948863464]
# expected_rev = 0.40848623666253775
# the expected_rev for idx=10 is 0.40848623666253775
# new_assortment:     prop_starrating  prop_review_score  prop_brand_bool  prop_location_score  \
# 23         1.471523           0.862323        -2.058406             1.284832
# 21         1.471523           0.862323         0.467820             1.284832
# 4          0.101484           0.862323         0.467820            -1.606040
# 0          0.101484          -0.301813         0.467820            -1.606040
# 22         1.471523          -0.301813         0.467820             1.284832
# 19         1.471523          -0.301813         0.467820             1.284832
# 2          0.101484           0.862323         0.467820            -0.642416
# 5          0.101484           0.862323         0.467820            -0.642416
# 1          0.101484           0.862323         0.467820            -0.642416
# 6          0.101484          -0.301813         0.467820             0.321208
# 15         0.101484          -0.301813         0.467820            -0.642416
#
#     prop_accesibility_score  prop_log_historical_price  price_usd  \
# 23                        0                   0.109713   1.509469
# 21                        0                   3.071976   1.426884
# 4                         0                   0.109713   1.344299
# 0                         0                   0.109713   1.179129
# 22                        0                   0.109713   1.055252
# 19                        0                   0.109713   1.055252
# 2                         0                   0.109713   0.972667
# 5                         0                   0.109713   0.931374
# 1                         0                   0.109713   0.766205
# 6                         0                   0.109713   0.394572
# 15                        0                   0.109713   0.394572
#
#     promotion_flag
# 23       -0.277555
# 21       -0.277555
# 4        -0.277555
# 0        -0.277555
# 22        3.469443
# 19        3.469443
# 2        -0.277555
# 5        -0.277555
# 1        -0.277555
# 6        -0.277555
# 15       -0.277555
# pref_weights = [0.03711609901428053, 0.043903480709077555, 0.0320492819597176, 0.03518173572477866, 0.1407249752077973, 0.1407249752077973, 0.05368597976621425, 0.05671940300006714, 0.07066668545777242, 0.10429732948863464, 0.10210982175607189]
# expected_rev = 0.407704397929613
# the expected_rev for idx=11 is 0.407704397929613
# new_assortment:     prop_starrating  prop_review_score  prop_brand_bool  prop_location_score  \
# 23         1.471523           0.862323        -2.058406             1.284832
# 21         1.471523           0.862323         0.467820             1.284832
# 4          0.101484           0.862323         0.467820            -1.606040
# 0          0.101484          -0.301813         0.467820            -1.606040
# 22         1.471523          -0.301813         0.467820             1.284832
# 19         1.471523          -0.301813         0.467820             1.284832
# 2          0.101484           0.862323         0.467820            -0.642416
# 5          0.101484           0.862323         0.467820            -0.642416
# 1          0.101484           0.862323         0.467820            -0.642416
# 6          0.101484          -0.301813         0.467820             0.321208
# 15         0.101484          -0.301813         0.467820            -0.642416
# 3          1.471523           0.862323         0.467820            -1.606040
#
#     prop_accesibility_score  prop_log_historical_price  price_usd  \
# 23                        0                   0.109713   1.509469
# 21                        0                   3.071976   1.426884
# 4                         0                   0.109713   1.344299
# 0                         0                   0.109713   1.179129
# 22                        0                   0.109713   1.055252
# 19                        0                   0.109713   1.055252
# 2                         0                   0.109713   0.972667
# 5                         0                   0.109713   0.931374
# 1                         0                   0.109713   0.766205
# 6                         0                   0.109713   0.394572
# 15                        0                   0.109713   0.394572
# 3                         0                   0.109713   0.146818
#
#     promotion_flag
# 23       -0.277555
# 21       -0.277555
# 4        -0.277555
# 0        -0.277555
# 22        3.469443
# 19        3.469443
# 2        -0.277555
# 5        -0.277555
# 1        -0.277555
# 6        -0.277555
# 15       -0.277555
# 3        -0.277555
# pref_weights = [0.03711609901428053, 0.043903480709077555, 0.0320492819597176, 0.03518173572477866, 0.1407249752077973, 0.1407249752077973, 0.05368597976621425, 0.05671940300006714, 0.07066668545777242, 0.10429732948863464, 0.10210982175607189, 0.27599816041766473]
# expected_rev = 0.37330490076290734
# the expected_rev for idx=12 is 0.37330490076290734
# new_assortment:     prop_starrating  prop_review_score  prop_brand_bool  prop_location_score  \
# 23         1.471523           0.862323        -2.058406             1.284832
# 21         1.471523           0.862323         0.467820             1.284832
# 4          0.101484           0.862323         0.467820            -1.606040
# 0          0.101484          -0.301813         0.467820            -1.606040
# 22         1.471523          -0.301813         0.467820             1.284832
# 19         1.471523          -0.301813         0.467820             1.284832
# 2          0.101484           0.862323         0.467820            -0.642416
# 5          0.101484           0.862323         0.467820            -0.642416
# 1          0.101484           0.862323         0.467820            -0.642416
# 6          0.101484          -0.301813         0.467820             0.321208
# 15         0.101484          -0.301813         0.467820            -0.642416
# 3          1.471523           0.862323         0.467820            -1.606040
# 20         0.101484          -1.465949        -2.058406             1.284832
#
#     prop_accesibility_score  prop_log_historical_price  price_usd  \
# 23                        0                   0.109713   1.509469
# 21                        0                   3.071976   1.426884
# 4                         0                   0.109713   1.344299
# 0                         0                   0.109713   1.179129
# 22                        0                   0.109713   1.055252
# 19                        0                   0.109713   1.055252
# 2                         0                   0.109713   0.972667
# 5                         0                   0.109713   0.931374
# 1                         0                   0.109713   0.766205
# 6                         0                   0.109713   0.394572
# 15                        0                   0.109713   0.394572
# 3                         0                   0.109713   0.146818
# 20                        0                   0.109713  -0.018352
#
#     promotion_flag
# 23       -0.277555
# 21       -0.277555
# 4        -0.277555
# 0        -0.277555
# 22        3.469443
# 19        3.469443
# 2        -0.277555
# 5        -0.277555
# 1        -0.277555
# 6        -0.277555
# 15       -0.277555
# 3        -0.277555
# 20       -0.277555
# pref_weights = [0.03711609901428053, 0.043903480709077555, 0.0320492819597176, 0.03518173572477866, 0.1407249752077973, 0.1407249752077973, 0.05368597976621425, 0.05671940300006714, 0.07066668545777242, 0.10429732948863464, 0.10210982175607189, 0.27599816041766473, 0.1258858398980091]
# expected_rev = 0.35108648403069564
# the expected_rev for idx=13 is 0.35108648403069564
# new_assortment:     prop_starrating  prop_review_score  prop_brand_bool  prop_location_score  \
# 23         1.471523           0.862323        -2.058406             1.284832
# 21         1.471523           0.862323         0.467820             1.284832
# 4          0.101484           0.862323         0.467820            -1.606040
# 0          0.101484          -0.301813         0.467820            -1.606040
# 22         1.471523          -0.301813         0.467820             1.284832
# 19         1.471523          -0.301813         0.467820             1.284832
# 2          0.101484           0.862323         0.467820            -0.642416
# 5          0.101484           0.862323         0.467820            -0.642416
# 1          0.101484           0.862323         0.467820            -0.642416
# 6          0.101484          -0.301813         0.467820             0.321208
# 15         0.101484          -0.301813         0.467820            -0.642416
# 3          1.471523           0.862323         0.467820            -1.606040
# 20         0.101484          -1.465949        -2.058406             1.284832
# 18         0.101484          -1.465949         0.467820            -0.642416
#
#     prop_accesibility_score  prop_log_historical_price  price_usd  \
# 23                        0                   0.109713   1.509469
# 21                        0                   3.071976   1.426884
# 4                         0                   0.109713   1.344299
# 0                         0                   0.109713   1.179129
# 22                        0                   0.109713   1.055252
# 19                        0                   0.109713   1.055252
# 2                         0                   0.109713   0.972667
# 5                         0                   0.109713   0.931374
# 1                         0                   0.109713   0.766205
# 6                         0                   0.109713   0.394572
# 15                        0                   0.109713   0.394572
# 3                         0                   0.109713   0.146818
# 20                        0                   0.109713  -0.018352
# 18                        0                   0.109713  -0.018352
#
#     promotion_flag
# 23       -0.277555
# 21       -0.277555
# 4        -0.277555
# 0        -0.277555
# 22        3.469443
# 19        3.469443
# 2        -0.277555
# 5        -0.277555
# 1        -0.277555
# 6        -0.277555
# 15       -0.277555
# 3        -0.277555
# 20       -0.277555
# 18       -0.277555
# pref_weights = [0.03711609901428053, 0.043903480709077555, 0.0320492819597176, 0.03518173572477866, 0.1407249752077973, 0.1407249752077973, 0.05368597976621425, 0.05671940300006714, 0.07066668545777242, 0.10429732948863464, 0.10210982175607189, 0.27599816041766473, 0.1258858398980091, 0.15588024587207722]
# expected_rev = 0.32683825201040306
# the expected_rev for idx=14 is 0.32683825201040306
# new_assortment:     prop_starrating  prop_review_score  prop_brand_bool  prop_location_score  \
# 23         1.471523           0.862323        -2.058406             1.284832
# 21         1.471523           0.862323         0.467820             1.284832
# 4          0.101484           0.862323         0.467820            -1.606040
# 0          0.101484          -0.301813         0.467820            -1.606040
# 22         1.471523          -0.301813         0.467820             1.284832
# 19         1.471523          -0.301813         0.467820             1.284832
# 2          0.101484           0.862323         0.467820            -0.642416
# 5          0.101484           0.862323         0.467820            -0.642416
# 1          0.101484           0.862323         0.467820            -0.642416
# 6          0.101484          -0.301813         0.467820             0.321208
# 15         0.101484          -0.301813         0.467820            -0.642416
# 3          1.471523           0.862323         0.467820            -1.606040
# 20         0.101484          -1.465949        -2.058406             1.284832
# 18         0.101484          -1.465949         0.467820            -0.642416
# 17         0.101484           0.862323         0.467820            -0.642416
#
#     prop_accesibility_score  prop_log_historical_price  price_usd  \
# 23                        0                   0.109713   1.509469
# 21                        0                   3.071976   1.426884
# 4                         0                   0.109713   1.344299
# 0                         0                   0.109713   1.179129
# 22                        0                   0.109713   1.055252
# 19                        0                   0.109713   1.055252
# 2                         0                   0.109713   0.972667
# 5                         0                   0.109713   0.931374
# 1                         0                   0.109713   0.766205
# 6                         0                   0.109713   0.394572
# 15                        0                   0.109713   0.394572
# 3                         0                   0.109713   0.146818
# 20                        0                   0.109713  -0.018352
# 18                        0                   0.109713  -0.018352
# 17                        0                   0.109713  -0.059645
#
#     promotion_flag
# 23       -0.277555
# 21       -0.277555
# 4        -0.277555
# 0        -0.277555
# 22        3.469443
# 19        3.469443
# 2        -0.277555
# 5        -0.277555
# 1        -0.277555
# 6        -0.277555
# 15       -0.277555
# 3        -0.277555
# 20       -0.277555
# 18       -0.277555
# 17       -0.277555
# pref_weights = [0.03711609901428053, 0.043903480709077555, 0.0320492819597176, 0.03518173572477866, 0.1407249752077973, 0.1407249752077973, 0.05368597976621425, 0.05671940300006714, 0.07066668545777242, 0.10429732948863464, 0.10210982175607189, 0.27599816041766473, 0.1258858398980091, 0.15588024587207722, 0.2121436686765426]
# expected_rev = 0.2951462827695272
# the expected_rev for idx=15 is 0.2951462827695272
# new_assortment:     prop_starrating  prop_review_score  prop_brand_bool  prop_location_score  \
# 23         1.471523           0.862323        -2.058406             1.284832
# 21         1.471523           0.862323         0.467820             1.284832
# 4          0.101484           0.862323         0.467820            -1.606040
# 0          0.101484          -0.301813         0.467820            -1.606040
# 22         1.471523          -0.301813         0.467820             1.284832
# 19         1.471523          -0.301813         0.467820             1.284832
# 2          0.101484           0.862323         0.467820            -0.642416
# 5          0.101484           0.862323         0.467820            -0.642416
# 1          0.101484           0.862323         0.467820            -0.642416
# 6          0.101484          -0.301813         0.467820             0.321208
# 15         0.101484          -0.301813         0.467820            -0.642416
# 3          1.471523           0.862323         0.467820            -1.606040
# 20         0.101484          -1.465949        -2.058406             1.284832
# 18         0.101484          -1.465949         0.467820            -0.642416
# 17         0.101484           0.862323         0.467820            -0.642416
# 24         0.101484           0.862323         0.467820             1.284832
#
#     prop_accesibility_score  prop_log_historical_price  price_usd  \
# 23                        0                   0.109713   1.509469
# 21                        0                   3.071976   1.426884
# 4                         0                   0.109713   1.344299
# 0                         0                   0.109713   1.179129
# 22                        0                   0.109713   1.055252
# 19                        0                   0.109713   1.055252
# 2                         0                   0.109713   0.972667
# 5                         0                   0.109713   0.931374
# 1                         0                   0.109713   0.766205
# 6                         0                   0.109713   0.394572
# 15                        0                   0.109713   0.394572
# 3                         0                   0.109713   0.146818
# 20                        0                   0.109713  -0.018352
# 18                        0                   0.109713  -0.018352
# 17                        0                   0.109713  -0.059645
# 24                        0                   0.109713  -0.142230
#
#     promotion_flag
# 23       -0.277555
# 21       -0.277555
# 4        -0.277555
# 0        -0.277555
# 22        3.469443
# 19        3.469443
# 2        -0.277555
# 5        -0.277555
# 1        -0.277555
# 6        -0.277555
# 15       -0.277555
# 3        -0.277555
# 20       -0.277555
# 18       -0.277555
# 17       -0.277555
# 24       -0.277555
# pref_weights = [0.03711609901428053, 0.043903480709077555, 0.0320492819597176, 0.03518173572477866, 0.1407249752077973, 0.1407249752077973, 0.05368597976621425, 0.05671940300006714, 0.07066668545777242, 0.10429732948863464, 0.10210982175607189, 0.27599816041766473, 0.1258858398980091, 0.15588024587207722, 0.2121436686765426, 0.2470489152130064]
# expected_rev = 0.2570206567285121
# the expected_rev for idx=16 is 0.2570206567285121
# new_assortment:     prop_starrating  prop_review_score  prop_brand_bool  prop_location_score  \
# 23         1.471523           0.862323        -2.058406             1.284832
# 21         1.471523           0.862323         0.467820             1.284832
# 4          0.101484           0.862323         0.467820            -1.606040
# 0          0.101484          -0.301813         0.467820            -1.606040
# 22         1.471523          -0.301813         0.467820             1.284832
# 19         1.471523          -0.301813         0.467820             1.284832
# 2          0.101484           0.862323         0.467820            -0.642416
# 5          0.101484           0.862323         0.467820            -0.642416
# 1          0.101484           0.862323         0.467820            -0.642416
# 6          0.101484          -0.301813         0.467820             0.321208
# 15         0.101484          -0.301813         0.467820            -0.642416
# 3          1.471523           0.862323         0.467820            -1.606040
# 20         0.101484          -1.465949        -2.058406             1.284832
# 18         0.101484          -1.465949         0.467820            -0.642416
# 17         0.101484           0.862323         0.467820            -0.642416
# 24         0.101484           0.862323         0.467820             1.284832
# 26         1.471523           0.862323         0.467820             1.284832
#
#     prop_accesibility_score  prop_log_historical_price  price_usd  \
# 23                        0                   0.109713   1.509469
# 21                        0                   3.071976   1.426884
# 4                         0                   0.109713   1.344299
# 0                         0                   0.109713   1.179129
# 22                        0                   0.109713   1.055252
# 19                        0                   0.109713   1.055252
# 2                         0                   0.109713   0.972667
# 5                         0                   0.109713   0.931374
# 1                         0                   0.109713   0.766205
# 6                         0                   0.109713   0.394572
# 15                        0                   0.109713   0.394572
# 3                         0                   0.109713   0.146818
# 20                        0                   0.109713  -0.018352
# 18                        0                   0.109713  -0.018352
# 17                        0                   0.109713  -0.059645
# 24                        0                   0.109713  -0.142230
# 26                        0                   0.109713  -0.389984
#
#     promotion_flag
# 23       -0.277555
# 21       -0.277555
# 4        -0.277555
# 0        -0.277555
# 22        3.469443
# 19        3.469443
# 2        -0.277555
# 5        -0.277555
# 1        -0.277555
# 6        -0.277555
# 15       -0.277555
# 3        -0.277555
# 20       -0.277555
# 18       -0.277555
# 17       -0.277555
# 24       -0.277555
# 26       -0.277555
# pref_weights = [0.03711609901428053, 0.043903480709077555, 0.0320492819597176, 0.03518173572477866, 0.1407249752077973, 0.1407249752077973, 0.05368597976621425, 0.05671940300006714, 0.07066668545777242, 0.10429732948863464, 0.10210982175607189, 0.27599816041766473, 0.1258858398980091, 0.15588024587207722, 0.2121436686765426, 0.2470489152130064, 0.6009566958706394]
# expected_rev = 0.14382955981037535
# the expected_rev for idx=17 is 0.14382955981037535
# new_assortment:     prop_starrating  prop_review_score  prop_brand_bool  prop_location_score  \
# 23         1.471523           0.862323        -2.058406             1.284832
# 21         1.471523           0.862323         0.467820             1.284832
# 4          0.101484           0.862323         0.467820            -1.606040
# 0          0.101484          -0.301813         0.467820            -1.606040
# 22         1.471523          -0.301813         0.467820             1.284832
# 19         1.471523          -0.301813         0.467820             1.284832
# 2          0.101484           0.862323         0.467820            -0.642416
# 5          0.101484           0.862323         0.467820            -0.642416
# 1          0.101484           0.862323         0.467820            -0.642416
# 6          0.101484          -0.301813         0.467820             0.321208
# 15         0.101484          -0.301813         0.467820            -0.642416
# 3          1.471523           0.862323         0.467820            -1.606040
# 20         0.101484          -1.465949        -2.058406             1.284832
# 18         0.101484          -1.465949         0.467820            -0.642416
# 17         0.101484           0.862323         0.467820            -0.642416
# 24         0.101484           0.862323         0.467820             1.284832
# 26         1.471523           0.862323         0.467820             1.284832
# 12        -1.268554          -0.301813        -2.058406             0.321208
#
#     prop_accesibility_score  prop_log_historical_price  price_usd  \
# 23                        0                   0.109713   1.509469
# 21                        0                   3.071976   1.426884
# 4                         0                   0.109713   1.344299
# 0                         0                   0.109713   1.179129
# 22                        0                   0.109713   1.055252
# 19                        0                   0.109713   1.055252
# 2                         0                   0.109713   0.972667
# 5                         0                   0.109713   0.931374
# 1                         0                   0.109713   0.766205
# 6                         0                   0.109713   0.394572
# 15                        0                   0.109713   0.394572
# 3                         0                   0.109713   0.146818
# 20                        0                   0.109713  -0.018352
# 18                        0                   0.109713  -0.018352
# 17                        0                   0.109713  -0.059645
# 24                        0                   0.109713  -0.142230
# 26                        0                   0.109713  -0.389984
# 12                        0                   0.109713  -0.555154
#
#     promotion_flag
# 23       -0.277555
# 21       -0.277555
# 4        -0.277555
# 0        -0.277555
# 22        3.469443
# 19        3.469443
# 2        -0.277555
# 5        -0.277555
# 1        -0.277555
# 6        -0.277555
# 15       -0.277555
# 3        -0.277555
# 20       -0.277555
# 18       -0.277555
# 17       -0.277555
# 24       -0.277555
# 26       -0.277555
# 12       -0.277555
# pref_weights = [0.03711609901428053, 0.043903480709077555, 0.0320492819597176, 0.03518173572477866, 0.1407249752077973, 0.1407249752077973, 0.05368597976621425, 0.05671940300006714, 0.07066668545777242, 0.10429732948863464, 0.10210982175607189, 0.27599816041766473, 0.1258858398980091, 0.15588024587207722, 0.2121436686765426, 0.2470489152130064, 0.6009566958706394, 0.16339534601371491]
# expected_rev = 0.1120910444524027
# the expected_rev for idx=18 is 0.1120910444524027
# new_assortment:     prop_starrating  prop_review_score  prop_brand_bool  prop_location_score  \
# 23         1.471523           0.862323        -2.058406             1.284832
# 21         1.471523           0.862323         0.467820             1.284832
# 4          0.101484           0.862323         0.467820            -1.606040
# 0          0.101484          -0.301813         0.467820            -1.606040
# 22         1.471523          -0.301813         0.467820             1.284832
# 19         1.471523          -0.301813         0.467820             1.284832
# 2          0.101484           0.862323         0.467820            -0.642416
# 5          0.101484           0.862323         0.467820            -0.642416
# 1          0.101484           0.862323         0.467820            -0.642416
# 6          0.101484          -0.301813         0.467820             0.321208
# 15         0.101484          -0.301813         0.467820            -0.642416
# 3          1.471523           0.862323         0.467820            -1.606040
# 20         0.101484          -1.465949        -2.058406             1.284832
# 18         0.101484          -1.465949         0.467820            -0.642416
# 17         0.101484           0.862323         0.467820            -0.642416
# 24         0.101484           0.862323         0.467820             1.284832
# 26         1.471523           0.862323         0.467820             1.284832
# 12        -1.268554          -0.301813        -2.058406             0.321208
# 14        -1.268554           0.862323         0.467820            -0.642416
#
#     prop_accesibility_score  prop_log_historical_price  price_usd  \
# 23                        0                   0.109713   1.509469
# 21                        0                   3.071976   1.426884
# 4                         0                   0.109713   1.344299
# 0                         0                   0.109713   1.179129
# 22                        0                   0.109713   1.055252
# 19                        0                   0.109713   1.055252
# 2                         0                   0.109713   0.972667
# 5                         0                   0.109713   0.931374
# 1                         0                   0.109713   0.766205
# 6                         0                   0.109713   0.394572
# 15                        0                   0.109713   0.394572
# 3                         0                   0.109713   0.146818
# 20                        0                   0.109713  -0.018352
# 18                        0                   0.109713  -0.018352
# 17                        0                   0.109713  -0.059645
# 24                        0                   0.109713  -0.142230
# 26                        0                   0.109713  -0.389984
# 12                        0                   0.109713  -0.555154
# 14                        0                  -2.852549  -0.596447
#
#     promotion_flag
# 23       -0.277555
# 21       -0.277555
# 4        -0.277555
# 0        -0.277555
# 22        3.469443
# 19        3.469443
# 2        -0.277555
# 5        -0.277555
# 1        -0.277555
# 6        -0.277555
# 15       -0.277555
# 3        -0.277555
# 20       -0.277555
# 18       -0.277555
# 17       -0.277555
# 24       -0.277555
# 26       -0.277555
# 12       -0.277555
# 14       -0.277555
# pref_weights = [0.03711609901428053, 0.043903480709077555, 0.0320492819597176, 0.03518173572477866, 0.1407249752077973, 0.1407249752077973, 0.05368597976621425, 0.05671940300006714, 0.07066668545777242, 0.10429732948863464, 0.10210982175607189, 0.27599816041766473, 0.1258858398980091, 0.15588024587207722, 0.2121436686765426, 0.2470489152130064, 0.6009566958706394, 0.16339534601371491, 0.30209593520106365]
# expected_rev = 0.057215590760132475
# the expected_rev for idx=19 is 0.057215590760132475
# new_assortment:     prop_starrating  prop_review_score  prop_brand_bool  prop_location_score  \
# 23         1.471523           0.862323        -2.058406             1.284832
# 21         1.471523           0.862323         0.467820             1.284832
# 4          0.101484           0.862323         0.467820            -1.606040
# 0          0.101484          -0.301813         0.467820            -1.606040
# 22         1.471523          -0.301813         0.467820             1.284832
# 19         1.471523          -0.301813         0.467820             1.284832
# 2          0.101484           0.862323         0.467820            -0.642416
# 5          0.101484           0.862323         0.467820            -0.642416
# 1          0.101484           0.862323         0.467820            -0.642416
# 6          0.101484          -0.301813         0.467820             0.321208
# 15         0.101484          -0.301813         0.467820            -0.642416
# 3          1.471523           0.862323         0.467820            -1.606040
# 20         0.101484          -1.465949        -2.058406             1.284832
# 18         0.101484          -1.465949         0.467820            -0.642416
# 17         0.101484           0.862323         0.467820            -0.642416
# 24         0.101484           0.862323         0.467820             1.284832
# 26         1.471523           0.862323         0.467820             1.284832
# 12        -1.268554          -0.301813        -2.058406             0.321208
# 14        -1.268554           0.862323         0.467820            -0.642416
# 9         -1.268554          -1.465949         0.467820            -0.642416
#
#     prop_accesibility_score  prop_log_historical_price  price_usd  \
# 23                        0                   0.109713   1.509469
# 21                        0                   3.071976   1.426884
# 4                         0                   0.109713   1.344299
# 0                         0                   0.109713   1.179129
# 22                        0                   0.109713   1.055252
# 19                        0                   0.109713   1.055252
# 2                         0                   0.109713   0.972667
# 5                         0                   0.109713   0.931374
# 1                         0                   0.109713   0.766205
# 6                         0                   0.109713   0.394572
# 15                        0                   0.109713   0.394572
# 3                         0                   0.109713   0.146818
# 20                        0                   0.109713  -0.018352
# 18                        0                   0.109713  -0.018352
# 17                        0                   0.109713  -0.059645
# 24                        0                   0.109713  -0.142230
# 26                        0                   0.109713  -0.389984
# 12                        0                   0.109713  -0.555154
# 14                        0                  -2.852549  -0.596447
# 9                         0                   0.109713  -0.596447
#
#     promotion_flag
# 23       -0.277555
# 21       -0.277555
# 4        -0.277555
# 0        -0.277555
# 22        3.469443
# 19        3.469443
# 2        -0.277555
# 5        -0.277555
# 1        -0.277555
# 6        -0.277555
# 15       -0.277555
# 3        -0.277555
# 20       -0.277555
# 18       -0.277555
# 17       -0.277555
# 24       -0.277555
# 26       -0.277555
# 12       -0.277555
# 14       -0.277555
# 9        -0.277555
# pref_weights = [0.03711609901428053, 0.043903480709077555, 0.0320492819597176, 0.03518173572477866, 0.1407249752077973, 0.1407249752077973, 0.05368597976621425, 0.05671940300006714, 0.07066668545777242, 0.10429732948863464, 0.10210982175607189, 0.27599816041766473, 0.1258858398980091, 0.15588024587207722, 0.2121436686765426, 0.2470489152130064, 0.6009566958706394, 0.16339534601371491, 0.30209593520106365, 0.19237392599987152]
# expected_rev = 0.026492688088797237
# the expected_rev for idx=20 is 0.026492688088797237
# new_assortment:     prop_starrating  prop_review_score  prop_brand_bool  prop_location_score  \
# 23         1.471523           0.862323        -2.058406             1.284832
# 21         1.471523           0.862323         0.467820             1.284832
# 4          0.101484           0.862323         0.467820            -1.606040
# 0          0.101484          -0.301813         0.467820            -1.606040
# 22         1.471523          -0.301813         0.467820             1.284832
# 19         1.471523          -0.301813         0.467820             1.284832
# 2          0.101484           0.862323         0.467820            -0.642416
# 5          0.101484           0.862323         0.467820            -0.642416
# 1          0.101484           0.862323         0.467820            -0.642416
# 6          0.101484          -0.301813         0.467820             0.321208
# 15         0.101484          -0.301813         0.467820            -0.642416
# 3          1.471523           0.862323         0.467820            -1.606040
# 20         0.101484          -1.465949        -2.058406             1.284832
# 18         0.101484          -1.465949         0.467820            -0.642416
# 17         0.101484           0.862323         0.467820            -0.642416
# 24         0.101484           0.862323         0.467820             1.284832
# 26         1.471523           0.862323         0.467820             1.284832
# 12        -1.268554          -0.301813        -2.058406             0.321208
# 14        -1.268554           0.862323         0.467820            -0.642416
# 9         -1.268554          -1.465949         0.467820            -0.642416
# 16        -1.268554          -0.301813        -2.058406            -0.642416
#
#     prop_accesibility_score  prop_log_historical_price  price_usd  \
# 23                        0                   0.109713   1.509469
# ...
# 2          0.101484           0.862323         0.467820            -0.642416
# 5          0.101484           0.862323         0.467820            -0.642416
# 1          0.101484           0.862323         0.467820            -0.642416
# 6          0.101484          -0.301813         0.467820             0.321208
# 15         0.101484          -0.301813         0.467820            -0.642416
# 3          1.471523           0.862323         0.467820            -1.606040
# 20         0.101484          -1.465949        -2.058406             1.284832
# 18         0.101484          -1.465949         0.467820            -0.642416
# 17         0.101484           0.862323         0.467820            -0.642416
# 24         0.101484           0.862323         0.467820             1.284832
# 26         1.471523           0.862323         0.467820             1.284832
# 12        -1.268554          -0.301813        -2.058406             0.321208
# 14        -1.268554           0.862323         0.467820            -0.642416
# 9         -1.268554          -1.465949         0.467820            -0.642416
# 16        -1.268554          -0.301813        -2.058406            -0.642416
# 25         0.101484           0.862323         0.467820             1.284832
# 11        -1.268554          -0.301813         0.467820             0.321208
# 10         0.101484           0.862323         0.467820             0.321208
# 7         -1.268554          -0.301813         0.467820             0.321208
#
#     prop_accesibility_score  prop_log_historical_price  price_usd  \
# 23                        0                   0.109713   1.509469
# 21                        0                   3.071976   1.426884
# 4                         0                   0.109713   1.344299
# 0                         0                   0.109713   1.179129
# 22                        0                   0.109713   1.055252
# 19                        0                   0.109713   1.055252
# 2                         0                   0.109713   0.972667
# 5                         0                   0.109713   0.931374
# 1                         0                   0.109713   0.766205
# 6                         0                   0.109713   0.394572
# 15                        0                   0.109713   0.394572
# 3                         0                   0.109713   0.146818
# 20                        0                   0.109713  -0.018352
# 18                        0                   0.109713  -0.018352
# 17                        0                   0.109713  -0.059645
# 24                        0                   0.109713  -0.142230
# 26                        0                   0.109713  -0.389984
# 12                        0                   0.109713  -0.555154
# 14                        0                  -2.852549  -0.596447
# 9                         0                   0.109713  -0.596447
# 16                        0                   0.109713  -0.679032
# 25                        0                   0.109713  -0.926786
# 11                        0                   0.109713  -1.091956
# 10                        0                   0.109713  -1.091956
# 7                         0                   0.109713  -1.257126
#
#     promotion_flag
# 23       -0.277555
# 21       -0.277555
# 4        -0.277555
# 0        -0.277555
# 22        3.469443
# 19        3.469443
# 2        -0.277555
# 5        -0.277555
# 1        -0.277555
# 6        -0.277555
# 15       -0.277555
# 3        -0.277555
# 20       -0.277555
# 18       -0.277555
# 17       -0.277555
# 24       -0.277555
# 26       -0.277555
# 12       -0.277555
# 14       -0.277555
# 9        -0.277555
# 16       -0.277555
# 25       -0.277555
# 11       -0.277555
# 10       -0.277555
# 7        -0.277555
# pref_weights = [0.03711609901428053, 0.043903480709077555, 0.0320492819597176, 0.03518173572477866, 0.1407249752077973, 0.1407249752077973, 0.05368597976621425, 0.05671940300006714, 0.07066668545777242, 0.10429732948863464, 0.10210982175607189, 0.27599816041766473, 0.1258858398980091, 0.15588024587207722, 0.2121436686765426, 0.2470489152130064, 0.6009566958706394, 0.16339534601371491, 0.30209593520106365, 0.19237392599987152, 0.18864544136707603, 0.7019845226018548, 0.4313057055489549, 0.8562585815349659, 0.5373636360406425]
# expected_rev = -0.4041629154117906
# the expected_rev for idx=25 is -0.4041629154117906
# new_assortment:     prop_starrating  prop_review_score  prop_brand_bool  prop_location_score  \
# 23         1.471523           0.862323        -2.058406             1.284832
# 21         1.471523           0.862323         0.467820             1.284832
# 4          0.101484           0.862323         0.467820            -1.606040
# 0          0.101484          -0.301813         0.467820            -1.606040
# 22         1.471523          -0.301813         0.467820             1.284832
# 19         1.471523          -0.301813         0.467820             1.284832
# 2          0.101484           0.862323         0.467820            -0.642416
# 5          0.101484           0.862323         0.467820            -0.642416
# 1          0.101484           0.862323         0.467820            -0.642416
# 6          0.101484          -0.301813         0.467820             0.321208
# 15         0.101484          -0.301813         0.467820            -0.642416
# 3          1.471523           0.862323         0.467820            -1.606040
# 20         0.101484          -1.465949        -2.058406             1.284832
# 18         0.101484          -1.465949         0.467820            -0.642416
# 17         0.101484           0.862323         0.467820            -0.642416
# 24         0.101484           0.862323         0.467820             1.284832
# 26         1.471523           0.862323         0.467820             1.284832
# 12        -1.268554          -0.301813        -2.058406             0.321208
# 14        -1.268554           0.862323         0.467820            -0.642416
# 9         -1.268554          -1.465949         0.467820            -0.642416
# 16        -1.268554          -0.301813        -2.058406            -0.642416
# 25         0.101484           0.862323         0.467820             1.284832
# 11        -1.268554          -0.301813         0.467820             0.321208
# 10         0.101484           0.862323         0.467820             0.321208
# 7         -1.268554          -0.301813         0.467820             0.321208
# 8         -1.268554          -1.465949        -2.058406            -0.642416
#
#     prop_accesibility_score  prop_log_historical_price  price_usd  \
# 23                        0                   0.109713   1.509469
# 21                        0                   3.071976   1.426884
# 4                         0                   0.109713   1.344299
# 0                         0                   0.109713   1.179129
# 22                        0                   0.109713   1.055252
# 19                        0                   0.109713   1.055252
# 2                         0                   0.109713   0.972667
# 5                         0                   0.109713   0.931374
# 1                         0                   0.109713   0.766205
# 6                         0                   0.109713   0.394572
# 15                        0                   0.109713   0.394572
# 3                         0                   0.109713   0.146818
# 20                        0                   0.109713  -0.018352
# 18                        0                   0.109713  -0.018352
# 17                        0                   0.109713  -0.059645
# 24                        0                   0.109713  -0.142230
# 26                        0                   0.109713  -0.389984
# 12                        0                   0.109713  -0.555154
# 14                        0                  -2.852549  -0.596447
# 9                         0                   0.109713  -0.596447
# 16                        0                   0.109713  -0.679032
# 25                        0                   0.109713  -0.926786
# 11                        0                   0.109713  -1.091956
# 10                        0                   0.109713  -1.091956
# 7                         0                   0.109713  -1.257126
# 8                         0                   0.109713  -1.835220
#
#     promotion_flag
# 23       -0.277555
# 21       -0.277555
# 4        -0.277555
# 0        -0.277555
# 22        3.469443
# 19        3.469443
# 2        -0.277555
# 5        -0.277555
# 1        -0.277555
# 6        -0.277555
# 15       -0.277555
# 3        -0.277555
# 20       -0.277555
# 18       -0.277555
# 17       -0.277555
# 24       -0.277555
# 26       -0.277555
# 12       -0.277555
# 14       -0.277555
# 9        -0.277555
# 16       -0.277555
# 25       -0.277555
# 11       -0.277555
# 10       -0.277555
# 7        -0.277555
# 8        -0.277555
# pref_weights = [0.03711609901428053, 0.043903480709077555, 0.0320492819597176, 0.03518173572477866, 0.1407249752077973, 0.1407249752077973, 0.05368597976621425, 0.05671940300006714, 0.07066668545777242, 0.10429732948863464, 0.10210982175607189, 0.27599816041766473, 0.1258858398980091, 0.15588024587207722, 0.2121436686765426, 0.2470489152130064, 0.6009566958706394, 0.16339534601371491, 0.30209593520106365, 0.19237392599987152, 0.18864544136707603, 0.7019845226018548, 0.4313057055489549, 0.8562585815349659, 0.5373636360406425, 0.7745397248843294]
# expected_rev = -0.5503323263621045
# the expected_rev for idx=26 is -0.5503323263621045
# new_assortment:     prop_starrating  prop_review_score  prop_brand_bool  prop_location_score  \
# 23         1.471523           0.862323        -2.058406             1.284832
# 21         1.471523           0.862323         0.467820             1.284832
# 4          0.101484           0.862323         0.467820            -1.606040
# 0          0.101484          -0.301813         0.467820            -1.606040
# 22         1.471523          -0.301813         0.467820             1.284832
# 19         1.471523          -0.301813         0.467820             1.284832
# 2          0.101484           0.862323         0.467820            -0.642416
# 5          0.101484           0.862323         0.467820            -0.642416
# 1          0.101484           0.862323         0.467820            -0.642416
# 6          0.101484          -0.301813         0.467820             0.321208
# 15         0.101484          -0.301813         0.467820            -0.642416
# 3          1.471523           0.862323         0.467820            -1.606040
# 18         0.101484          -1.465949         0.467820            -0.642416
# 20         0.101484          -1.465949        -2.058406             1.284832
# 17         0.101484           0.862323         0.467820            -0.642416
# 24         0.101484           0.862323         0.467820             1.284832
# 26         1.471523           0.862323         0.467820             1.284832
# 12        -1.268554          -0.301813        -2.058406             0.321208
# 14        -1.268554           0.862323         0.467820            -0.642416
# 9         -1.268554          -1.465949         0.467820            -0.642416
# 16        -1.268554          -0.301813        -2.058406            -0.642416
# 25         0.101484           0.862323         0.467820             1.284832
# 11        -1.268554          -0.301813         0.467820             0.321208
# 10         0.101484           0.862323         0.467820             0.321208
# 7         -1.268554          -0.301813         0.467820             0.321208
# 8         -1.268554          -1.465949        -2.058406            -0.642416
# 13        -1.268554          -2.630085         0.467820            -0.642416
#
#     prop_accesibility_score  prop_log_historical_price  price_usd  \
# 23                        0                   0.109713   1.509469
# 21                        0                   3.071976   1.426884
# 4                         0                   0.109713   1.344299
# 0                         0                   0.109713   1.179129
# 22                        0                   0.109713   1.055252
# 19                        0                   0.109713   1.055252
# 2                         0                   0.109713   0.972667
# 5                         0                   0.109713   0.931374
# 1                         0                   0.109713   0.766205
# 6                         0                   0.109713   0.394572
# 15                        0                   0.109713   0.394572
# 3                         0                   0.109713   0.146818
# 18                        0                   0.109713  -0.018352
# 20                        0                   0.109713  -0.018352
# 17                        0                   0.109713  -0.059645
# 24                        0                   0.109713  -0.142230
# 26                        0                   0.109713  -0.389984
# 12                        0                   0.109713  -0.555154
# 14                        0                  -2.852549  -0.596447
# 9                         0                   0.109713  -0.596447
# 16                        0                   0.109713  -0.679032
# 25                        0                   0.109713  -0.926786
# 11                        0                   0.109713  -1.091956
# 10                        0                   0.109713  -1.091956
# 7                         0                   0.109713  -1.257126
# 8                         0                   0.109713  -1.835220
# 13                        0                  -2.852549  -1.917805
#
#     promotion_flag
# 23       -0.277555
# 21       -0.277555
# 4        -0.277555
# 0        -0.277555
# 22        3.469443
# 19        3.469443
# 2        -0.277555
# 5        -0.277555
# 1        -0.277555
# 6        -0.277555
# 15       -0.277555
# 3        -0.277555
# 18       -0.277555
# 20       -0.277555
# 17       -0.277555
# 24       -0.277555
# 26       -0.277555
# 12       -0.277555
# 14       -0.277555
# 9        -0.277555
# 16       -0.277555
# 25       -0.277555
# 11       -0.277555
# 10       -0.277555
# 7        -0.277555
# 8        -0.277555
# 13       -0.277555
# pref_weights = [0.03711609901428053, 0.043903480709077555, 0.0320492819597176, 0.03518173572477866, 0.1407249752077973, 0.1407249752077973, 0.05368597976621425, 0.05671940300006714, 0.07066668545777242, 0.10429732948863464, 0.10210982175607189, 0.27599816041766473, 0.15588024587207722, 0.1258858398980091, 0.2121436686765426, 0.2470489152130064, 0.6009566958706394, 0.16339534601371491, 0.30209593520106365, 0.19237392599987152, 0.18864544136707603, 0.7019845226018548, 0.4313057055489549, 0.8562585815349659, 0.5373636360406425, 0.7745397248843294, 1.199657046331662]
# expected_rev = -0.7371195457058468
# the expected_rev for idx=27 is -0.7371195457058468
# include the first 9 hotels, the optimal revenue is 0.40938715724160935
# {'9': 0.40938715724160935,
#  '10': 0.40848623666253775,
#  '11': 0.407704397929613,
#  '8': 0.3930148424122737,
#  '12': 0.37330490076290734,
#  '7': 0.37242989807467236,
#  '13': 0.35108648403069564,
#  '6': 0.34989069856367533,
#  '14': 0.32683825201040306,
#  '15': 0.2951462827695272,
#  '5': 0.2728823260759068,
#  '16': 0.2570206567285121,
#  '4': 0.1769982807452966,
#  '3': 0.14532306066883105,
#  '17': 0.14382955981037535,
#  '18': 0.1120910444524027,
#  '2': 0.10977669678125837,
#  '19': 0.057215590760132475,
#  '1': 0.05402055923960557,
#  '20': 0.026492688088797237,
#  '21': -0.004592374996262746,
#  '22': -0.13449191559015425,
#  '23': -0.21075559880461003,
#  '24': -0.3310740692723555,
#  '25': -0.4041629154117906,
#  '26': -0.5503323263621045,
#  '27': -0.7371195457058468}

# %%
# re-compute the expected revenue without normalization
S1 = pd.read_csv("data1.csv").sort_values(by="price_usd", ascending=False)

S1 = S1.nlargest(1, "price_usd")
print(S1)
expected_rev(S1,betas)
betas = [-1.7467,  0.408127, 0.108755, 0.101379, 0.021997, 0.043445,  -0.066872, -1.331102, 0.159767] # from normalzied data
x_aug_1 = [1,4,5,0,3,0,5,158,0]
price1 = 158 
v1 = np.exp(np.dot(x_aug_1, betas))
rev1 = price1* v1 / (1+v1)
print(f"pref_weight = {v1}, expected rev = {rev1}")
# Out:
#     prop_starrating  prop_review_score  prop_brand_bool  prop_location_score  \
# 23                4                  5                0                    3
#
#     prop_accesibility_score  prop_log_historical_price  price_usd  \
# 23                        0                          5        158
#
#     promotion_flag
# 23               0
# pref_weights = [5.3920549007725585e-92]
# pref_weight = 5.3920549007725585e-92, expected rev = 8.519446743220642e-90

# %% [markdown]
# ### Simple test for problem 2

# %%
# simple verification , with normalized data
# if the assortment only include the hotel with the highest price
x1 = [1.471523 ,0.862323, -2.058406, 1.284832 , 0, 0.109713, 1.509469,  -0.277555  ]
x1_aug_1 = [1, 1.471523 ,0.862323, -2.058406, 1.284832 , 0, 0.109713, 1.509469,  -0.277555  ]
price1 = 1.509469  
v1 = np.exp(np.dot(x1_aug_1, betas))
rev1 = 1.509469 * v1 / (1+v1)
print(f"pref_weight = {v1}, expected rev = {rev1}")

# it the assortment include the hotels with the first and second highest prices.
x2 = [1.471523, 0.862323, 0.467820, 1.284832, 0, 3.071976, 1.426884,-0.277555 ]
x2_aug_1 = [1, 1.471523, 0.862323, 0.467820, 1.284832, 0, 3.071976, 1.426884,-0.277555]
v2 = np.exp(np.dot(x2_aug_1, betas))
price2 = 1.426884 
rev12 = price1*v1 / (1+v1+v2) + price2*v2 / (1+v1+v2)
print(f"pref_weight_1 = {v1},{v2}, expected rev = {rev12}")
# Out:
# pref_weight = 0.037116095987600885, expected rev = 0.054020563860748064
# pref_weight_1 = 0.037116095987600885,0.04390348064174514, expected rev = 0.10977670796336833

# %% [markdown]
# # Problem 3
#
# Assumptions:
# * provide all the hotels in data1.csv to customers.
#
# Expected revenue if the customer is provided by assortment 1:
#
# $R(S_1) = \sum_{j \in S_1} p_j P(j|S_1) = \sum_{j \in S} p_j \frac{e^{\beta_0 + \sum_{i=1,..8}\beta_i x_ji}}{1+ \sum_{i \in S} e^{\beta * x}}$
#
# $\argmax R(S)$

# %% [markdown]
# **Make sure the order and number of features match your data correctly.**

# %%
import pandas as pd
hotel_prices = pd.read_csv('data1.csv')['price_usd']
initial_prices=hotel_prices.to_numpy() # (num_hotels, )
print(f"intial_price.shape={initial_prices.shape}")

from scipy.optimize import minimize
import numpy as np
# Revenue function, i.t.o. price_usd only
def neg_expected_revenue_p3_d1(prices):
    """
    Inputs:
        prices (List): of size # of hotels in data1.csv
    """
    df = pd.read_csv('data1.csv')
    num_hotels = df.shape[0]
    # print(f"num_hotels={num_hotels}")
    betas = np.array([-1.7467,  0.408127, 0.108755, 0.101379, 0.021997, 0.043445,  -0.066872, -1.331102, 0.159767]) # (num_features,)
    # print(f"betas.shape()={betas.shape}")
    values = df.to_numpy() # shape(num_hotels, num_features), augmented by 1.
    values = np.hstack((np.array([[1] for i in range(num_hotels)]),values))
    # print(f"values.shape()={values.shape}")
    utilities = values[:, :7] @ betas[:7] + betas[7] * prices + betas[8]*values[:,8] # (num_hotels,)
    # print(f"utilities={utilities.shape}")
    exp_utilities = np.exp(utilities)
    denom = np.exp(betas[0]) + np.sum(exp_utilities) # use beta_0 or 1???
    choice_probs = exp_utilities/denom
    revenue = np.sum(prices * choice_probs)
    return -revenue

neg_expected_revenue_p3_d1(initial_prices)
# Out:
# intial_price.shape=(27,)
# -8.571124856150396e-42

# %%
df = pd.read_csv('data1.csv')
num_hotels = df.shape[0]
price_bounds_d1 = [(1,500)] * num_hotels
# Optimize
result = minimize(neg_expected_revenue_p3_d1,initial_prices, bounds=price_bounds_d1, method='L-BFGS-B')
optimal_prices=result.x
optimal_prices= np.sort(optimal_prices)
max_revenue = -result.fun
# Print results
print(f"optimal prices = {np.round(optimal_prices,2)}")
print(f"max revenue = {max_revenue:.2f}")
# Out:
# optimal prices = [ 75.  77.  91.  95.  95.  99. 105. 107. 107. 108. 112. 118. 120. 121.
#  121. 125. 131. 131. 140. 144. 145. 147. 147. 150. 154. 156. 158.]
# max revenue = 0.00

# %%
import pandas as pd
import numpy as np
from scipy.optimize import minimize

def neg_expected_revenue_p3_d1(prices):
    """
    Computes the negative expected revenue under MNL model given hotel prices.
    
    Inputs:
        prices (np.array): array of prices (num_hotels,)
        
    Returns:
        Negative expected revenue (scalar)
    """
    df = pd.read_csv('data1.csv')
    num_hotels = df.shape[0]
    
    # Beta coefficients (assumed order matches feature columns)
    betas = np.array([
        -1.7467,     # intercept
         0.408127,   # star rating
         0.108755,   # review score
         0.101379,   # hotel brand
         0.021997,   # location score
         0.043445,   # accessibility score
        -0.066872,   # historical price
        -1.331102,   # displayed price
         0.159767    # promotion flag
    ])
    
    # Extract features from the dataframe
    features = df[['prop_starrating', 'prop_review_score', 'prop_brand_bool',
                   'prop_location_score', 'prop_accesibility_score',
                   'prop_log_historical_price', 'price_usd', 'promotion_flag']].to_numpy()
    
    # Construct feature matrix (with intercept and updated price)
    X = np.hstack((
        np.ones((num_hotels, 1)),             # Intercept
        features[:, :6],                      # features (6 cols before price)
        prices.reshape(-1, 1),                # current prices as a variable
        features[:, 7].reshape(-1, 1)         # promotion flag
    ))
    print("x:",X)
    # Compute utility and choice probability
    utilities = X @ betas
    print("utilities:",utilities)
    exp_utilities = np.exp(utilities)
    denom =  np.sum(exp_utilities) # ???
    choice_probs = exp_utilities / denom

    # Expected revenue = sum(price_j * P(choice_j))
    revenue = np.sum(prices * choice_probs)
    
    return -revenue  # we minimize the negative to maximize revenue

# Load initial prices
initial_prices = pd.read_csv('data1.csv')['price_usd'].to_numpy()

# Set bounds: assume reasonable prices in the range [20, 500]
bounds = [(20, 500)] * len(initial_prices)

# Run optimization
result = minimize(neg_expected_revenue_p3_d1,
                  x0=initial_prices,
                  bounds=bounds,
                  method='L-BFGS-B')

# Print results
if result.success:
    optimal_prices = result.x
    print("Optimal prices found!")
    print("optimal_prices:", np.sort(optimal_prices))
    print("max revenue:", -result.fun)
else:
    print("Optimization failed.")
    print(result.message)
# Out:
# x: [[  1.   3.   4.   1.   0.   0.   5. 150.   0.]
#  [  1.   3.   5.   1.   1.   0.   5. 140.   0.]
#  [  1.   3.   5.   1.   1.   0.   5. 145.   0.]
#  [  1.   4.   5.   1.   0.   0.   5. 125.   0.]
#  [  1.   3.   5.   1.   0.   0.   5. 154.   0.]
#  [  1.   3.   5.   1.   1.   0.   5. 144.   0.]
#  [  1.   3.   4.   1.   2.   0.   5. 131.   0.]
#  [  1.   2.   4.   1.   2.   0.   5.  91.   0.]
#  [  1.   2.   3.   0.   1.   0.   5.  77.   0.]
#  [  1.   2.   3.   1.   1.   0.   5. 107.   0.]
#  [  1.   3.   5.   1.   2.   0.   5.  95.   0.]
#  [  1.   2.   4.   1.   2.   0.   5.  95.   0.]
#  [  1.   2.   4.   0.   2.   0.   5. 108.   0.]
#  [  1.   2.   2.   1.   1.   0.   4.  75.   0.]
#  [  1.   2.   5.   1.   1.   0.   4. 107.   0.]
#  [  1.   3.   4.   1.   1.   0.   5. 131.   0.]
#  [  1.   2.   4.   0.   1.   0.   5. 105.   0.]
#  [  1.   3.   5.   1.   1.   0.   5. 120.   0.]
#  [  1.   3.   3.   1.   1.   0.   5. 121.   0.]
#  [  1.   4.   4.   1.   3.   0.   5. 147.   1.]
#  [  1.   3.   3.   0.   3.   0.   5. 121.   0.]
#  [  1.   4.   5.   1.   3.   0.   6. 156.   0.]
#  [  1.   4.   4.   1.   3.   0.   5. 147.   1.]
#  [  1.   4.   5.   0.   3.   0.   5. 158.   0.]
#  [  1.   3.   5.   1.   3.   0.   5. 118.   0.]
#  [  1.   3.   5.   1.   3.   0.   5.  99.   0.]
#  [  1.   4.   5.   1.   3.   0.   5. 112.   0.]]
# utilities: [-199.98558  -186.543808 -193.199318 -166.191148 -205.201233 -191.868216
#  -174.650648 -121.814695 -103.411398 -143.243079 -126.622221 -127.139103
#  -144.544808 -100.689698 -142.958697 -174.672645 -140.573499 -159.921768
#  -161.47038  -195.358389 -161.527765 -207.456191 -195.358389 -210.152902
#  -157.21557  -131.924632 -148.820831]
# x: [[  1.           3.           4.           1.           0.
#     0.           5.         150.00000001   0.        ]
#  [  1.           3.           5.           1.           1.
#     0.           5.         140.           0.        ]
#  [  1.           3.           5.           1.           1.
#     0.           5.         145.           0.        ]
#  [  1.           4.           5.           1.           0.
#     0.           5.         125.           0.        ]
#  [  1.           3.           5.           1.           0.
#     0.           5.         154.           0.        ]
#  [  1.           3.           5.           1.           1.
#     0.           5.         144.           0.        ]
#  [  1.           3.           4.           1.           2.
#     0.           5.         131.           0.        ]
#  [  1.           2.           4.           1.           2.
#     0.           5.          91.           0.        ]
#  [  1.           2.           3.           0.           1.
#     0.           5.          77.           0.        ]
#  [  1.           2.           3.           1.           1.
#     0.           5.         107.           0.        ]
#  [  1.           3.           5.           1.           2.
#     0.           5.          95.           0.        ]
#  [  1.           2.           4.           1.           2.
#     0.           5.          95.           0.        ]
#  [  1.           2.           4.           0.           2.
#     0.           5.         108.           0.        ]
#  [  1.           2.           2.           1.           1.
#     0.           4.          75.           0.        ]
#  [  1.           2.           5.           1.           1.
#     0.           4.         107.           0.        ]
#  [  1.           3.           4.           1.           1.
#     0.           5.         131.           0.        ]
#  [  1.           2.           4.           0.           1.
#     0.           5.         105.           0.        ]
#  [  1.           3.           5.           1.           1.
#     0.           5.         120.           0.        ]
#  [  1.           3.           3.           1.           1.
#     0.           5.         121.           0.        ]
#  [  1.           4.           4.           1.           3.
#     0.           5.         147.           1.        ]
#  [  1.           3.           3.           0.           3.
#     0.           5.         121.           0.        ]
#  [  1.           4.           5.           1.           3.
#     0.           6.         156.           0.        ]
#  [  1.           4.           4.           1.           3.
#     0.           5.         147.           1.        ]
#  [  1.           4.           5.           0.           3.
#     0.           5.         158.           0.        ]
#  [  1.           3.           5.           1.           3.
#     0.           5.         118.           0.        ]
#  [  1.           3.           5.           1.           3.
#     0.           5.          99.           0.        ]
#  [  1.           4.           5.           1.           3.
#     0.           5.         112.           0.        ]]
# utilities: [-199.98558001 -186.543808   -193.199318   -166.191148   -205.201233
#  -191.868216   -174.650648   -121.814695   -103.411398   -143.243079
#  -126.622221   -127.139103   -144.544808   -100.689698   -142.958697
#  -174.672645   -140.573499   -159.921768   -161.47038    -195.358389
#  -161.527765   -207.456191   -195.358389   -210.152902   -157.21557
#  -131.924632   -148.820831  ]
# x: [[  1.           3.           4.           1.           0.
#     0.           5.         150.           0.        ]
#  [  1.           3.           5.           1.           1.
#     0.           5.         140.00000001   0.        ]
#  [  1.           3.           5.           1.           1.
#     0.           5.         145.           0.        ]
#  [  1.           4.           5.           1.           0.
#     0.           5.         125.           0.        ]
#  [  1.           3.           5.           1.           0.
#     0.           5.         154.           0.        ]
#  [  1.           3.           5.           1.           1.
#     0.           5.         144.           0.        ]
#  [  1.           3.           4.           1.           2.
#     0.           5.         131.           0.        ]
#  [  1.           2.           4.           1.           2.
#     0.           5.          91.           0.        ]
#  [  1.           2.           3.           0.           1.
#     0.           5.          77.           0.        ]
#  [  1.           2.           3.           1.           1.
#     0.           5.         107.           0.        ]
#  [  1.           3.           5.           1.           2.
#     0.           5.          95.           0.        ]
#  [  1.           2.           4.           1.           2.
#     0.           5.          95.           0.        ]
#  [  1.           2.           4.           0.           2.
#     0.           5.         108.           0.        ]
#  [  1.           2.           2.           1.           1.
#     0.           4.          75.           0.        ]
#  [  1.           2.           5.           1.           1.
#     0.           4.         107.           0.        ]
#  [  1.           3.           4.           1.           1.
#     0.           5.         131.           0.        ]
#  [  1.           2.           4.           0.           1.
#     0.           5.         105.           0.        ]
#  [  1.           3.           5.           1.           1.
#     0.           5.         120.           0.        ]
#  [  1.           3.           3.           1.           1.
#     0.           5.         121.           0.        ]
#  [  1.           4.           4.           1.           3.
#     0.           5.         147.           1.        ]
#  [  1.           3.           3.           0.           3.
#     0.           5.         121.           0.        ]
#  [  1.           4.           5.           1.           3.
#     0.           6.         156.           0.        ]
#  [  1.           4.           4.           1.           3.
#     0.           5.         147.           1.        ]
#  [  1.           4.           5.           0.           3.
#     0.           5.         158.           0.        ]
#  [  1.           3.           5.           1.           3.
#     0.           5.         118.           0.        ]
#  [  1.           3.           5.           1.           3.
#     0.           5.          99.           0.        ]
#  [  1.           4.           5.           1.           3.
#     0.           5.         112.           0.        ]]
# utilities: [-199.98558    -186.54380801 -193.199318   -166.191148   -205.201233
#  -191.868216   -174.650648   -121.814695   -103.411398   -143.243079
#  -126.622221   -127.139103   -144.544808   -100.689698   -142.958697
#  -174.672645   -140.573499   -159.921768   -161.47038    -195.358389
#  -161.527765   -207.456191   -195.358389   -210.152902   -157.21557
#  -131.924632   -148.820831  ]
# x: [[  1.           3.           4.           1.           0.
#     0.           5.         150.           0.        ]
#  [  1.           3.           5.           1.           1.
#     0.           5.         140.           0.        ]
#  [  1.           3.           5.           1.           1.
#     0.           5.         145.00000001   0.        ]
#  [  1.           4.           5.           1.           0.
#     0.           5.         125.           0.        ]
#  [  1.           3.           5.           1.           0.
#     0.           5.         154.           0.        ]
#  [  1.           3.           5.           1.           1.
#     0.           5.         144.           0.        ]
#  [  1.           3.           4.           1.           2.
#     0.           5.         131.           0.        ]
#  [  1.           2.           4.           1.           2.
#     0.           5.          91.           0.        ]
#  [  1.           2.           3.           0.           1.
#     0.           5.          77.           0.        ]
#  [  1.           2.           3.           1.           1.
#     0.           5.         107.           0.        ]
#  [  1.           3.           5.           1.           2.
#     0.           5.          95.           0.        ]
#  [  1.           2.           4.           1.           2.
#     0.           5.          95.           0.        ]
#  [  1.           2.           4.           0.           2.
#     0.           5.         108.           0.        ]
#  [  1.           2.           2.           1.           1.
#     0.           4.          75.           0.        ]
#  [  1.           2.           5.           1.           1.
#     0.           4.         107.           0.        ]
#  [  1.           3.           4.           1.           1.
#     0.           5.         131.           0.        ]
#  [  1.           2.           4.           0.           1.
#     0.           5.         105.           0.        ]
#  [  1.           3.           5.           1.           1.
#     0.           5.         120.           0.        ]
#  [  1.           3.           3.           1.           1.
#     0.           5.         121.           0.        ]
#  [  1.           4.           4.           1.           3.
#     0.           5.         147.           1.        ]
#  [  1.           3.           3.           0.           3.
#     0.           5.         121.           0.        ]
#  [  1.           4.           5.           1.           3.
#     0.           6.         156.           0.        ]
#  [  1.           4.           4.           1.           3.
#     0.           5.         147.           1.        ]
#  [  1.           4.           5.           0.           3.
#     0.           5.         158.           0.        ]
#  [  1.           3.           5.           1.           3.
#     0.           5.         118.           0.        ]
#  [  1.           3.           5.           1.           3.
#     0.           5.          99.           0.        ]
#  [  1.           4.           5.           1.           3.
#     0.           5.         112.           0.        ]]
# utilities: [-199.98558    -186.543808   -193.19931801 -166.191148   -205.201233
#  -191.868216   -174.650648   -121.814695   -103.411398   -143.243079
#  -126.622221   -127.139103   -144.544808   -100.689698   -142.958697
#  -174.672645   -140.573499   -159.921768   -161.47038    -195.358389
#  -161.527765   -207.456191   -195.358389   -210.152902   -157.21557
#  -131.924632   -148.820831  ]
# x: [[  1.           3.           4.           1.           0.
#     0.           5.         150.           0.        ]
#  [  1.           3.           5.           1.           1.
#     0.           5.         140.           0.        ]
#  [  1.           3.           5.           1.           1.
#     0.           5.         145.           0.        ]
#  [  1.           4.           5.           1.           0.
#     0.           5.         125.00000001   0.        ]
#  [  1.           3.           5.           1.           0.
#     0.           5.         154.           0.        ]
#  [  1.           3.           5.           1.           1.
#     0.           5.         144.           0.        ]
#  [  1.           3.           4.           1.           2.
#     0.           5.         131.           0.        ]
#  [  1.           2.           4.           1.           2.
#     0.           5.          91.           0.        ]
#  [  1.           2.           3.           0.           1.
#     0.           5.          77.           0.        ]
#  [  1.           2.           3.           1.           1.
#     0.           5.         107.           0.        ]
#  [  1.           3.           5.           1.           2.
#     0.           5.          95.           0.        ]
#  [  1.           2.           4.           1.           2.
#     0.           5.          95.           0.        ]
#  [  1.           2.           4.           0.           2.
#     0.           5.         108.           0.        ]
#  [  1.           2.           2.           1.           1.
#     0.           4.          75.           0.        ]
#  [  1.           2.           5.           1.           1.
#     0.           4.         107.           0.        ]
#  [  1.           3.           4.           1.           1.
#     0.           5.         131.           0.        ]
#  [  1.           2.           4.           0.           1.
#     0.           5.         105.           0.        ]
#  [  1.           3.           5.           1.           1.
#     0.           5.         120.           0.        ]
#  [  1.           3.           3.           1.           1.
#     0.           5.         121.           0.        ]
#  [  1.           4.           4.           1.           3.
#     0.           5.         147.           1.        ]
#  [  1.           3.           3.           0.           3.
#     0.           5.         121.           0.        ]
#  [  1.           4.           5.           1.           3.
#     0.           6.         156.           0.        ]
#  [  1.           4.           4.           1.           3.
#     0.           5.         147.           1.        ]
#  [  1.           4.           5.           0.           3.
#     0.           5.         158.           0.        ]
#  [  1.           3.           5.           1.           3.
#     0.           5.         118.           0.        ]
#  [  1.           3.           5.           1.           3.
#     0.           5.          99.           0.        ]
#  [  1.           4.           5.           1.           3.
#     0.           5.         112.           0.        ]]
# utilities: [-199.98558    -186.543808   -193.199318   -166.19114801 -205.201233
#  -191.868216   -174.650648   -121.814695   -103.411398   -143.243079
#  -126.622221   -127.139103   -144.544808   -100.689698   -142.958697
#  -174.672645   -140.573499   -159.921768   -161.47038    -195.358389
#  -161.527765   -207.456191   -195.358389   -210.152902   -157.21557
#  -131.924632   -148.820831  ]
# x: [[  1.           3.           4.           1.           0.
#     0.           5.         150.           0.        ]
#  [  1.           3.           5.           1.           1.
#     0.           5.         140.           0.        ]
#  [  1.           3.           5.           1.           1.
#     0.           5.         145.           0.        ]
#  [  1.           4.           5.           1.           0.
#     0.           5.         125.           0.        ]
#  [  1.           3.           5.           1.           0.
#     0.           5.         154.00000001   0.        ]
#  [  1.           3.           5.           1.           1.
#     0.           5.         144.           0.        ]
#  [  1.           3.           4.           1.           2.
#     0.           5.         131.           0.        ]
#  [  1.           2.           4.           1.           2.
#     0.           5.          91.           0.        ]
#  [  1.           2.           3.           0.           1.
#     0.           5.          77.           0.        ]
#  [  1.           2.           3.           1.           1.
#     0.           5.         107.           0.        ]
#  [  1.           3.           5.           1.           2.
#     0.           5.          95.           0.        ]
#  [  1.           2.           4.           1.           2.
#     0.           5.          95.           0.        ]
#  [  1.           2.           4.           0.           2.
#     0.           5.         108.           0.        ]
#  [  1.           2.           2.           1.           1.
#     0.           4.          75.           0.        ]
#  [  1.           2.           5.           1.           1.
#     0.           4.         107.           0.        ]
#  [  1.           3.           4.           1.           1.
#     0.           5.         131.           0.        ]
#  [  1.           2.           4.           0.           1.
#     0.           5.         105.           0.        ]
#  [  1.           3.           5.           1.           1.
#     0.           5.         120.           0.        ]
#  [  1.           3.           3.           1.           1.
#     0.           5.         121.           0.        ]
#  [  1.           4.           4.           1.           3.
#     0.           5.         147.           1.        ]
#  [  1.           3.           3.           0.           3.
#     0.           5.         121.           0.        ]
#  [  1.           4.           5.           1.           3.
#     0.           6.         156.           0.        ]
#  [  1.           4.           4.           1.           3.
#     0.           5.         147.           1.        ]
#  [  1.           4.           5.           0.           3.
#     0.           5.         158.           0.        ]
#  [  1.           3.           5.           1.           3.
#     0.           5.         118.           0.        ]
#  [  1.           3.           5.           1.           3.
#     0.           5.          99.           0.        ]
#  [  1.           4.           5.           1.           3.
#     0.           5.         112.           0.        ]]
# utilities: [-199.98558    -186.543808   -193.199318   -166.191148   -205.20123301
#  -191.868216   -174.650648   -121.814695   -103.411398   -143.243079
#  -126.622221   -127.139103   -144.544808   -100.689698   -142.958697
#  -174.672645   -140.573499   -159.921768   -161.47038    -195.358389
#  -161.527765   -207.456191   -195.358389   -210.152902   -157.21557
#  -131.924632   -148.820831  ]
# x: [[  1.           3.           4.           1.           0.
#     0.           5.         150.           0.        ]
#  [  1.           3.           5.           1.           1.
#     0.           5.         140.           0.        ]
#  [  1.           3.           5.           1.           1.
#     0.           5.         145.           0.        ]
#  [  1.           4.           5.           1.           0.
#     0.           5.         125.           0.        ]
#  [  1.           3.           5.           1.           0.
#     0.           5.         154.           0.        ]
#  [  1.           3.           5.           1.           1.
#     0.           5.         144.00000001   0.        ]
#  [  1.           3.           4.           1.           2.
#     0.           5.         131.           0.        ]
#  [  1.           2.           4.           1.           2.
#     0.           5.          91.           0.        ]
#  [  1.           2.           3.           0.           1.
#     0.           5.          77.           0.        ]
#  [  1.           2.           3.           1.           1.
#     0.           5.         107.           0.        ]
#  [  1.           3.           5.           1.           2.
#     0.           5.          95.           0.        ]
#  [  1.           2.           4.           1.           2.
#     0.           5.          95.           0.        ]
#  [  1.           2.           4.           0.           2.
#     0.           5.         108.           0.        ]
#  [  1.           2.           2.           1.           1.
#     0.           4.          75.           0.        ]
#  [  1.           2.           5.           1.           1.
#     0.           4.         107.           0.        ]
#  [  1.           3.           4.           1.           1.
#     0.           5.         131.           0.        ]
#  [  1.           2.           4.           0.           1.
#     0.           5.         105.           0.        ]
#  [  1.           3.           5.           1.           1.
#     0.           5.         120.           0.        ]
#  [  1.           3.           3.           1.           1.
#     0.           5.         121.           0.        ]
#  [  1.           4.           4.           1.           3.
#     0.           5.         147.           1.        ]
#  [  1.           3.           3.           0.           3.
#     0.           5.         121.           0.        ]
#  [  1.           4.           5.           1.           3.
#     0.           6.         156.           0.        ]
#  [  1.           4.           4.           1.           3.
#     0.           5.         147.           1.        ]
#  [  1.           4.           5.           0.           3.
#     0.           5.         158.           0.        ]
#  [  1.           3.           5.           1.           3.
#     0.           5.         118.           0.        ]
#  [  1.           3.           5.           1.           3.
#     0.           5.          99.           0.        ]
#  [  1.           4.           5.           1.           3.
#     0.           5.         112.           0.        ]]
# utilities: [-199.98558    -186.543808   -193.199318   -166.191148   -205.201233
#  -191.86821601 -174.650648   -121.814695   -103.411398   -143.243079
#  -126.622221   -127.139103   -144.544808   -100.689698   -142.958697
#  -174.672645   -140.573499   -159.921768   -161.47038    -195.358389
#  -161.527765   -207.456191   -195.358389   -210.152902   -157.21557
#  -131.924632   -148.820831  ]
# x: [[  1.           3.           4.           1.           0.
#     0.           5.         150.           0.        ]
#  [  1.           3.           5.           1.           1.
#     0.           5.         140.           0.        ]
#  [  1.           3.           5.           1.           1.
#     0.           5.         145.           0.        ]
#  [  1.           4.           5.           1.           0.
#     0.           5.         125.           0.        ]
#  [  1.           3.           5.           1.           0.
#     0.           5.         154.           0.        ]
#  [  1.           3.           5.           1.           1.
#     0.           5.         144.           0.        ]
#  [  1.           3.           4.           1.           2.
#     0.           5.         131.00000001   0.        ]
#  [  1.           2.           4.           1.           2.
#     0.           5.          91.           0.        ]
#  [  1.           2.           3.           0.           1.
#     0.           5.          77.           0.        ]
#  [  1.           2.           3.           1.           1.
#     0.           5.         107.           0.        ]
#  [  1.           3.           5.           1.           2.
#     0.           5.          95.           0.        ]
#  [  1.           2.           4.           1.           2.
#     0.           5.          95.           0.        ]
#  [  1.           2.           4.           0.           2.
#     0.           5.         108.           0.        ]
#  [  1.           2.           2.           1.           1.
#     0.           4.          75.           0.        ]
#  [  1.           2.           5.           1.           1.
#     0.           4.         107.           0.        ]
#  [  1.           3.           4.           1.           1.
#     0.           5.         131.           0.        ]
#  [  1.           2.           4.           0.           1.
#     0.           5.         105.           0.        ]
#  [  1.           3.           5.           1.           1.
#     0.           5.         120.           0.        ]
#  [  1.           3.           3.           1.           1.
#     0.           5.         121.           0.        ]
#  [  1.           4.           4.           1.           3.
#     0.           5.         147.           1.        ]
#  [  1.           3.           3.           0.           3.
#     0.           5.         121.           0.        ]
#  [  1.           4.           5.           1.           3.
#     0.           6.         156.           0.        ]
#  [  1.           4.           4.           1.           3.
#     0.           5.         147.           1.        ]
#  [  1.           4.           5.           0.           3.
#     0.           5.         158.           0.        ]
#  [  1.           3.           5.           1.           3.
#     0.           5.         118.           0.        ]
#  [  1.           3.           5.           1.           3.
#     0.           5.          99.           0.        ]
#  [  1.           4.           5.           1.           3.
#     0.           5.         112.           0.        ]]
# utilities: [-199.98558    -186.543808   -193.199318   -166.191148   -205.201233
#  -191.868216   -174.65064801 -121.814695   -103.411398   -143.243079
#  -126.622221   -127.139103   -144.544808   -100.689698   -142.958697
#  -174.672645   -140.573499   -159.921768   -161.47038    -195.358389
#  -161.527765   -207.456191   -195.358389   -210.152902   -157.21557
#  -131.924632   -148.820831  ]
# x: [[  1.           3.           4.           1.           0.
#     0.           5.         150.           0.        ]
#  [  1.           3.           5.           1.           1.
#     0.           5.         140.           0.        ]
#  [  1.           3.           5.           1.           1.
#     0.           5.         145.           0.        ]
#  [  1.           4.           5.           1.           0.
#     0.           5.         125.           0.        ]
#  [  1.           3.           5.           1.           0.
#     0.           5.         154.           0.        ]
#  [  1.           3.           5.           1.           1.
#     0.           5.         144.           0.        ]
#  [  1.           3.           4.           1.           2.
#     0.           5.         131.           0.        ]
#  [  1.           2.           4.           1.           2.
#     0.           5.          91.00000001   0.        ]
#  [  1.           2.           3.           0.           1.
#     0.           5.          77.           0.        ]
#  [  1.           2.           3.           1.           1.
#     0.           5.         107.           0.        ]
#  [  1.           3.           5.           1.           2.
#     0.           5.          95.           0.        ]
#  [  1.           2.           4.           1.           2.
#     0.           5.          95.           0.        ]
#  [  1.           2.           4.           0.           2.
#     0.           5.         108.           0.        ]
#  [  1.           2.           2.           1.           1.
#     0.           4.          75.           0.        ]
#  [  1.           2.           5.           1.           1.
#     0.           4.         107.           0.        ]
#  [  1.           3.           4.           1.           1.
#     0.           5.         131.           0.        ]
#  [  1.           2.           4.           0.           1.
#     0.           5.         105.           0.        ]
#  [  1.           3.           5.           1.           1.
#     0.           5.         120.           0.        ]
#  [  1.           3.           3.           1.           1.
#     0.           5.         121.           0.        ]
#  [  1.           4.           4.           1.           3.
#     0.           5.         147.           1.        ]
#  [  1.           3.           3.           0.           3.
#     0.           5.         121.           0.        ]
#  [  1.           4.           5.           1.           3.
#     0.           6.         156.           0.        ]
#  [  1.           4.           4.           1.           3.
#     0.           5.         147.           1.        ]
#  [  1.           4.           5.           0.           3.
#     0.           5.         158.           0.        ]
#  [  1.           3.           5.           1.           3.
#     0.           5.         118.           0.        ]
#  [  1.           3.           5.           1.           3.
#     0.           5.          99.           0.        ]
#  [  1.           4.           5.           1.           3.
#     0.           5.         112.           0.        ]]
# utilities: [-199.98558    -186.543808   -193.199318   -166.191148   -205.201233
#  -191.868216   -174.650648   -121.81469501 -103.411398   -143.243079
#  -126.622221   -127.139103   -144.544808   -100.689698   -142.958697
#  -174.672645   -140.573499   -159.921768   -161.47038    -195.358389
#  -161.527765   -207.456191   -195.358389   -210.152902   -157.21557
#  -131.924632   -148.820831  ]
# x: [[  1.           3.           4.           1.           0.
#     0.           5.         150.           0.        ]
#  [  1.           3.           5.           1.           1.
#     0.           5.         140.           0.        ]
#  [  1.           3.           5.           1.           1.
#     0.           5.         145.           0.        ]
#  [  1.           4.           5.           1.           0.
#     0.           5.         125.           0.        ]
#  [  1.           3.           5.           1.           0.
#     0.           5.         154.           0.        ]
#  [  1.           3.           5.           1.           1.
#     0.           5.         144.           0.        ]
#  [  1.           3.           4.           1.           2.
#     0.           5.         131.           0.        ]
#  [  1.           2.           4.           1.           2.
#     0.           5.          91.           0.        ]
#  [  1.           2.           3.           0.           1.
#     0.           5.          77.00000001   0.        ]
#  [  1.           2.           3.           1.           1.
#     0.           5.         107.           0.        ]
#  [  1.           3.           5.           1.           2.
#     0.           5.          95.           0.        ]
#  [  1.           2.           4.           1.           2.
#     0.           5.          95.           0.        ]
#  [  1.           2.           4.           0.           2.
#     0.           5.         108.           0.        ]
#  [  1.           2.           2.           1.           1.
#     0.           4.          75.           0.        ]
#  [  1.           2.           5.           1.           1.
#     0.           4.         107.           0.        ]
#  [  1.           3.           4.           1.           1.
#     0.           5.         131.           0.        ]
#  [  1.           2.           4.           0.           1.
#     0.           5.         105.           0.        ]
#  [  1.           3.           5.           1.           1.
#     0.           5.         120.           0.        ]
#  [  1.           3.           3.           1.           1.
#     0.           5.         121.           0.        ]
#  [  1.           4.           4.           1.           3.
#     0.           5.         147.           1.        ]
#  [  1.           3.           3.           0.           3.
#     0.           5.         121.           0.        ]
#  [  1.           4.           5.           1.           3.
#     0.           6.         156.           0.        ]
#  [  1.           4.           4.           1.           3.
#     0.           5.         147.           1.        ]
#  [  1.           4.           5.           0.           3.
#     0.           5.         158.           0.        ]
#  [  1.           3.           5.           1.           3.
#     0.           5.         118.           0.        ]
#  [  1.           3.           5.           1.           3.
#     0.           5.          99.           0.        ]
#  [  1.           4.           5.           1.           3.
#     0.           5.         112.           0.        ]]
# utilities: [-199.98558    -186.543808   -193.199318   -166.191148   -205.201233
#  -191.868216   -174.650648   -121.814695   -103.41139801 -143.243079
#  -126.622221   -127.139103   -144.544808   -100.689698   -142.958697
#  -174.672645   -140.573499   -159.921768   -161.47038    -195.358389
#  -161.527765   -207.456191   -195.358389   -210.152902   -157.21557
#  -131.924632   -148.820831  ]
# x: [[  1.           3.           4.           1.           0.
#     0.           5.         150.           0.        ]
#  [  1.           3.           5.           1.           1.
#     0.           5.         140.           0.        ]
#  [  1.           3.           5.           1.           1.
#     0.           5.         145.           0.        ]
#  [  1.           4.           5.           1.           0.
#     0.           5.         125.           0.        ]
#  [  1.           3.           5.           1.           0.
#     0.           5.         154.           0.        ]
#  [  1.           3.           5.           1.           1.
#     0.           5.         144.           0.        ]
#  [  1.           3.           4.           1.           2.
#     0.           5.         131.           0.        ]
#  [  1.           2.           4.           1.           2.
#     0.           5.          91.           0.        ]
#  [  1.           2.           3.           0.           1.
#     0.           5.          77.           0.        ]
#  [  1.           2.           3.           1.           1.
#     0.           5.         107.00000001   0.        ]
#  [  1.           3.           5.           1.           2.
#     0.           5.          95.           0.        ]
#  [  1.           2.           4.           1.           2.
#     0.           5.          95.           0.        ]
#  [  1.           2.           4.           0.           2.
#     0.           5.         108.           0.        ]
#  [  1.           2.           2.           1.           1.
#     0.           4.          75.           0.        ]
#  [  1.           2.           5.           1.           1.
#     0.           4.         107.           0.        ]
#  [  1.           3.           4.           1.           1.
#     0.           5.         131.           0.        ]
#  [  1.           2.           4.           0.           1.
#     0.           5.         105.           0.        ]
#  [  1.           3.           5.           1.           1.
#     0.           5.         120.           0.        ]
#  [  1.           3.           3.           1.           1.
#     0.           5.         121.           0.        ]
#  [  1.           4.           4.           1.           3.
#     0.           5.         147.           1.        ]
#  [  1.           3.           3.           0.           3.
#     0.           5.         121.           0.        ]
#  [  1.           4.           5.           1.           3.
#     0.           6.         156.           0.        ]
#  [  1.           4.           4.           1.           3.
#     0.           5.         147.           1.        ]
#  [  1.           4.           5.           0.           3.
#     0.           5.         158.           0.        ]
#  [  1.           3.           5.           1.           3.
#     0.           5.         118.           0.        ]
#  [  1.           3.           5.           1.           3.
#     0.           5.          99.           0.        ]
#  [  1.           4.           5.           1.           3.
#     0.           5.         112.           0.        ]]
# utilities: [-199.98558    -186.543808   -193.199318   -166.191148   -205.201233
#  -191.868216   -174.650648   -121.814695   -103.411398   -143.24307901
#  -126.622221   -127.139103   -144.544808   -100.689698   -142.958697
#  -174.672645   -140.573499   -159.921768   -161.47038    -195.358389
#  -161.527765   -207.456191   -195.358389   -210.152902   -157.21557
#  -131.924632   -148.820831  ]
# x: [[  1.           3.           4.           1.           0.
#     0.           5.         150.           0.        ]
#  [  1.           3.           5.           1.           1.
#     0.           5.         140.           0.        ]
#  [  1.           3.           5.           1.           1.
#     0.           5.         145.           0.        ]
#  [  1.           4.           5.           1.           0.
#     0.           5.         125.           0.        ]
#  [  1.           3.           5.           1.           0.
#     0.           5.         154.           0.        ]
#  [  1.           3.           5.           1.           1.
#     0.           5.         144.           0.        ]
#  [  1.           3.           4.           1.           2.
#     0.           5.         131.           0.        ]
#  [  1.           2.           4.           1.           2.
#     0.           5.          91.           0.        ]
#  [  1.           2.           3.           0.           1.
#     0.           5.          77.           0.        ]
#  [  1.           2.           3.           1.           1.
#     0.           5.         107.           0.        ]
#  [  1.           3.           5.           1.           2.
#     0.           5.          95.00000001   0.        ]
#  [  1.           2.           4.           1.           2.
#     0.           5.          95.           0.        ]
#  [  1.           2.           4.           0.           2.
#     0.           5.         108.           0.        ]
#  [  1.           2.           2.           1.           1.
#     0.           4.          75.           0.        ]
#  [  1.           2.           5.           1.           1.
#     0.           4.         107.           0.        ]
#  [  1.           3.           4.           1.           1.
#     0.           5.         131.           0.        ]
#  [  1.           2.           4.           0.           1.
#     0.           5.         105.           0.        ]
#  [  1.           3.           5.           1.           1.
#     0.           5.         120.           0.        ]
#  [  1.           3.           3.           1.           1.
#     0.           5.         121.           0.        ]
#  [  1.           4.           4.           1.           3.
#     0.           5.         147.           1.        ]
#  [  1.           3.           3.           0.           3.
#     0.           5.         121.           0.        ]
#  [  1.           4.           5.           1.           3.
#     0.           6.         156.           0.        ]
#  [  1.           4.           4.           1.           3.
#     0.           5.         147.           1.        ]
#  [  1.           4.           5.           0.           3.
#     0.           5.         158.           0.        ]
#  [  1.           3.           5.           1.           3.
#     0.           5.         118.           0.        ]
#  [  1.           3.           5.           1.           3.
#     0.           5.          99.           0.        ]
#  [  1.           4.           5.           1.           3.
#     0.           5.         112.           0.        ]]
# utilities: [-199.98558    -186.543808   -193.199318   -166.191148   -205.201233
#  -191.868216   -174.650648   -121.814695   -103.411398   -143.243079
#  -126.62222101 -127.139103   -144.544808   -100.689698   -142.958697
#  -174.672645   -140.573499   -159.921768   -161.47038    -195.358389
#  -161.527765   -207.456191   -195.358389   -210.152902   -157.21557
#  -131.924632   -148.820831  ]
# x: [[  1.           3.           4.           1.           0.
#     0.           5.         150.           0.        ]
#  [  1.           3.           5.           1.           1.
#     0.           5.         140.           0.        ]
#  [  1.           3.           5.           1.           1.
#     0.           5.         145.           0.        ]
#  [  1.           4.           5.           1.           0.
#     0.           5.         125.           0.        ]
#  [  1.           3.           5.           1.           0.
#     0.           5.         154.           0.        ]
#  [  1.           3.           5.           1.           1.
#     0.           5.         144.           0.        ]
#  [  1.           3.           4.           1.           2.
#     0.           5.         131.           0.        ]
#  [  1.           2.           4.           1.           2.
#     0.           5.          91.           0.        ]
#  [  1.           2.           3.           0.           1.
#     0.           5.          77.           0.        ]
#  [  1.           2.           3.           1.           1.
#     0.           5.         107.           0.        ]
#  [  1.           3.           5.           1.           2.
#     0.           5.          95.           0.        ]
#  [  1.           2.           4.           1.           2.
#     0.           5.          95.00000001   0.        ]
#  [  1.           2.           4.           0.           2.
#     0.           5.         108.           0.        ]
#  [  1.           2.           2.           1.           1.
#     0.           4.          75.           0.        ]
#  [  1.           2.           5.           1.           1.
#     0.           4.         107.           0.        ]
#  [  1.           3.           4.           1.           1.
#     0.           5.         131.           0.        ]
#  [  1.           2.           4.           0.           1.
#     0.           5.         105.           0.        ]
#  [  1.           3.           5.           1.           1.
#     0.           5.         120.           0.        ]
#  [  1.           3.           3.           1.           1.
#     0.           5.         121.           0.        ]
#  [  1.           4.           4.           1.           3.
#     0.           5.         147.           1.        ]
#  [  1.           3.           3.           0.           3.
#     0.           5.         121.           0.        ]
#  [  1.           4.           5.           1.           3.
#     0.           6.         156.           0.        ]
#  [  1.           4.           4.           1.           3.
#     0.           5.         147.           1.        ]
#  [  1.           4.           5.           0.           3.
#     0.           5.         158.           0.        ]
#  [  1.           3.           5.           1.           3.
#     0.           5.         118.           0.        ]
#  [  1.           3.           5.           1.           3.
#     0.           5.          99.           0.        ]
#  [  1.           4.           5.           1.           3.
#     0.           5.         112.           0.        ]]
# utilities: [-199.98558    -186.543808   -193.199318   -166.191148   -205.201233
#  -191.868216   -174.650648   -121.814695   -103.411398   -143.243079
#  -126.622221   -127.13910301 -144.544808   -100.689698   -142.958697
#  -174.672645   -140.573499   -159.921768   -161.47038    -195.358389
#  -161.527765   -207.456191   -195.358389   -210.152902   -157.21557
#  -131.924632   -148.820831  ]
# x: [[  1.           3.           4.           1.           0.
#     0.           5.         150.           0.        ]
#  [  1.           3.           5.           1.           1.
#     0.           5.         140.           0.        ]
#  [  1.           3.           5.           1.           1.
#     0.           5.         145.           0.        ]
#  [  1.           4.           5.           1.           0.
#     0.           5.         125.           0.        ]
#  [  1.           3.           5.           1.           0.
#     0.           5.         154.           0.        ]
#  [  1.           3.           5.           1.           1.
#     0.           5.         144.           0.        ]
#  [  1.           3.           4.           1.           2.
#     0.           5.         131.           0.        ]
#  [  1.           2.           4.           1.           2.
#     0.           5.          91.           0.        ]
#  [  1.           2.           3.           0.           1.
#     0.           5.          77.           0.        ]
#  [  1.           2.           3.           1.           1.
#     0.           5.         107.           0.        ]
#  [  1.           3.           5.           1.           2.
#     0.           5.          95.           0.        ]
#  [  1.           2.           4.           1.           2.
#     0.           5.          95.           0.        ]
#  [  1.           2.           4.           0.           2.
#     0.           5.         108.00000001   0.        ]
#  [  1.           2.           2.           1.           1.
#     0.           4.          75.           0.        ]
#  [  1.           2.           5.           1.           1.
#     0.           4.         107.           0.        ]
#  [  1.           3.           4.           1.           1.
#     0.           5.         131.           0.        ]
#  [  1.           2.           4.           0.           1.
#     0.           5.         105.           0.        ]
#  [  1.           3.           5.           1.           1.
#     0.           5.         120.           0.        ]
#  [  1.           3.           3.           1.           1.
#     0.           5.         121.           0.        ]
#  [  1.           4.           4.           1.           3.
#     0.           5.         147.           1.        ]
#  [  1.           3.           3.           0.           3.
#     0.           5.         121.           0.        ]
#  [  1.           4.           5.           1.           3.
#     0.           6.         156.           0.        ]
#  [  1.           4.           4.           1.           3.
#     0.           5.         147.           1.        ]
#  [  1.           4.           5.           0.           3.
#     0.           5.         158.           0.        ]
#  [  1.           3.           5.           1.           3.
#     0.           5.         118.           0.        ]
#  [  1.           3.           5.           1.           3.
#     0.           5.          99.           0.        ]
#  [  1.           4.           5.           1.           3.
#     0.           5.         112.           0.        ]]
# utilities: [-199.98558    -186.543808   -193.199318   -166.191148   -205.201233
#  -191.868216   -174.650648   -121.814695   -103.411398   -143.243079
#  -126.622221   -127.139103   -144.54480801 -100.689698   -142.958697
#  -174.672645   -140.573499   -159.921768   -161.47038    -195.358389
#  -161.527765   -207.456191   -195.358389   -210.152902   -157.21557
#  -131.924632   -148.820831  ]
# x: [[  1.           3.           4.           1.           0.
#     0.           5.         150.           0.        ]
#  [  1.           3.           5.           1.           1.
#     0.           5.         140.           0.        ]
#  [  1.           3.           5.           1.           1.
#     0.           5.         145.           0.        ]
#  [  1.           4.           5.           1.           0.
#     0.           5.         125.           0.        ]
#  [  1.           3.           5.           1.           0.
#     0.           5.         154.           0.        ]
#  [  1.           3.           5.           1.           1.
#     0.           5.         144.           0.        ]
#  [  1.           3.           4.           1.           2.
#     0.           5.         131.           0.        ]
#  [  1.           2.           4.           1.           2.
#     0.           5.          91.           0.        ]
#  [  1.           2.           3.           0.           1.
#     0.           5.          77.           0.        ]
#  [  1.           2.           3.           1.           1.
#     0.           5.         107.           0.        ]
#  [  1.           3.           5.           1.           2.
#     0.           5.          95.           0.        ]
# ...
#     0.           4.         500.           0.        ]
#  [  1.           2.           5.           1.           1.
#     0.           4.         500.           0.        ]
#  [  1.           3.           4.           1.           1.
#     0.           5.         500.           0.        ]
#  [  1.           2.           4.           0.           1.
#     0.           5.         500.           0.        ]
#  [  1.           3.           5.           1.           1.
#     0.           5.         500.           0.        ]
#  [  1.           3.           3.           1.           1.
#     0.           5.         500.           0.        ]
#  [  1.           4.           4.           1.           3.
#     0.           5.         500.           1.        ]
#  [  1.           3.           3.           0.           3.
#     0.           5.         500.           0.        ]
#  [  1.           4.           5.           1.           3.
#     0.           6.         500.           0.        ]
#  [  1.           4.           4.           1.           3.
#     0.           5.         499.99999999   1.        ]
#  [  1.           4.           5.           0.           3.
#     0.           5.         500.           0.        ]
#  [  1.           3.           5.           1.           3.
#     0.           5.         500.           0.        ]
#  [  1.           3.           5.           1.           3.
#     0.           5.         500.           0.        ]
#  [  1.           4.           5.           1.           3.
#     0.           5.         500.           0.        ]]
# utilities: [-665.87128    -665.740528   -665.740528   -665.354398   -665.762525
#  -665.740528   -665.827286   -666.235413   -666.467544   -666.366165
#  -665.718531   -666.235413   -666.336792   -666.408048   -666.081783
#  -665.849283   -666.358789   -665.740528   -665.958038   -665.237395
#  -666.015423   -665.355279   -665.23739499 -665.389786   -665.696534
#  -665.696534   -665.288407  ]
# x: [[  1.           3.           4.           1.           0.
#     0.           5.         500.           0.        ]
#  [  1.           3.           5.           1.           1.
#     0.           5.         500.           0.        ]
#  [  1.           3.           5.           1.           1.
#     0.           5.         500.           0.        ]
#  [  1.           4.           5.           1.           0.
#     0.           5.         500.           0.        ]
#  [  1.           3.           5.           1.           0.
#     0.           5.         500.           0.        ]
#  [  1.           3.           5.           1.           1.
#     0.           5.         500.           0.        ]
#  [  1.           3.           4.           1.           2.
#     0.           5.         500.           0.        ]
#  [  1.           2.           4.           1.           2.
#     0.           5.         500.           0.        ]
#  [  1.           2.           3.           0.           1.
#     0.           5.         500.           0.        ]
#  [  1.           2.           3.           1.           1.
#     0.           5.         500.           0.        ]
#  [  1.           3.           5.           1.           2.
#     0.           5.         500.           0.        ]
#  [  1.           2.           4.           1.           2.
#     0.           5.         500.           0.        ]
#  [  1.           2.           4.           0.           2.
#     0.           5.         500.           0.        ]
#  [  1.           2.           2.           1.           1.
#     0.           4.         500.           0.        ]
#  [  1.           2.           5.           1.           1.
#     0.           4.         500.           0.        ]
#  [  1.           3.           4.           1.           1.
#     0.           5.         500.           0.        ]
#  [  1.           2.           4.           0.           1.
#     0.           5.         500.           0.        ]
#  [  1.           3.           5.           1.           1.
#     0.           5.         500.           0.        ]
#  [  1.           3.           3.           1.           1.
#     0.           5.         500.           0.        ]
#  [  1.           4.           4.           1.           3.
#     0.           5.         500.           1.        ]
#  [  1.           3.           3.           0.           3.
#     0.           5.         500.           0.        ]
#  [  1.           4.           5.           1.           3.
#     0.           6.         500.           0.        ]
#  [  1.           4.           4.           1.           3.
#     0.           5.         500.           1.        ]
#  [  1.           4.           5.           0.           3.
#     0.           5.         499.99999999   0.        ]
#  [  1.           3.           5.           1.           3.
#     0.           5.         500.           0.        ]
#  [  1.           3.           5.           1.           3.
#     0.           5.         500.           0.        ]
#  [  1.           4.           5.           1.           3.
#     0.           5.         500.           0.        ]]
# utilities: [-665.87128    -665.740528   -665.740528   -665.354398   -665.762525
#  -665.740528   -665.827286   -666.235413   -666.467544   -666.366165
#  -665.718531   -666.235413   -666.336792   -666.408048   -666.081783
#  -665.849283   -666.358789   -665.740528   -665.958038   -665.237395
#  -666.015423   -665.355279   -665.237395   -665.38978599 -665.696534
#  -665.696534   -665.288407  ]
# x: [[  1.           3.           4.           1.           0.
#     0.           5.         500.           0.        ]
#  [  1.           3.           5.           1.           1.
#     0.           5.         500.           0.        ]
#  [  1.           3.           5.           1.           1.
#     0.           5.         500.           0.        ]
#  [  1.           4.           5.           1.           0.
#     0.           5.         500.           0.        ]
#  [  1.           3.           5.           1.           0.
#     0.           5.         500.           0.        ]
#  [  1.           3.           5.           1.           1.
#     0.           5.         500.           0.        ]
#  [  1.           3.           4.           1.           2.
#     0.           5.         500.           0.        ]
#  [  1.           2.           4.           1.           2.
#     0.           5.         500.           0.        ]
#  [  1.           2.           3.           0.           1.
#     0.           5.         500.           0.        ]
#  [  1.           2.           3.           1.           1.
#     0.           5.         500.           0.        ]
#  [  1.           3.           5.           1.           2.
#     0.           5.         500.           0.        ]
#  [  1.           2.           4.           1.           2.
#     0.           5.         500.           0.        ]
#  [  1.           2.           4.           0.           2.
#     0.           5.         500.           0.        ]
#  [  1.           2.           2.           1.           1.
#     0.           4.         500.           0.        ]
#  [  1.           2.           5.           1.           1.
#     0.           4.         500.           0.        ]
#  [  1.           3.           4.           1.           1.
#     0.           5.         500.           0.        ]
#  [  1.           2.           4.           0.           1.
#     0.           5.         500.           0.        ]
#  [  1.           3.           5.           1.           1.
#     0.           5.         500.           0.        ]
#  [  1.           3.           3.           1.           1.
#     0.           5.         500.           0.        ]
#  [  1.           4.           4.           1.           3.
#     0.           5.         500.           1.        ]
#  [  1.           3.           3.           0.           3.
#     0.           5.         500.           0.        ]
#  [  1.           4.           5.           1.           3.
#     0.           6.         500.           0.        ]
#  [  1.           4.           4.           1.           3.
#     0.           5.         500.           1.        ]
#  [  1.           4.           5.           0.           3.
#     0.           5.         500.           0.        ]
#  [  1.           3.           5.           1.           3.
#     0.           5.         499.99999999   0.        ]
#  [  1.           3.           5.           1.           3.
#     0.           5.         500.           0.        ]
#  [  1.           4.           5.           1.           3.
#     0.           5.         500.           0.        ]]
# utilities: [-665.87128    -665.740528   -665.740528   -665.354398   -665.762525
#  -665.740528   -665.827286   -666.235413   -666.467544   -666.366165
#  -665.718531   -666.235413   -666.336792   -666.408048   -666.081783
#  -665.849283   -666.358789   -665.740528   -665.958038   -665.237395
#  -666.015423   -665.355279   -665.237395   -665.389786   -665.69653399
#  -665.696534   -665.288407  ]
# x: [[  1.           3.           4.           1.           0.
#     0.           5.         500.           0.        ]
#  [  1.           3.           5.           1.           1.
#     0.           5.         500.           0.        ]
#  [  1.           3.           5.           1.           1.
#     0.           5.         500.           0.        ]
#  [  1.           4.           5.           1.           0.
#     0.           5.         500.           0.        ]
#  [  1.           3.           5.           1.           0.
#     0.           5.         500.           0.        ]
#  [  1.           3.           5.           1.           1.
#     0.           5.         500.           0.        ]
#  [  1.           3.           4.           1.           2.
#     0.           5.         500.           0.        ]
#  [  1.           2.           4.           1.           2.
#     0.           5.         500.           0.        ]
#  [  1.           2.           3.           0.           1.
#     0.           5.         500.           0.        ]
#  [  1.           2.           3.           1.           1.
#     0.           5.         500.           0.        ]
#  [  1.           3.           5.           1.           2.
#     0.           5.         500.           0.        ]
#  [  1.           2.           4.           1.           2.
#     0.           5.         500.           0.        ]
#  [  1.           2.           4.           0.           2.
#     0.           5.         500.           0.        ]
#  [  1.           2.           2.           1.           1.
#     0.           4.         500.           0.        ]
#  [  1.           2.           5.           1.           1.
#     0.           4.         500.           0.        ]
#  [  1.           3.           4.           1.           1.
#     0.           5.         500.           0.        ]
#  [  1.           2.           4.           0.           1.
#     0.           5.         500.           0.        ]
#  [  1.           3.           5.           1.           1.
#     0.           5.         500.           0.        ]
#  [  1.           3.           3.           1.           1.
#     0.           5.         500.           0.        ]
#  [  1.           4.           4.           1.           3.
#     0.           5.         500.           1.        ]
#  [  1.           3.           3.           0.           3.
#     0.           5.         500.           0.        ]
#  [  1.           4.           5.           1.           3.
#     0.           6.         500.           0.        ]
#  [  1.           4.           4.           1.           3.
#     0.           5.         500.           1.        ]
#  [  1.           4.           5.           0.           3.
#     0.           5.         500.           0.        ]
#  [  1.           3.           5.           1.           3.
#     0.           5.         500.           0.        ]
#  [  1.           3.           5.           1.           3.
#     0.           5.         499.99999999   0.        ]
#  [  1.           4.           5.           1.           3.
#     0.           5.         500.           0.        ]]
# utilities: [-665.87128    -665.740528   -665.740528   -665.354398   -665.762525
#  -665.740528   -665.827286   -666.235413   -666.467544   -666.366165
#  -665.718531   -666.235413   -666.336792   -666.408048   -666.081783
#  -665.849283   -666.358789   -665.740528   -665.958038   -665.237395
#  -666.015423   -665.355279   -665.237395   -665.389786   -665.696534
#  -665.69653399 -665.288407  ]
# x: [[  1.           3.           4.           1.           0.
#     0.           5.         500.           0.        ]
#  [  1.           3.           5.           1.           1.
#     0.           5.         500.           0.        ]
#  [  1.           3.           5.           1.           1.
#     0.           5.         500.           0.        ]
#  [  1.           4.           5.           1.           0.
#     0.           5.         500.           0.        ]
#  [  1.           3.           5.           1.           0.
#     0.           5.         500.           0.        ]
#  [  1.           3.           5.           1.           1.
#     0.           5.         500.           0.        ]
#  [  1.           3.           4.           1.           2.
#     0.           5.         500.           0.        ]
#  [  1.           2.           4.           1.           2.
#     0.           5.         500.           0.        ]
#  [  1.           2.           3.           0.           1.
#     0.           5.         500.           0.        ]
#  [  1.           2.           3.           1.           1.
#     0.           5.         500.           0.        ]
#  [  1.           3.           5.           1.           2.
#     0.           5.         500.           0.        ]
#  [  1.           2.           4.           1.           2.
#     0.           5.         500.           0.        ]
#  [  1.           2.           4.           0.           2.
#     0.           5.         500.           0.        ]
#  [  1.           2.           2.           1.           1.
#     0.           4.         500.           0.        ]
#  [  1.           2.           5.           1.           1.
#     0.           4.         500.           0.        ]
#  [  1.           3.           4.           1.           1.
#     0.           5.         500.           0.        ]
#  [  1.           2.           4.           0.           1.
#     0.           5.         500.           0.        ]
#  [  1.           3.           5.           1.           1.
#     0.           5.         500.           0.        ]
#  [  1.           3.           3.           1.           1.
#     0.           5.         500.           0.        ]
#  [  1.           4.           4.           1.           3.
#     0.           5.         500.           1.        ]
#  [  1.           3.           3.           0.           3.
#     0.           5.         500.           0.        ]
#  [  1.           4.           5.           1.           3.
#     0.           6.         500.           0.        ]
#  [  1.           4.           4.           1.           3.
#     0.           5.         500.           1.        ]
#  [  1.           4.           5.           0.           3.
#     0.           5.         500.           0.        ]
#  [  1.           3.           5.           1.           3.
#     0.           5.         500.           0.        ]
#  [  1.           3.           5.           1.           3.
#     0.           5.         500.           0.        ]
#  [  1.           4.           5.           1.           3.
#     0.           5.         499.99999999   0.        ]]
# utilities: [-665.87128    -665.740528   -665.740528   -665.354398   -665.762525
#  -665.740528   -665.827286   -666.235413   -666.467544   -666.366165
#  -665.718531   -666.235413   -666.336792   -666.408048   -666.081783
#  -665.849283   -666.358789   -665.740528   -665.958038   -665.237395
#  -666.015423   -665.355279   -665.237395   -665.389786   -665.696534
#  -665.696534   -665.28840699]
# Optimal prices found!
# optimal_prices: [500. 500. 500. 500. 500. 500. 500. 500. 500. 500. 500. 500. 500. 500.
#  500. 500. 500. 500. 500. 500. 500. 500. 500. 500. 500. 500. 500.]
# max revenue: 500.0

# %% [markdown]
# # Problem 4

# %%
import pandas as pd
import numpy as np
from scipy import optimize
import matplotlib.pyplot as plt

# Read the data
data = pd.read_csv("data.csv")
print(f"Data loaded, shape: {data.shape}")

# Define customer segments based on booking window
data['customer_segment'] = np.where(data['srch_booking_window'] < 7, 2, 1)  # 2 for late, 1 for early

# Calculate theta values (probability of customer belonging to each segment)
unique_searches = data['srch_id'].nunique()
# Count unique searches in each segment (we need to count searches, not individual hotel options)
segment_counts = data.drop_duplicates(subset=['srch_id'])[['srch_id', 'customer_segment']].groupby('customer_segment').count()
theta_1 = segment_counts.loc[1, 'srch_id'] / unique_searches  # early bookings
theta_2 = segment_counts.loc[2, 'srch_id'] / unique_searches  # late bookings

print(f"\nTotal unique searches: {unique_searches}")
print(f"Early booking searches (segment 1): {segment_counts.loc[1, 'srch_id']}")
print(f"Late booking searches (segment 2): {segment_counts.loc[2, 'srch_id']}")
print(f"θ₁ (probability of early booking): {theta_1:.4f}")
print(f"θ₂ (probability of late booking): {theta_2:.4f}")

# Features to use in the MNL model
features = [
    'prop_starrating',
    'prop_review_score',
    'prop_brand_bool',
    'prop_location_score',
    'prop_accesibility_score',
    'prop_log_historical_price',
    'price_usd',
    'promotion_flag'
]

# Create separate datasets for each segment
data_segment_1 = data[data['customer_segment'] == 1].copy()  # early bookings
data_segment_2 = data[data['customer_segment'] == 2].copy()  # late bookings

# Group by search_id for each segment
search_groups_1 = data_segment_1.groupby('srch_id')
search_groups_2 = data_segment_2.groupby('srch_id')

# Store original data for each segment (before normalization)
data_original_1 = data_segment_1.copy()
data_original_2 = data_segment_2.copy()

# Normalize features separately for each segment
normalization_params_1 = {}
print("\nNormalizing features for Segment 1 (Early Bookings):")
for feature in features:
    if feature not in ['prop_brand_bool', 'promotion_flag']:  # Skip binary features
        mean = data_segment_1[feature].mean()
        std = data_segment_1[feature].std()
        data_segment_1[feature] = (data_segment_1[feature] - mean) / std
        normalization_params_1[feature] = {'mean': mean, 'std': std}
        print(f"  Normalized {feature}: mean={mean:.4f}, std={std:.4f}")

normalization_params_2 = {}
print("\nNormalizing features for Segment 2 (Late Bookings):")
for feature in features:
    if feature not in ['prop_brand_bool', 'promotion_flag']:  # Skip binary features
        mean = data_segment_2[feature].mean()
        std = data_segment_2[feature].std()
        data_segment_2[feature] = (data_segment_2[feature] - mean) / std
        normalization_params_2[feature] = {'mean': mean, 'std': std}
        print(f"  Normalized {feature}: mean={mean:.4f}, std={std:.4f}")

# Function to calculate MNL log-likelihood (same as before)
def mnl_log_likelihood(beta, data, search_groups, features):
    # Initialize log-likelihood
    log_likelihood = 0
    
    # Extract beta values
    beta0 = beta[0]  # intercept
    beta_features = beta[1:]  # coefficients for features
    
    # Loop through each search session
    for search_id, group in search_groups:
        # Get the hotels in this search
        hotels = group.copy()
        
        # Calculate utilities
        X = hotels[features]
        utilities = beta0 + X.dot(beta_features)
        hotels['utility'] = utilities
        
        # Calculate exp(utility) with numerical stability
        max_utility = utilities.max()
        hotels['exp_utility'] = np.exp(utilities - max_utility)
        
        # Calculate denominator (sum of exp(utility) + no-purchase option)
        denominator = hotels['exp_utility'].sum() + np.exp(-max_utility)  # no-purchase has utility 0
        
        # If there was a booking
        if (hotels['booking_bool'] == 1).any():
            # Get the booked hotel
            booked_hotel = hotels[hotels['booking_bool'] == 1].iloc[0]
            
            # Add to log-likelihood: log(P(j|S))
            log_likelihood += (booked_hotel['utility'] - max_utility) - np.log(denominator)
        else:
            # No booking - customer chose outside option
            log_likelihood += (-max_utility) - np.log(denominator)
    
    return -log_likelihood  # Negative because we're minimizing

# Function to fit MNL model
def fit_mnl_model(data, search_groups, features, segment_name):
    # Initial beta values (all zeros)
    initial_beta = np.zeros(len(features) + 1)  # +1 for intercept
    
    # Define the objective function for optimization
    def objective(beta):
        return mnl_log_likelihood(beta, data, search_groups, features)
    
    # Optimize using L-BFGS-B algorithm
    print(f"\nStarting optimization for {segment_name}...")
    result = optimize.minimize(
        objective,
        initial_beta,
        method='L-BFGS-B',
        options={'disp': True, 'maxiter': 100}
    )
    
    print(f"Optimization completed for {segment_name}: {result.success}")
    print(f"Final negative log-likelihood: {result.fun}")
    
    # Extract optimal beta values
    beta_opt = result.x
    
    return beta_opt

# Fit MNL model for each segment
beta_opt_1 = fit_mnl_model(data_segment_1, search_groups_1, features, "Segment 1 (Early Bookings)")
beta_opt_2 = fit_mnl_model(data_segment_2, search_groups_2, features, "Segment 2 (Late Bookings)")

# Helper function to print results
def print_mnl_results(beta_opt, segment_name, normalization_params):
    print(f"\nMNL Model Parameters for {segment_name}:")
    print(f"Intercept (β₀): {beta_opt[0]:.4f}")
    
    feature_descriptions = {
        'prop_starrating': 'Star Rating (higher = better hotel quality)',
        'prop_review_score': 'Review Score (higher = better guest reviews)',
        'prop_brand_bool': 'Brand Flag (1 = branded hotel, 0 = independent)',
        'prop_location_score': 'Location Score (higher = better location)',
        'prop_accesibility_score': 'Accessibility Score (higher = better accessibility)',
        'prop_log_historical_price': 'Log Historical Price',
        'price_usd': 'Price in USD',
        'promotion_flag': 'Promotion Flag (1 = has promotion, 0 = no promotion)'
    }
    
    # Store coefficients for comparison
    coefficients = []
    feature_names = []
    
    for i, feature in enumerate(features):
        coef = beta_opt[i+1]
        print(f"{feature_descriptions.get(feature, feature)} (β{i+1}): {coef:.6f}")
        coefficients.append(coef)
        feature_names.append(feature)
    '''
    # Additional interpretation of the coefficients (considering normalization)
    print("\nInterpretation of Coefficients:")
    for i, feature in enumerate(features):
        coef = beta_opt[i+1]
        if feature in normalization_params:
            # For normalized features, we need to interpret differently
            std = normalization_params[feature]['std']
            original_coef = coef / std
            print(f"{feature}: A one-unit increase in the original {feature} increases utility by {original_coef:.6f}")
        else:
            # For binary features, interpretation remains the same
            print(f"{feature}: Presence of this feature changes utility by {coef:.6f}")

    '''
    
    return coefficients, feature_names

# Print results for each segment
coef_1, features_list = print_mnl_results(beta_opt_1, "Segment 1 (Early Bookings)", normalization_params_1)
coef_2, _ = print_mnl_results(beta_opt_2, "Segment 2 (Late Bookings)", normalization_params_2)

# Compare coefficients between segments
print("\nComparison of Coefficients between Segments:")
print("Feature | Early Booking (β) | Late Booking (β) | Difference")
print("--------|-------------------|-----------------|------------")
for i, feature in enumerate(features_list):
    diff = coef_1[i] - coef_2[i]
    print(f"{feature} | {coef_1[i]:.6f} | {coef_2[i]:.6f} | {diff:.6f}")
# Out:
# Data loaded, shape: (153009, 15)
#
# Total unique searches: 8354
# Early booking searches (segment 1): 4537
# Late booking searches (segment 2): 3817
# θ₁ (probability of early booking): 0.5431
# θ₂ (probability of late booking): 0.4569
#
# Normalizing features for Segment 1 (Early Bookings):
#   Normalized prop_starrating: mean=3.2108, std=0.8640
#   Normalized prop_review_score: mean=4.0044, std=0.8981
#   Normalized prop_location_score: mean=2.6720, std=1.3706
#   Normalized prop_accesibility_score: mean=0.0063, std=0.0789
#   Normalized prop_log_historical_price: mean=4.2802, std=1.8238
#   Normalized price_usd: mean=147.7488, std=222.5223
#
# Normalizing features for Segment 2 (Late Bookings):
#   Normalized prop_starrating: mean=3.0926, std=0.8443
#   Normalized prop_review_score: mean=3.9674, std=0.9175
#   Normalized prop_location_score: mean=2.5507, std=1.3173
#   Normalized prop_accesibility_score: mean=0.0057, std=0.0751
#   Normalized prop_log_historical_price: mean=4.2715, std=1.7471
#   Normalized price_usd: mean=133.2432, std=113.7666
#
# Starting optimization for Segment 1 (Early Bookings)...
# Optimization completed for Segment 1 (Early Bookings): True
# Final negative log-likelihood: 11052.587137453187
#
# Starting optimization for Segment 2 (Late Bookings)...
# Optimization completed for Segment 2 (Late Bookings): True
# Final negative log-likelihood: 9505.447784875925
#
# MNL Model Parameters for Segment 1 (Early Bookings):
# Intercept (β₀): -2.1408
# Star Rating (higher = better hotel quality) (β1): 0.382053
# Review Score (higher = better guest reviews) (β2): 0.123381
# Brand Flag (1 = branded hotel, 0 = independent) (β3): 0.208820
# Location Score (higher = better location) (β4): -0.021836
# Accessibility Score (higher = better accessibility) (β5): 0.059120
# Log Historical Price (β6): -0.096779
# Price in USD (β7): -1.311830
# Promotion Flag (1 = has promotion, 0 = no promotion) (β8): 0.383003
#
# MNL Model Parameters for Segment 2 (Late Bookings):
# Intercept (β₀): -1.7752
# Star Rating (higher = better hotel quality) (β1): 0.455831
# Review Score (higher = better guest reviews) (β2): 0.096685
# Brand Flag (1 = branded hotel, 0 = independent) (β3): 0.256050
# Location Score (higher = better location) (β4): 0.085284
# Accessibility Score (higher = better accessibility) (β5): 0.024864
# Log Historical Price (β6): -0.031224
# Price in USD (β7): -1.062082
# Promotion Flag (1 = has promotion, 0 = no promotion) (β8): 0.551681
#
# Comparison of Coefficients between Segments:
# Feature | Early Booking (β) | Late Booking (β) | Difference
# --------|-------------------|-----------------|------------
# prop_starrating | 0.382053 | 0.455831 | -0.073778
# prop_review_score | 0.123381 | 0.096685 | 0.026696
# prop_brand_bool | 0.208820 | 0.256050 | -0.047230
# prop_location_score | -0.021836 | 0.085284 | -0.107121
# prop_accesibility_score | 0.059120 | 0.024864 | 0.034256
# prop_log_historical_price | -0.096779 | -0.031224 | -0.065555
# price_usd | -1.311830 | -1.062082 | -0.249749
# promotion_flag | 0.383003 | 0.551681 | -0.168678

# %% [markdown]
# # Problem 4
# ### normalise all variables including the boolean ones. also used same normalisation across the two segments

# %%
import pandas as pd
import numpy as np
from scipy import optimize
import matplotlib.pyplot as plt

# Read the data
data = pd.read_csv("data.csv")
print(f"Data loaded, shape: {data.shape}")

# Define customer segments based on booking window
data['customer_segment'] = np.where(data['srch_booking_window'] < 7, 2, 1)  # 2 for late, 1 for early

# Calculate theta values (probability of customer belonging to each segment)
unique_searches = data['srch_id'].nunique()
# Count unique searches in each segment (we need to count searches, not individual hotel options)
segment_counts = data.drop_duplicates(subset=['srch_id'])[['srch_id', 'customer_segment']].groupby('customer_segment').count()
theta_1 = segment_counts.loc[1, 'srch_id'] / unique_searches  # early bookings
theta_2 = segment_counts.loc[2, 'srch_id'] / unique_searches  # late bookings

print(f"\nTotal unique searches: {unique_searches}")
print(f"Early booking searches (segment 1): {segment_counts.loc[1, 'srch_id']}")
print(f"Late booking searches (segment 2): {segment_counts.loc[2, 'srch_id']}")
print(f"θ₁ (probability of early booking): {theta_1:.4f}")
print(f"θ₂ (probability of late booking): {theta_2:.4f}")

# Features to use in the MNL model
features = [
    'prop_starrating',
    'prop_review_score',
    'prop_brand_bool',
    'prop_location_score',
    'prop_accesibility_score',
    'prop_log_historical_price',
    'price_usd',
    'promotion_flag'
]

# Create separate datasets for each segment
data_segment_1 = data[data['customer_segment'] == 1].copy()  # early bookings
data_segment_2 = data[data['customer_segment'] == 2].copy()  # late bookings

# Group by search_id for each segment
search_groups_1 = data_segment_1.groupby('srch_id')
search_groups_2 = data_segment_2.groupby('srch_id')

# Store original data for each segment (before normalization)
data_original_1 = data_segment_1.copy()
data_original_2 = data_segment_2.copy()

# Normalize features together in both segments - including booleans
'''
normalization_params_1 = {}
print("\nNormalizing features for Segment 1 (Early Bookings):")
for feature in features:
    mean = data_segment_1[feature].mean()
    std = data_segment_1[feature].std()
    data_segment_1[feature] = (data_segment_1[feature] - mean) / std
    normalization_params_1[feature] = {'mean': mean, 'std': std}
    print(f"  Normalized {feature}: mean={mean:.4f}, std={std:.4f}")

normalization_params_2 = {}
print("\nNormalizing features for Segment 2 (Late Bookings):")
for feature in features:
    mean = data_segment_2[feature].mean()
    std = data_segment_2[feature].std()
    data_segment_2[feature] = (data_segment_2[feature] - mean) / std
    normalization_params_2[feature] = {'mean': mean, 'std': std}
    print(f"  Normalized {feature}: mean={mean:.4f}, std={std:.4f}")
'''
# Apply normalization using normalization_params_q1 to Segment 1
print("\nApplying normalization_params_q1 to Segment 1 (Early Bookings):")
for feature in features:
    mean_q1 = normalization_params_q1[feature]['mean']
    std_q1 = normalization_params_q1[feature]['std']
    data_segment_1[feature] = (data_segment_1[feature] - mean_q1) / std_q1
    segment1_mean = data_segment_1[feature].mean()
    segment1_std = data_segment_1[feature].std()
    print(f"  Normalized {feature}: new mean={segment1_mean:.4f}, new std={segment1_std:.4f}")

# Apply normalization using normalization_params_q1 to Segment 2
print("\nApplying normalization_params_q1 to Segment 2 (Late Bookings):")
for feature in features:
    mean_q1 = normalization_params_q1[feature]['mean']
    std_q1 = normalization_params_q1[feature]['std']
    data_segment_2[feature] = (data_segment_2[feature] - mean_q1) / std_q1
    segment2_mean = data_segment_2[feature].mean()
    segment2_std = data_segment_2[feature].std()
    print(f"  Normalized {feature}: new mean={segment2_mean:.4f}, new std={segment2_std:.4f}")

# Function to calculate MNL log-likelihood (same as before)
def mnl_log_likelihood(beta, data, search_groups, features):
    # Initialize log-likelihood
    log_likelihood = 0
    
    # Extract beta values
    beta0 = beta[0]  # intercept
    beta_features = beta[1:]  # coefficients for features
    
    # Loop through each search session
    for search_id, group in search_groups:
        # Get the hotels in this search
        hotels = group.copy()
        
        # Calculate utilities
        X = hotels[features]
        utilities = beta0 + X.dot(beta_features)
        hotels['utility'] = utilities
        
        # Calculate exp(utility) with numerical stability
        max_utility = utilities.max()
        hotels['exp_utility'] = np.exp(utilities - max_utility)
        
        # Calculate denominator (sum of exp(utility) + no-purchase option)
        denominator = hotels['exp_utility'].sum() + np.exp(-max_utility)  # no-purchase has utility 0
        
        # If there was a booking
        if (hotels['booking_bool'] == 1).any():
            # Get the booked hotel
            booked_hotel = hotels[hotels['booking_bool'] == 1].iloc[0]
            
            # Add to log-likelihood: log(P(j|S))
            log_likelihood += (booked_hotel['utility'] - max_utility) - np.log(denominator)
        else:
            # No booking - customer chose outside option
            log_likelihood += (-max_utility) - np.log(denominator)
    
    return -log_likelihood  # Negative because we're minimizing

# Function to fit MNL model
def fit_mnl_model(data, search_groups, features, segment_name):
    # Initial beta values (all zeros)
    initial_beta = np.zeros(len(features) + 1)  # +1 for intercept
    
    # Define the objective function for optimization
    def objective(beta):
        return mnl_log_likelihood(beta, data, search_groups, features)
    
    # Optimize using L-BFGS-B algorithm
    print(f"\nStarting optimization for {segment_name}...")
    result = optimize.minimize(
        objective,
        initial_beta,
        method='L-BFGS-B',
        options={'disp': True, 'maxiter': 100}
    )
    
    print(f"Optimization completed for {segment_name}: {result.success}")
    print(f"Final negative log-likelihood: {result.fun}")
    
    # Extract optimal beta values
    beta_opt = result.x
    
    return beta_opt

# Fit MNL model for each segment
beta_opt_1 = fit_mnl_model(data_segment_1, search_groups_1, features, "Segment 1 (Early Bookings)")
beta_opt_2 = fit_mnl_model(data_segment_2, search_groups_2, features, "Segment 2 (Late Bookings)")

# Helper function to print results
def print_mnl_results(beta_opt, segment_name, normalization_params):
    print(f"\nMNL Model Parameters for {segment_name}:")
    print(f"Intercept (β₀): {beta_opt[0]:.4f}")
    
    feature_descriptions = {
        'prop_starrating': 'Star Rating (higher = better hotel quality)',
        'prop_review_score': 'Review Score (higher = better guest reviews)',
        'prop_brand_bool': 'Brand Flag (1 = branded hotel, 0 = independent)',
        'prop_location_score': 'Location Score (higher = better location)',
        'prop_accesibility_score': 'Accessibility Score (higher = better accessibility)',
        'prop_log_historical_price': 'Log Historical Price',
        'price_usd': 'Price in USD',
        'promotion_flag': 'Promotion Flag (1 = has promotion, 0 = no promotion)'
    }
    
    # Store coefficients for comparison
    coefficients = []
    feature_names = []
    
    for i, feature in enumerate(features):
        coef = beta_opt[i+1]
        print(f"{feature_descriptions.get(feature, feature)} (β{i+1}): {coef:.6f}")
        coefficients.append(coef)
        feature_names.append(feature)
    '''
    # Additional interpretation of the coefficients (considering normalization)
    print("\nInterpretation of Coefficients:")
    for i, feature in enumerate(features):
        coef = beta_opt[i+1]
        if feature in normalization_params:
            # For normalized features, we need to interpret differently
            std = normalization_params[feature]['std']
            original_coef = coef / std
            print(f"{feature}: A one-unit increase in the original {feature} increases utility by {original_coef:.6f}")
        else:
            # For binary features, interpretation remains the same
            print(f"{feature}: Presence of this feature changes utility by {coef:.6f}")

    '''
    
    return coefficients, feature_names

# Print results for each segment
coef_1, features_list = print_mnl_results(beta_opt_1, "Segment 1 (Early Bookings)", normalization_params_1)
coef_2, _ = print_mnl_results(beta_opt_2, "Segment 2 (Late Bookings)", normalization_params_2)

# Compare coefficients between segments
print("\nComparison of Coefficients between Segments:")
print("Feature | Early Booking (β) | Late Booking (β) | Difference")
print("--------|-------------------|-----------------|------------")
for i, feature in enumerate(features_list):
    diff = coef_1[i] - coef_2[i]
    print(f"{feature} | {coef_1[i]:.6f} | {coef_2[i]:.6f} | {diff:.6f}")
# Out:
# Data loaded, shape: (153009, 15)
#
# Total unique searches: 8354
# Early booking searches (segment 1): 4537
# Late booking searches (segment 2): 3817
# θ₁ (probability of early booking): 0.5431
# θ₂ (probability of late booking): 0.4569
#
# Applying normalization_params_q1 to Segment 1 (Early Bookings):
#   Normalized prop_starrating: new mean=0.0623, new std=1.0079
#   Normalized prop_review_score: new mean=0.0184, new std=0.9901
#   Normalized prop_brand_bool: new mean=-0.0489, new std=1.0246
#   Normalized prop_location_score: new mean=0.0407, new std=1.0167
#   Normalized prop_accesibility_score: new mean=0.0035, new std=1.0219
#   Normalized prop_log_historical_price: new mean=0.0022, new std=1.0191
#   Normalized price_usd: new mean=0.0361, new std=1.2242
#   Normalized promotion_flag: new mean=0.0471, new std=1.0454
#
# Applying normalization_params_q1 to Segment 2 (Late Bookings):
#   Normalized prop_starrating: new mean=-0.0756, new std=0.9850
#   Normalized prop_review_score: new mean=-0.0224, new std=1.0115
#   Normalized prop_brand_bool: new mean=0.0593, new std=0.9660
#   Normalized prop_location_score: new mean=-0.0493, new std=0.9771
#   Normalized prop_accesibility_score: new mean=-0.0042, new std=0.9728
#   Normalized prop_log_historical_price: new mean=-0.0027, new std=0.9763
#   Normalized price_usd: new mean=-0.0437, new std=0.6259
#   Normalized promotion_flag: new mean=-0.0571, new std=0.9388
#
# Starting optimization for Segment 1 (Early Bookings)...
# Optimization completed for Segment 1 (Early Bookings): True
# Final negative log-likelihood: 11052.587145050955
#
# Starting optimization for Segment 2 (Late Bookings)...
# Optimization completed for Segment 2 (Late Bookings): True
# Final negative log-likelihood: 9505.447785059454
#
# MNL Model Parameters for Segment 1 (Early Bookings):
# Intercept (β₀): -1.9180
# Star Rating (higher = better hotel quality) (β1): 0.379038
# Review Score (higher = better guest reviews) (β2): 0.124630
# Brand Flag (1 = branded hotel, 0 = independent) (β3): 0.092098
# Location Score (higher = better location) (β4): -0.021459
# Accessibility Score (higher = better accessibility) (β5): 0.057844
# Log Historical Price (β6): -0.094884
# Price in USD (β7): -1.071555
# Promotion Flag (1 = has promotion, 0 = no promotion) (β8): 0.134802
#
# MNL Model Parameters for Segment 2 (Late Bookings):
# Intercept (β₀): -1.5397
# Star Rating (higher = better hotel quality) (β1): 0.462759
# Review Score (higher = better guest reviews) (β2): 0.095586
# Brand Flag (1 = branded hotel, 0 = independent) (β3): 0.112906
# Location Score (higher = better location) (β4): 0.087280
# Accessibility Score (higher = better accessibility) (β5): 0.025559
# Log Historical Price (β6): -0.031981
# Price in USD (β7): -1.696923
# Promotion Flag (1 = has promotion, 0 = no promotion) (β8): 0.194143
#
# Comparison of Coefficients between Segments:
# Feature | Early Booking (β) | Late Booking (β) | Difference
# --------|-------------------|-----------------|------------
# prop_starrating | 0.379038 | 0.462759 | -0.083721
# prop_review_score | 0.124630 | 0.095586 | 0.029044
# prop_brand_bool | 0.092098 | 0.112906 | -0.020808
# prop_location_score | -0.021459 | 0.087280 | -0.108738
# prop_accesibility_score | 0.057844 | 0.025559 | 0.032285
# prop_log_historical_price | -0.094884 | -0.031981 | -0.062903
# price_usd | -1.071555 | -1.696923 | 0.625368
# promotion_flag | 0.134802 | 0.194143 | -0.059341

# %% [markdown]
# # Problem 5

# %%
import pandas as pd

df_norm_params = pd.DataFrame(normalization_params_q1).T
df_norm_params = df_norm_params.T

# Save to CSV
df_norm_params.to_csv("normalization_params_q1.csv", index=False)

# %% [markdown]
# refer to "Question5.ipynb"

# %% [markdown]
# # Problem 6

# %%
import pandas as pd
import numpy as np
from scipy import optimize
import matplotlib.pyplot as plt

# Read the data
data = pd.read_csv("data.csv")
print(f"Data loaded, shape: {data.shape}")

# Define customer segments based on booking window
data['customer_segment'] = np.where(data['srch_saturday_night_bool'] == 1, 2, 1)  # 2 for sat night, 1 for non sat night

# Calculate theta values (probability of customer belonging to each segment)
unique_searches = data['srch_id'].nunique()
# Count unique searches in each segment (we need to count searches, not individual hotel options)
segment_counts = data.drop_duplicates(subset=['srch_id'])[['srch_id', 'customer_segment']].groupby('customer_segment').count()
theta_1 = segment_counts.loc[1, 'srch_id'] / unique_searches  # non sat night
theta_2 = segment_counts.loc[2, 'srch_id'] / unique_searches  # sat night

print(f"\nTotal unique searches: {unique_searches}")
print(f"Non-Saturday searches (segment 1): {segment_counts.loc[1, 'srch_id']}")
print(f"Saturday searches (segment 2): {segment_counts.loc[2, 'srch_id']}")
print(f"θ₁ (probability of non-Sat search): {theta_1:.4f}")
print(f"θ₂ (probability of Sat search): {theta_2:.4f}")

# Features to use in the MNL model
features = [
    'prop_starrating',
    'prop_review_score',
    'prop_brand_bool',
    'prop_location_score',
    'prop_accesibility_score',
    'prop_log_historical_price',
    'price_usd',
    'promotion_flag'
]

# Create separate datasets for each segment
data_segment_1 = data[data['customer_segment'] == 1].copy()  # non Sat night
data_segment_2 = data[data['customer_segment'] == 2].copy()  # Sat night

# Group by search_id for each segment
search_groups_1 = data_segment_1.groupby('srch_id')
search_groups_2 = data_segment_2.groupby('srch_id')

# Store original data for each segment (before normalization)
data_original_1 = data_segment_1.copy()
data_original_2 = data_segment_2.copy()

# Normalize features together in both segments
# Apply normalization using normalization_params_q1 to Segment 1
print("\nApplying normalization_params_q1 to Segment 1 (Non-Sat Bookings):")
for feature in features:
    mean_q1 = normalization_params_q1[feature]['mean']
    std_q1 = normalization_params_q1[feature]['std']
    data_segment_1[feature] = (data_segment_1[feature] - mean_q1) / std_q1
    segment1_mean = data_segment_1[feature].mean()
    segment1_std = data_segment_1[feature].std()
    print(f"  Normalized {feature}: new mean={segment1_mean:.4f}, new std={segment1_std:.4f}")

# Apply normalization using normalization_params_q1 to Segment 2
print("\nApplying normalization_params_q1 to Segment 2 (Sat Bookings):")
for feature in features:
    mean_q1 = normalization_params_q1[feature]['mean']
    std_q1 = normalization_params_q1[feature]['std']
    data_segment_2[feature] = (data_segment_2[feature] - mean_q1) / std_q1
    segment2_mean = data_segment_2[feature].mean()
    segment2_std = data_segment_2[feature].std()
    print(f"  Normalized {feature}: new mean={segment2_mean:.4f}, new std={segment2_std:.4f}")

# Function to calculate MNL log-likelihood (same as before)
def mnl_log_likelihood(beta, data, search_groups, features):
    # Initialize log-likelihood
    log_likelihood = 0
    
    # Extract beta values
    beta0 = beta[0]  # intercept
    beta_features = beta[1:]  # coefficients for features
    
    # Loop through each search session
    for search_id, group in search_groups:
        # Get the hotels in this search
        hotels = group.copy()
        
        # Calculate utilities
        X = hotels[features]
        utilities = beta0 + X.dot(beta_features)
        hotels['utility'] = utilities
        
        # Calculate exp(utility) with numerical stability
        max_utility = utilities.max()
        hotels['exp_utility'] = np.exp(utilities - max_utility)
        
        # Calculate denominator (sum of exp(utility) + no-purchase option)
        denominator = hotels['exp_utility'].sum() + np.exp(-max_utility)  # no-purchase has utility 0
        
        # If there was a booking
        if (hotels['booking_bool'] == 1).any():
            # Get the booked hotel
            booked_hotel = hotels[hotels['booking_bool'] == 1].iloc[0]
            
            # Add to log-likelihood: log(P(j|S))
            log_likelihood += (booked_hotel['utility'] - max_utility) - np.log(denominator)
        else:
            # No booking - customer chose outside option
            log_likelihood += (-max_utility) - np.log(denominator)
    
    return -log_likelihood  # Negative because we're minimizing

# Function to fit MNL model
def fit_mnl_model(data, search_groups, features, segment_name):
    # Initial beta values (all zeros)
    initial_beta = np.zeros(len(features) + 1)  # +1 for intercept
    
    # Define the objective function for optimization
    def objective(beta):
        return mnl_log_likelihood(beta, data, search_groups, features)
    
    # Optimize using L-BFGS-B algorithm
    print(f"\nStarting optimization for {segment_name}...")
    result = optimize.minimize(
        objective,
        initial_beta,
        method='L-BFGS-B',
        options={'disp': True, 'maxiter': 100}
    )
    
    print(f"Optimization completed for {segment_name}: {result.success}")
    print(f"Final negative log-likelihood: {result.fun}")
    
    # Extract optimal beta values
    beta_opt = result.x
    
    return beta_opt
# Out:
# Data loaded, shape: (153009, 15)
#
# Total unique searches: 8354
# Non-Saturday searches (segment 1): 3537
# Saturday searches (segment 2): 4817
# θ₁ (probability of non-Sat search): 0.4234
# θ₂ (probability of Sat search): 0.5766
#
# Applying normalization_params_q1 to Segment 1 (Non-Sat Bookings):
#   Normalized prop_starrating: new mean=0.0372, new std=1.0068
#   Normalized prop_review_score: new mean=-0.0035, new std=0.9916
#   Normalized prop_brand_bool: new mean=-0.0370, new std=1.0189
#   Normalized prop_location_score: new mean=0.0215, new std=1.0129
#   Normalized prop_accesibility_score: new mean=-0.0029, new std=0.9813
#   Normalized prop_log_historical_price: new mean=-0.0130, new std=1.0165
#   Normalized price_usd: new mean=-0.0020, new std=0.6541
#   Normalized promotion_flag: new mean=0.0134, new std=1.0133
#
# Applying normalization_params_q1 to Segment 2 (Sat Bookings):
#   Normalized prop_starrating: new mean=-0.0281, new std=0.9939
#   Normalized prop_review_score: new mean=0.0026, new std=1.0063
#   Normalized prop_brand_bool: new mean=0.0280, new std=0.9845
#   Normalized prop_location_score: new mean=-0.0162, new std=0.9899
#   Normalized prop_accesibility_score: new mean=0.0022, new std=1.0139
#   Normalized prop_log_historical_price: new mean=0.0098, new std=0.9872
#   Normalized price_usd: new mean=0.0015, new std=1.1968
#   Normalized promotion_flag: new mean=-0.0101, new std=0.9897

# %%
# Fit MNL model for each segment
beta_opt_1 = fit_mnl_model(data_segment_1, search_groups_1, features, "Segment 1 (Non-Sat Bookings)")
beta_opt_2 = fit_mnl_model(data_segment_2, search_groups_2, features, "Segment 2 (Sat Bookings)")

# Helper function to print results
def print_mnl_results(beta_opt, segment_name, normalization_params):
    print(f"\nMNL Model Parameters for {segment_name}:")
    print(f"Intercept (β₀): {beta_opt[0]:.4f}")
    
    feature_descriptions = {
        'prop_starrating': 'Star Rating (higher = better hotel quality)',
        'prop_review_score': 'Review Score (higher = better guest reviews)',
        'prop_brand_bool': 'Brand Flag (1 = branded hotel, 0 = independent)',
        'prop_location_score': 'Location Score (higher = better location)',
        'prop_accesibility_score': 'Accessibility Score (higher = better accessibility)',
        'prop_log_historical_price': 'Log Historical Price',
        'price_usd': 'Price in USD',
        'promotion_flag': 'Promotion Flag (1 = has promotion, 0 = no promotion)'
    }
    
    # Store coefficients for comparison
    coefficients = []
    feature_names = []
    
    for i, feature in enumerate(features):
        coef = beta_opt[i+1]
        print(f"{feature_descriptions.get(feature, feature)} (β{i+1}): {coef:.6f}")
        coefficients.append(coef)
        feature_names.append(feature)
    '''
    # Additional interpretation of the coefficients (considering normalization)
    print("\nInterpretation of Coefficients:")
    for i, feature in enumerate(features):
        coef = beta_opt[i+1]
        if feature in normalization_params:
            # For normalized features, we need to interpret differently
            std = normalization_params[feature]['std']
            original_coef = coef / std
            print(f"{feature}: A one-unit increase in the original {feature} increases utility by {original_coef:.6f}")
        else:
            # For binary features, interpretation remains the same
            print(f"{feature}: Presence of this feature changes utility by {coef:.6f}")

    '''
    
    return coefficients, feature_names
# Out:
# Starting optimization for Segment 1 (Non-Sat Bookings)...
# Optimization completed for Segment 1 (Non-Sat Bookings): True
# Final negative log-likelihood: 8775.771219710332
#
# Starting optimization for Segment 2 (Sat Bookings)...
# Optimization completed for Segment 2 (Sat Bookings): True
# Final negative log-likelihood: 11827.069625491831
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 49
#      46     return coefficients, feature_names
#      48 # Print results for each segment
# ---> 49 coef_1, features_list = print_mnl_results(beta_opt_1, "Segment 1 (Non-Sat Bookings)", normalization_params_1)
#      50 coef_2, _ = print_mnl_results(beta_opt_2, "Segment 2 (Sat Bookings)", normalization_params_2)
#      52 # Compare coefficients between segments
#
# NameError: name 'normalization_params_1' is not defined

# %%
# Print results for each segment
coef_1, features_list = print_mnl_results(beta_opt_1, "Segment 1 (Non-Sat Bookings)", normalization_params)
coef_2, _ = print_mnl_results(beta_opt_2, "Segment 2 (Sat Bookings)", normalization_params)

# Compare coefficients between segments
print("\nComparison of Coefficients between Segments:")
print("Feature | Non-Sat Booking (β) | Sat Booking (β) | Difference")
print("--------|-------------------|-----------------|------------")
for i, feature in enumerate(features_list):
    diff = coef_1[i] - coef_2[i]
    print(f"{feature} | {coef_1[i]:.6f} | {coef_2[i]:.6f} | {diff:.6f}")
# Out:
# MNL Model Parameters for Segment 1 (Non-Sat Bookings):
# Intercept (β₀): -1.7391
# Star Rating (higher = better hotel quality) (β1): 0.473942
# Review Score (higher = better guest reviews) (β2): 0.109629
# Brand Flag (1 = branded hotel, 0 = independent) (β3): 0.108720
# Location Score (higher = better location) (β4): 0.016666
# Accessibility Score (higher = better accessibility) (β5): 0.052382
# Log Historical Price (β6): -0.070328
# Price in USD (β7): -1.568860
# Promotion Flag (1 = has promotion, 0 = no promotion) (β8): 0.147910
#
# MNL Model Parameters for Segment 2 (Sat Bookings):
# Intercept (β₀): -1.7551
# Star Rating (higher = better hotel quality) (β1): 0.358241
# Review Score (higher = better guest reviews) (β2): 0.111053
# Brand Flag (1 = branded hotel, 0 = independent) (β3): 0.098476
# Location Score (higher = better location) (β4): 0.025599
# Accessibility Score (higher = better accessibility) (β5): 0.036260
# Log Historical Price (β6): -0.061769
# Price in USD (β7): -1.155128
# Promotion Flag (1 = has promotion, 0 = no promotion) (β8): 0.167791
#
# Comparison of Coefficients between Segments:
# Feature | Non-Sat Booking (β) | Sat Booking (β) | Difference
# --------|-------------------|-----------------|------------
# prop_starrating | 0.473942 | 0.358241 | 0.115701
# prop_review_score | 0.109629 | 0.111053 | -0.001424
# prop_brand_bool | 0.108720 | 0.098476 | 0.010244
# prop_location_score | 0.016666 | 0.025599 | -0.008933
# prop_accesibility_score | 0.052382 | 0.036260 | 0.016122
# prop_log_historical_price | -0.070328 | -0.061769 | -0.008559
# price_usd | -1.568860 | -1.155128 | -0.413732
# promotion_flag | 0.147910 | 0.167791 | -0.019882
